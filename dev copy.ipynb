# %%
import torch
import torch.nn as nn
from torch.utils.tensorboard import SummaryWriter


class MLP(nn.Module):
    def __init__(self):
        super().__init__()
        self.layers = nn.Sequential(
            nn.Linear(10, 32),
            nn.ReLU(),
            nn.Linear(32, 2)
        )
    def forward(self, x):
        return self.layers(x)


class SimpleCNN(nn.Module):
    def __init__(self, num_classes=4):
        super(SimpleCNN, self).__init__()
        self.conv1 = nn.Conv2d(in_channels=3, out_channels=16, kernel_size=3, padding=1)
        self.relu1 = nn.ReLU()
        self.pool1 = nn.MaxPool2d(2, 2)

        self.conv2 = nn.Conv2d(16, 32, 3, padding=1)
        self.relu2 = nn.ReLU()
        self.pool2 = nn.MaxPool2d(2, 2)

        self.flatten = nn.Flatten()
        self.fc1 = nn.Linear(32 * 8 * 8, 128)  
        self.relu3 = nn.ReLU()
        self.fc2 = nn.Linear(128, num_classes)

    def forward(self, x):
        x = self.pool1(self.relu1(self.conv1(x)))   
        x = self.pool2(self.relu2(self.conv2(x)))   
        x = self.flatten(x)                         
        x = self.relu3(self.fc1(x))                 
        x = self.fc2(x)                             
        return x

# %%
# --- Init model + writer ---
model = MLP()
dummy_input = torch.randn(1, 10)
model
# Out:
# MLP(
#   (layers): Sequential(
#     (0): Linear(in_features=10, out_features=32, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=32, out_features=2, bias=True)
#   )
# )

# %%
trace = torch.jit.trace(model, dummy_input)

# %%
trace.inlined_graph
# Out:
# graph(%self.1 : __torch__.___torch_mangle_20.MLP,
#       %x : Float(1, 10, strides=[10, 1], requires_grad=0, device=cpu)):
#   %layers : __torch__.torch.nn.modules.container.___torch_mangle_19.Sequential = prim::GetAttr[name="layers"](%self.1)
#   %_2 : __torch__.torch.nn.modules.linear.___torch_mangle_18.Linear = prim::GetAttr[name="2"](%layers)
#   %_1 : __torch__.torch.nn.modules.activation.___torch_mangle_17.ReLU = prim::GetAttr[name="1"](%layers)
#   %_0 : __torch__.torch.nn.modules.linear.___torch_mangle_16.Linear = prim::GetAttr[name="0"](%layers)
#   %bias.1 : Tensor = prim::GetAttr[name="bias"](%_0)
#   %weight.1 : Tensor = prim::GetAttr[name="weight"](%_0)
#   %input.1 : Float(1, 32, strides=[32, 1], requires_grad=1, device=cpu) = aten::linear(%x, %weight.1, %bias.1), scope: __module.layers/__module.layers.0 # /home/coder/Playground/.venv/lib/python3.10/site-packages/torch/nn/modules/linear.py:134:0
#   %input : Float(1, 32, strides=[32, 1], requires_grad=1, device=cpu) = aten::relu(%input.1), scope: __module.layers/__module.layers.1 # /home/coder/Playground/.venv/lib/python3.10/site-packages/torch/nn/functional.py:1697:0
#   %bias : Tensor = prim::GetAttr[name="bias"](%_2)
#   %weight : Tensor = prim::GetAttr[name="weight"](%_2)
#   %13 : Float(1, 2, strides=[2, 1], requires_grad=1, device=cpu) = aten::linear(%input, %weight, %bias), scope: __module.layers/__module.layers.2 # /home/coder/Playground/.venv/lib/python3.10/site-packages/torch/nn/modules/linear.py:134:0
#   return (%13)

# %%
model = SimpleCNN()
dummy_input = torch.randn(1, 3, 32, 32)
model
# Out:
# SimpleCNN(
#   (conv1): Conv2d(3, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (relu1): ReLU()
#   (pool1): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (conv2): Conv2d(16, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (relu2): ReLU()
#   (pool2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (flatten): Flatten(start_dim=1, end_dim=-1)
#   (fc1): Linear(in_features=2048, out_features=128, bias=True)
#   (relu3): ReLU()
#   (fc2): Linear(in_features=128, out_features=4, bias=True)
# )

# %%
writer = SummaryWriter("runs/mlp_test")
writer.add_graph(model, dummy_input)     # log model graph
writer.add_scalar("loss", 0.42, 1)       # log scalar
writer.close()

# %%
# mypy: allow-untyped-defs
from collections import OrderedDict
import contextlib
from typing import Any

from tensorboard.compat.proto.config_pb2 import RunMetadata
from tensorboard.compat.proto.graph_pb2 import GraphDef
from tensorboard.compat.proto.step_stats_pb2 import StepStats, DeviceStepStats
from tensorboard.compat.proto.versions_pb2 import VersionDef
from google.protobuf.json_format import MessageToDict
import torch
from torch.utils.tensorboard._proto_graph import node_proto

# %%
methods_OP = [
    "attributeNames",
    "hasMultipleOutputs",
    "hasUses",
    "inputs",
    "kind",
    "outputs",
    "outputsSize",
    "scopeName",
]
# Some additional methods to explure for methods_IO are
#
#   'unique' (type int)
#   'type' (type <Tensor<class 'torch._C.Type'>>)
#
# But the below are sufficient for now.
methods_IO = ["node", "offset", "debugName"]

GETATTR_KIND = "prim::GetAttr"
CLASSTYPE_KIND = "ClassType"


class NodeBase:
    def __init__(
        self,
        debugName=None,
        inputs=None,
        scope=None,
        tensor_size=None,
        op_type="UnSpecified",
        attributes="",
    ):
        # TODO; Specify a __slots__ for this class or potentially
        # used namedtuple instead
        self.debugName = debugName
        self.inputs = inputs
        self.tensor_size = tensor_size
        self.kind = op_type
        self.attributes = attributes
        self.scope = scope

    def __repr__(self):
        repr = []
        repr.append(str(type(self)))
        repr.extend(
            m + ": " + str(getattr(self, m)) + str(type(getattr(self, m)))
            for m in dir(self)
            if "__" not in m
        )
        return "\n".join(repr) + "\n\n"


class NodePy(NodeBase):
    def __init__(self, node_cpp, valid_methods):
        super().__init__(node_cpp)
        valid_methods = valid_methods[:]
        self.inputs = []

        for m in valid_methods:
            if m == "inputs" or m == "outputs":
                list_of_node = list(getattr(node_cpp, m)())
                io_unique_names = []
                io_tensor_sizes = []
                for n in list_of_node:
                    io_unique_names.append(n.debugName())
                    if n.isCompleteTensor():
                        io_tensor_sizes.append(n.type().sizes())
                    else:
                        io_tensor_sizes.append(None)

                setattr(self, m, io_unique_names)
                setattr(self, m + "tensor_size", io_tensor_sizes)

            else:
                setattr(self, m, getattr(node_cpp, m)())


class NodePyIO(NodePy):
    def __init__(self, node_cpp, input_or_output=None):
        super().__init__(node_cpp, methods_IO)
        try:
            tensor_size = node_cpp.type().sizes()
        except RuntimeError:
            tensor_size = [
                1,
            ]  # fail when constant model is used.
        self.tensor_size = tensor_size
        # Kind attribute string is purely descriptive and will be shown
        # in detailed information for the node in TensorBoard's graph plugin.
        #
        # NodePyOP nodes get this from their kind() method.
        self.kind = "Parameter"
        if input_or_output:
            self.input_or_output = input_or_output
            self.kind = "IO Node"


class NodePyOP(NodePy):
    def __init__(self, node_cpp):
        super().__init__(node_cpp, methods_OP)
        # Replace single quote which causes strange behavior in TensorBoard
        # TODO: See if we can remove this in the future
        self.attributes = str(
            {k: _node_get(node_cpp, k) for k in node_cpp.attributeNames()}
        ).replace("'", " ")
        print(self.attributes)
        self.kind = node_cpp.kind()


class GraphPy:
    """Helper class to convert torch.nn.Module to GraphDef proto and visualization with TensorBoard.

    GraphDef generation operates in two passes:

    In the first pass, all nodes are read and saved to two lists.
    One list is for input/output nodes (nodes_io), which only have inbound
    or outbound connections, but not both. Another list is for internal
    operator nodes (nodes_op). The first pass also saves all scope name
    appeared in the nodes in scope_name_appeared list for later processing.

    In the second pass, scope names are fully applied to all nodes.
    debugNameToScopedName is a mapping from a node's ID to its fully qualified
    scope name. e.g. Net1/Linear[0]/1. Unfortunately torch.jit doesn't have
    totally correct scope output, so this is nontrivial. The function
    populate_namespace_from_OP_to_IO and find_common_root are used to
    assign scope name to a node based on the connection between nodes
    in a heuristic kind of way. Bookkeeping is done with shallowest_scope_name
    and scope_name_appeared.
    """

    def __init__(self):
        self.nodes_op = []
        self.nodes_io = OrderedDict()
        self.unique_name_to_scoped_name = {}
        self.shallowest_scope_name = "default"
        self.scope_name_appeared = []

    def append(self, x):
        if isinstance(x, NodePyIO):
            self.nodes_io[x.debugName] = x
        if isinstance(x, NodePyOP):
            self.nodes_op.append(x)

    def printall(self):
        print("all nodes")
        for node in self.nodes_op:
            print(node)
        for key in self.nodes_io:
            print(self.nodes_io[key])

    def find_common_root(self):
        for fullscope in self.scope_name_appeared:
            if fullscope:
                self.shallowest_scope_name = fullscope.split("/")[0]

    def populate_namespace_from_OP_to_IO(self):
        for node in self.nodes_op:
            for node_output, outputSize in zip(node.outputs, node.outputstensor_size):
                self.scope_name_appeared.append(node.scopeName)
                self.nodes_io[node_output] = NodeBase(
                    node_output,
                    node.inputs,
                    node.scopeName,
                    outputSize,
                    op_type=node.kind,
                    attributes=node.attributes,
                )

        self.find_common_root()

        for node in self.nodes_op:
            for input_node_id in node.inputs:
                self.unique_name_to_scoped_name[input_node_id] = (
                    node.scopeName + "/" + input_node_id
                )

        for key, node in self.nodes_io.items():
            if type(node) == NodeBase:
                self.unique_name_to_scoped_name[key] = node.scope + "/" + node.debugName
            if hasattr(node, "input_or_output"):
                self.unique_name_to_scoped_name[key] = (
                    node.input_or_output + "/" + node.debugName
                )

            if hasattr(node, "scope") and node.scope is not None:
                self.unique_name_to_scoped_name[key] = node.scope + "/" + node.debugName
                if node.scope == "" and self.shallowest_scope_name:
                    self.unique_name_to_scoped_name[node.debugName] = (
                        self.shallowest_scope_name + "/" + node.debugName
                    )

        # replace name
        for key, node in self.nodes_io.items():
            self.nodes_io[key].inputs = [
                self.unique_name_to_scoped_name[node_input_id]
                for node_input_id in node.inputs
            ]
            if node.debugName in self.unique_name_to_scoped_name:
                self.nodes_io[key].debugName = self.unique_name_to_scoped_name[
                    node.debugName
                ]

    def to_proto(self):
        """Convert graph representation of GraphPy object to TensorBoard required format."""
        # TODO: compute correct memory usage and CPU time once
        # PyTorch supports it
        nodes = [
            node_proto(
                v.debugName,
                input=v.inputs,
                outputsize=v.tensor_size,
                op=v.kind,
                attributes=v.attributes,
            )
            for v in self.nodes_io.values()
        ]
        return nodes


def parse(graph, trace, args=None, omit_useless_nodes=True):
    """Parse an optimized PyTorch model graph and produces a list of nodes and node stats.

    Useful for eventual conversion to TensorBoard protobuf format.

    Args:
      graph (PyTorch module): The model graph to be parsed.
      trace (PyTorch JIT TracedModule): The model trace to be parsed.
      args (tuple): input tensor[s] for the model.
      omit_useless_nodes (boolean): Whether to remove nodes from the graph.
    """
    nodes_py = GraphPy()
    for node in graph.inputs():
        if omit_useless_nodes:
            if (
                len(node.uses()) == 0
            ):  # number of user of the node (= number of outputs/ fanout)
                continue

        if node.type().kind() != CLASSTYPE_KIND:
            nodes_py.append(NodePyIO(node, "input"))

    attr_to_scope: dict[Any, str] = {}
    for node in graph.nodes():
        if node.kind() == GETATTR_KIND:
            attr_name = node.s("name")
            attr_key = node.output().debugName()
            parent = node.input().node()
            if (
                parent.kind() == GETATTR_KIND
            ):  # If the parent node is not the top-level "self" node
                parent_attr_key = parent.output().debugName()
                parent_scope = attr_to_scope[parent_attr_key]
                attr_scope = parent_scope.split("/")[-1]
                attr_to_scope[attr_key] = f"{parent_scope}/{attr_scope}.{attr_name}"
            else:
                attr_to_scope[attr_key] = f"__module.{attr_name}"
            # We don't need classtype nodes; scope will provide this information
            if node.output().type().kind() != CLASSTYPE_KIND:
                node_py = NodePyOP(node)
                node_py.scopeName = attr_to_scope[attr_key]  # type: ignore[attr-defined]
                nodes_py.append(node_py)
        else:
            nodes_py.append(NodePyOP(node))

    for i, node in enumerate(graph.outputs()):  # Create sink nodes for output ops
        node_pyio = NodePyIO(node, "output")
        node_pyio.debugName = f"output.{i + 1}"
        node_pyio.inputs = [node.debugName()]
        nodes_py.append(node_pyio)

    def parse_traced_name(module):
        if isinstance(module, torch.jit.TracedModule):
            module_name = module._name
        else:
            module_name = getattr(module, "original_name", "Module")
        return module_name

    alias_to_name = {}
    base_name = parse_traced_name(trace)
    for name, module in trace.named_modules(prefix="__module"):
        mod_name = parse_traced_name(module)
        attr_name = name.split(".")[-1]
        alias_to_name[name] = f"{mod_name}[{attr_name}]"

    for node in nodes_py.nodes_op:
        module_aliases = node.scopeName.split("/")
        replacements = [
            alias_to_name[alias] if alias in alias_to_name else alias.split(".")[-1]
            for alias in module_aliases
        ]
        node.scopeName = base_name
        if any(replacements):
            node.scopeName += "/" + "/".join(replacements)

    nodes_py.populate_namespace_from_OP_to_IO()
    return nodes_py.to_proto()


def graph(model, args, verbose=False, use_strict_trace=True):
    """
    Process a PyTorch model and produces a `GraphDef` proto that can be logged to TensorBoard.

    Args:
      model (PyTorch module): The model to be parsed.
      args (tuple): input tensor[s] for the model.
      verbose (bool): Whether to print out verbose information while
        processing.
      use_strict_trace (bool): Whether to pass keyword argument `strict` to
        `torch.jit.trace`. Pass False when you want the tracer to
        record your mutable container types (list, dict)
    """
    with _set_model_to_eval(model):
        try:
            trace = torch.jit.trace(model, args, strict=use_strict_trace)
            graph = trace.graph
            torch._C._jit_pass_inline(graph)
        except RuntimeError as e:
            print(e)
            print("Error occurs, No graph saved")
            raise e

    if verbose:
        print(graph)
    list_of_nodes = parse(graph, trace, args)
    # We are hardcoding that this was run on CPU even though it might have actually
    # run on GPU. Note this is what is shown in TensorBoard and has no bearing
    # on actual execution.
    # TODO: See if we can extract GPU vs CPU information from the PyTorch model
    # and pass it correctly to TensorBoard.
    #
    # Definition of StepStats and DeviceStepStats can be found at
    # https://github.com/tensorflow/tensorboard/blob/master/tensorboard/plugins/graph/tf_graph_common/test/graph-test.ts
    # and
    # https://github.com/tensorflow/tensorboard/blob/master/tensorboard/compat/proto/step_stats.proto
    stepstats = RunMetadata(
        step_stats=StepStats(dev_stats=[DeviceStepStats(device="/device:CPU:0")])
    )
    return GraphDef(node=list_of_nodes, versions=VersionDef(producer=22)), stepstats
    # The producer version has been reverse engineered from standard
    # TensorBoard logged data.


@contextlib.contextmanager
def _set_model_to_eval(model):
    """Context manager to temporarily set the training mode of ``model`` to eval."""
    if not isinstance(model, torch.jit.ScriptFunction):
        originally_training = model.training
        model.train(False)
        try:
            yield
        finally:
            model.train(originally_training)
    else:
        # Do nothing for ScriptFunction
        try:
            yield
        finally:
            pass


def _node_get(node: torch._C.Node, key: str):
    """Get attributes of a node which is polymorphic over return type."""
    sel = node.kindOf(key)
    return getattr(node, sel)(key)

# %%
import base64
from typing import Dict, Any

def try_decode_base64_attr(s: str) -> str:
    """Safely decodes a Base64 string if it appears to contain dictionary-like data."""
    if not isinstance(s, str):
        return s
    
    try:
        # Attempt to decode, handling both Base64 and UTF-8 conversion errors
        decoded_bytes = base64.b64decode(s, validate=True)
        decoded_str = decoded_bytes.decode('utf-8')
        
        # Heuristic check: only replace if the content looks like a dictionary/text
        if '{' in decoded_str or '}' in decoded_str or ':' in decoded_str or 'name' in decoded_str:
            return decoded_str.strip()
            
    except Exception:
        # Return the original string if decoding fails or heuristic check fails
        pass

    return s

def clean_graphdef_attributes(data_dict: Dict[str, Any]) -> Dict[str, Any]:
    """
    Cleans Base64-encoded attribute values within a dictionary representation 
    of a GraphDef Protobuf message created by MessageToDict.
    """
    if 'node' not in data_dict:
        return data_dict

    for node in data_dict['node']:
        if 'attr' in node:
            # Check the dictionary that holds the attributes (e.g., {'attr': {'s': 'Base64...'}})
            for attr_name, attr_data in node['attr'].items():
                # Base64 strings are typically stored under the 's' key for string/bytes fields
                if 's' in attr_data:
                    encoded_value = attr_data['s']
                    decoded_value = try_decode_base64_attr(encoded_value)
                    
                    if decoded_value != encoded_value:
                        # If decoding was successful, replace the 's' key with the decoded string
                        attr_data['s'] = decoded_value

    return data_dict

# %%
model_graph = graph(model,dummy_input,True)[0]
# Out:
# graph(%self.1 : __torch__.___torch_mangle_54.SimpleCNN,
#       %x : Float(1, 3, 32, 32, strides=[3072, 1024, 32, 1], requires_grad=0, device=cpu)):
#   %fc2 : __torch__.torch.nn.modules.linear.___torch_mangle_53.Linear = prim::GetAttr[name="fc2"](%self.1)
#   %relu3 : __torch__.torch.nn.modules.activation.___torch_mangle_52.ReLU = prim::GetAttr[name="relu3"](%self.1)
#   %fc1 : __torch__.torch.nn.modules.linear.___torch_mangle_51.Linear = prim::GetAttr[name="fc1"](%self.1)
#   %flatten : __torch__.torch.nn.modules.flatten.___torch_mangle_50.Flatten = prim::GetAttr[name="flatten"](%self.1)
#   %pool2 : __torch__.torch.nn.modules.pooling.___torch_mangle_49.MaxPool2d = prim::GetAttr[name="pool2"](%self.1)
#   %relu2 : __torch__.torch.nn.modules.activation.___torch_mangle_48.ReLU = prim::GetAttr[name="relu2"](%self.1)
#   %conv2 : __torch__.torch.nn.modules.conv.___torch_mangle_47.Conv2d = prim::GetAttr[name="conv2"](%self.1)
#   %pool1 : __torch__.torch.nn.modules.pooling.___torch_mangle_46.MaxPool2d = prim::GetAttr[name="pool1"](%self.1)
#   %relu1 : __torch__.torch.nn.modules.activation.___torch_mangle_45.ReLU = prim::GetAttr[name="relu1"](%self.1)
#   %conv1 : __torch__.torch.nn.modules.conv.___torch_mangle_44.Conv2d = prim::GetAttr[name="conv1"](%self.1)
#   %164 : bool = prim::Constant[value=1](), scope: __module.conv1 # /home/coder/Playground/.venv/lib/python3.10/site-packages/torch/nn/modules/conv.py:543:0
#   %165 : int = prim::Constant[value=0](), scope: __module.conv1 # /home/coder/Playground/.venv/lib/python3.10/site-packages/torch/nn/modules/conv.py:543:0
#   %166 : bool = prim::Constant[value=0](), scope: __module.conv1 # /home/coder/Playground/.venv/lib/python3.10/site-packages/torch/nn/modules/conv.py:543:0
#   %167 : int = prim::Constant[value=1](), scope: __module.conv1 # /home/coder/Playground/.venv/lib/python3.10/site-packages/torch/nn/modules/conv.py:543:0
#   %bias.5 : Tensor = prim::GetAttr[name="bias"](%conv1)
#   %weight.5 : Tensor = prim::GetAttr[name="weight"](%conv1)
#   %170 : int[] = prim::ListConstruct(%167, %167), scope: __module.conv1
#   %171 : int[] = prim::ListConstruct(%167, %167), scope: __module.conv1
#   %172 : int[] = prim::ListConstruct(%167, %167), scope: __module.conv1
#   %173 : int[] = prim::ListConstruct(%165, %165), scope: __module.conv1
#   %input.1 : Float(1, 16, 32, 32, strides=[16384, 1024, 32, 1], requires_grad=0, device=cpu) = aten::_convolution(%x, %weight.5, %bias.5, %170, %171, %172, %166, %173, %167, %166, %166, %164, %164), scope: __module.conv1 # /home/coder/Playground/.venv/lib/python3.10/site-packages/torch/nn/modules/conv.py:543:0
#   %input.3 : Float(1, 16, 32, 32, strides=[16384, 1024, 32, 1], requires_grad=1, device=cpu) = aten::relu(%input.1), scope: __module.relu1 # /home/coder/Playground/.venv/lib/python3.10/site-packages/torch/nn/functional.py:1697:0
#   %176 : bool = prim::Constant[value=0](), scope: __module.pool1 # /home/coder/Playground/.venv/lib/python3.10/site-packages/torch/nn/functional.py:823:0
#   %177 : int = prim::Constant[value=1](), scope: __module.pool1 # /home/coder/Playground/.venv/lib/python3.10/site-packages/torch/nn/functional.py:823:0
#   %178 : int = prim::Constant[value=0](), scope: __module.pool1 # /home/coder/Playground/.venv/lib/python3.10/site-packages/torch/nn/functional.py:823:0
#   %179 : int = prim::Constant[value=2](), scope: __module.pool1 # /home/coder/Playground/.venv/lib/python3.10/site-packages/torch/nn/functional.py:823:0
#   %180 : int[] = prim::ListConstruct(%179, %179), scope: __module.pool1
#   %181 : int[] = prim::ListConstruct(%179, %179), scope: __module.pool1
#   %182 : int[] = prim::ListConstruct(%178, %178), scope: __module.pool1
#   %183 : int[] = prim::ListConstruct(%177, %177), scope: __module.pool1
#   %input.5 : Float(1, 16, 16, 16, strides=[4096, 256, 16, 1], requires_grad=1, device=cpu) = aten::max_pool2d(%input.3, %180, %181, %182, %183, %176), scope: __module.pool1 # /home/coder/Playground/.venv/lib/python3.10/site-packages/torch/nn/functional.py:823:0
#   %185 : bool = prim::Constant[value=1](), scope: __module.conv2 # /home/coder/Playground/.venv/lib/python3.10/site-packages/torch/nn/modules/conv.py:543:0
#   %186 : int = prim::Constant[value=0](), scope: __module.conv2 # /home/coder/Playground/.venv/lib/python3.10/site-packages/torch/nn/modules/conv.py:543:0
#   %187 : bool = prim::Constant[value=0](), scope: __module.conv2 # /home/coder/Playground/.venv/lib/python3.10/site-packages/torch/nn/modules/conv.py:543:0
#   %188 : int = prim::Constant[value=1](), scope: __module.conv2 # /home/coder/Playground/.venv/lib/python3.10/site-packages/torch/nn/modules/conv.py:543:0
#   %bias.7 : Tensor = prim::GetAttr[name="bias"](%conv2)
#   %weight.7 : Tensor = prim::GetAttr[name="weight"](%conv2)
#   %191 : int[] = prim::ListConstruct(%188, %188), scope: __module.conv2
#   %192 : int[] = prim::ListConstruct(%188, %188), scope: __module.conv2
#   %193 : int[] = prim::ListConstruct(%188, %188), scope: __module.conv2
#   %194 : int[] = prim::ListConstruct(%186, %186), scope: __module.conv2
#   %input.7 : Float(1, 32, 16, 16, strides=[8192, 256, 16, 1], requires_grad=0, device=cpu) = aten::_convolution(%input.5, %weight.7, %bias.7, %191, %192, %193, %187, %194, %188, %187, %187, %185, %185), scope: __module.conv2 # /home/coder/Playground/.venv/lib/python3.10/site-packages/torch/nn/modules/conv.py:543:0
#   %input.9 : Float(1, 32, 16, 16, strides=[8192, 256, 16, 1], requires_grad=1, device=cpu) = aten::relu(%input.7), scope: __module.relu2 # /home/coder/Playground/.venv/lib/python3.10/site-packages/torch/nn/functional.py:1697:0
#   %197 : bool = prim::Constant[value=0](), scope: __module.pool2 # /home/coder/Playground/.venv/lib/python3.10/site-packages/torch/nn/functional.py:823:0
#   %198 : int = prim::Constant[value=1](), scope: __module.pool2 # /home/coder/Playground/.venv/lib/python3.10/site-packages/torch/nn/functional.py:823:0
#   %199 : int = prim::Constant[value=0](), scope: __module.pool2 # /home/coder/Playground/.venv/lib/python3.10/site-packages/torch/nn/functional.py:823:0
#   %200 : int = prim::Constant[value=2](), scope: __module.pool2 # /home/coder/Playground/.venv/lib/python3.10/site-packages/torch/nn/functional.py:823:0
#   %201 : int[] = prim::ListConstruct(%200, %200), scope: __module.pool2
#   %202 : int[] = prim::ListConstruct(%200, %200), scope: __module.pool2
#   %203 : int[] = prim::ListConstruct(%199, %199), scope: __module.pool2
#   %204 : int[] = prim::ListConstruct(%198, %198), scope: __module.pool2
#   %input.11 : Float(1, 32, 8, 8, strides=[2048, 64, 8, 1], requires_grad=1, device=cpu) = aten::max_pool2d(%input.9, %201, %202, %203, %204, %197), scope: __module.pool2 # /home/coder/Playground/.venv/lib/python3.10/site-packages/torch/nn/functional.py:823:0
#   %206 : int = prim::Constant[value=-1](), scope: __module.flatten # /home/coder/Playground/.venv/lib/python3.10/site-packages/torch/nn/modules/flatten.py:56:0
#   %207 : int = prim::Constant[value=1](), scope: __module.flatten # /home/coder/Playground/.venv/lib/python3.10/site-packages/torch/nn/modules/flatten.py:56:0
#   %input.13 : Float(1, 2048, strides=[2048, 1], requires_grad=1, device=cpu) = aten::flatten(%input.11, %207, %206), scope: __module.flatten # /home/coder/Playground/.venv/lib/python3.10/site-packages/torch/nn/modules/flatten.py:56:0
#   %bias.9 : Tensor = prim::GetAttr[name="bias"](%fc1)
#   %weight.9 : Tensor = prim::GetAttr[name="weight"](%fc1)
#   %input.15 : Float(1, 128, strides=[128, 1], requires_grad=1, device=cpu) = aten::linear(%input.13, %weight.9, %bias.9), scope: __module.fc1 # /home/coder/Playground/.venv/lib/python3.10/site-packages/torch/nn/modules/linear.py:134:0
#   %input : Float(1, 128, strides=[128, 1], requires_grad=1, device=cpu) = aten::relu(%input.15), scope: __module.relu3 # /home/coder/Playground/.venv/lib/python3.10/site-packages/torch/nn/functional.py:1697:0
#   %bias : Tensor = prim::GetAttr[name="bias"](%fc2)
#   %weight : Tensor = prim::GetAttr[name="weight"](%fc2)
#   %215 : Float(1, 4, strides=[4, 1], requires_grad=1, device=cpu) = aten::linear(%input, %weight, %bias), scope: __module.fc2 # /home/coder/Playground/.venv/lib/python3.10/site-packages/torch/nn/modules/linear.py:134:0
#   return (%215)
#
# { value : 1}
# { value : 0}
# { value : 0}
# { value : 1}
# { name :  bias }
# { name :  weight }
# {}
# {}
# {}
# {}
# {}
# {}
# { value : 0}
# { value : 1}
# { value : 0}
# { value : 2}
# {}
# {}
# {}
# {}
# {}
# { value : 1}
# { value : 0}
# { value : 0}
# { value : 1}
# { name :  bias }
# { name :  weight }
# {}
# {}
# {}
# {}
# {}
# {}
# { value : 0}
# { value : 1}
# { value : 0}
# { value : 2}
# {}
# {}
# {}
# {}
# {}
# { value : -1}
# { value : 1}
# {}
# { name :  bias }
# { name :  weight }
# {}
# {}
# { name :  bias }
# { name :  weight }
# {}

# %%
model_graph
# Out:
# node {
#   name: "input/x"
#   op: "IO Node"
#   attr {
#     key: "attr"
#     value {
#       s: ""
#     }
#   }
#   attr {
#     key: "_output_shapes"
#     value {
#       list {
#         shape {
#           dim {
#             size: 1
#           }
#           dim {
#             size: 3
#           }
#           dim {
#             size: 32
#           }
#           dim {
#             size: 32
#           }
#         }
#       }
#     }
#   }
# }
# node {
#   name: "output/output.1"
#   op: "IO Node"
#   input: "SimpleCNN/Linear[fc2]/215"
#   attr {
#     key: "attr"
#     value {
#       s: ""
#     }
#   }
#   attr {
#     key: "_output_shapes"
#     value {
#       list {
#         shape {
#           dim {
#             size: 1
#           }
#           dim {
#             size: 4
#           }
#         }
#       }
#     }
#   }
# }
# node {
#   name: "SimpleCNN/Conv2d[conv1]/164"
#   op: "prim::Constant"
#   attr {
#     key: "attr"
#     value {
#       s: "{ value : 1}"
#     }
#   }
# }
# node {
#   name: "SimpleCNN/Conv2d[conv1]/165"
#   op: "prim::Constant"
#   attr {
#     key: "attr"
#     value {
#       s: "{ value : 0}"
#     }
#   }
# }
# node {
#   name: "SimpleCNN/Conv2d[conv1]/166"
#   op: "prim::Constant"
#   attr {
#     key: "attr"
#     value {
#       s: "{ value : 0}"
#     }
#   }
# }
# node {
#   name: "SimpleCNN/Conv2d[conv1]/167"
#   op: "prim::Constant"
#   attr {
#     key: "attr"
#     value {
#       s: "{ value : 1}"
#     }
#   }
# }
# node {
#   name: "SimpleCNN/Conv2d[conv1]/bias/bias.5"
#   op: "prim::GetAttr"
#   input: "SimpleCNN/Conv2d[conv1]/weight/conv1"
#   attr {
#     key: "attr"
#     value {
#       s: "{ name :  bias }"
#     }
#   }
# }
# node {
#   name: "SimpleCNN/Conv2d[conv1]/weight/weight.5"
#   op: "prim::GetAttr"
#   input: "SimpleCNN/Conv2d[conv1]/weight/conv1"
#   attr {
#     key: "attr"
#     value {
#       s: "{ name :  weight }"
#     }
#   }
# }
# node {
#   name: "SimpleCNN/Conv2d[conv1]/170"
#   op: "prim::ListConstruct"
#   input: "SimpleCNN/Conv2d[conv1]/167"
#   input: "SimpleCNN/Conv2d[conv1]/167"
#   attr {
#     key: "attr"
#     value {
#       s: "{}"
#     }
#   }
# }
# node {
#   name: "SimpleCNN/Conv2d[conv1]/171"
#   op: "prim::ListConstruct"
#   input: "SimpleCNN/Conv2d[conv1]/167"
#   input: "SimpleCNN/Conv2d[conv1]/167"
#   attr {
#     key: "attr"
#     value {
#       s: "{}"
#     }
#   }
# }
# node {
#   name: "SimpleCNN/Conv2d[conv1]/172"
#   op: "prim::ListConstruct"
#   input: "SimpleCNN/Conv2d[conv1]/167"
#   input: "SimpleCNN/Conv2d[conv1]/167"
#   attr {
#     key: "attr"
#     value {
#       s: "{}"
#     }
#   }
# }
# node {
#   name: "SimpleCNN/Conv2d[conv1]/173"
#   op: "prim::ListConstruct"
#   input: "SimpleCNN/Conv2d[conv1]/165"
#   input: "SimpleCNN/Conv2d[conv1]/165"
#   attr {
#     key: "attr"
#     value {
#       s: "{}"
#     }
#   }
# }
# node {
#   name: "SimpleCNN/Conv2d[conv1]/input.1"
#   op: "aten::_convolution"
#   input: "input/x"
#   input: "SimpleCNN/Conv2d[conv1]/weight/weight.5"
#   input: "SimpleCNN/Conv2d[conv1]/bias/bias.5"
#   input: "SimpleCNN/Conv2d[conv1]/170"
#   input: "SimpleCNN/Conv2d[conv1]/171"
#   input: "SimpleCNN/Conv2d[conv1]/172"
#   input: "SimpleCNN/Conv2d[conv1]/166"
#   input: "SimpleCNN/Conv2d[conv1]/173"
#   input: "SimpleCNN/Conv2d[conv1]/167"
#   input: "SimpleCNN/Conv2d[conv1]/166"
#   input: "SimpleCNN/Conv2d[conv1]/166"
#   input: "SimpleCNN/Conv2d[conv1]/164"
#   input: "SimpleCNN/Conv2d[conv1]/164"
#   attr {
#     key: "attr"
#     value {
#       s: "{}"
#     }
#   }
#   attr {
#     key: "_output_shapes"
#     value {
#       list {
#         shape {
#           dim {
#             size: 1
#           }
#           dim {
#             size: 16
#           }
#           dim {
#             size: 32
#           }
#           dim {
#             size: 32
#           }
#         }
#       }
#     }
#   }
# }
# node {
#   name: "SimpleCNN/ReLU[relu1]/input.3"
#   op: "aten::relu"
#   input: "SimpleCNN/Conv2d[conv1]/input.1"
#   attr {
#     key: "attr"
#     value {
#       s: "{}"
#     }
#   }
#   attr {
#     key: "_output_shapes"
#     value {
#       list {
#         shape {
#           dim {
#             size: 1
#           }
#           dim {
#             size: 16
#           }
#           dim {
#             size: 32
#           }
#           dim {
#             size: 32
#           }
#         }
#       }
#     }
#   }
# }
# node {
#   name: "SimpleCNN/MaxPool2d[pool1]/176"
#   op: "prim::Constant"
#   attr {
#     key: "attr"
#     value {
#       s: "{ value : 0}"
#     }
#   }
# }
# node {
#   name: "SimpleCNN/MaxPool2d[pool1]/177"
#   op: "prim::Constant"
#   attr {
#     key: "attr"
#     value {
#       s: "{ value : 1}"
#     }
#   }
# }
# node {
#   name: "SimpleCNN/MaxPool2d[pool1]/178"
#   op: "prim::Constant"
#   attr {
#     key: "attr"
#     value {
#       s: "{ value : 0}"
#     }
#   }
# }
# node {
#   name: "SimpleCNN/MaxPool2d[pool1]/179"
#   op: "prim::Constant"
#   attr {
#     key: "attr"
#     value {
#       s: "{ value : 2}"
#     }
#   }
# }
# node {
#   name: "SimpleCNN/MaxPool2d[pool1]/180"
#   op: "prim::ListConstruct"
#   input: "SimpleCNN/MaxPool2d[pool1]/179"
#   input: "SimpleCNN/MaxPool2d[pool1]/179"
#   attr {
#     key: "attr"
#     value {
#       s: "{}"
#     }
#   }
# }
# node {
#   name: "SimpleCNN/MaxPool2d[pool1]/181"
#   op: "prim::ListConstruct"
#   input: "SimpleCNN/MaxPool2d[pool1]/179"
#   input: "SimpleCNN/MaxPool2d[pool1]/179"
#   attr {
#     key: "attr"
#     value {
#       s: "{}"
#     }
#   }
# }
# node {
#   name: "SimpleCNN/MaxPool2d[pool1]/182"
#   op: "prim::ListConstruct"
#   input: "SimpleCNN/MaxPool2d[pool1]/178"
#   input: "SimpleCNN/MaxPool2d[pool1]/178"
#   attr {
#     key: "attr"
#     value {
#       s: "{}"
#     }
#   }
# }
# node {
#   name: "SimpleCNN/MaxPool2d[pool1]/183"
#   op: "prim::ListConstruct"
#   input: "SimpleCNN/MaxPool2d[pool1]/177"
#   input: "SimpleCNN/MaxPool2d[pool1]/177"
#   attr {
#     key: "attr"
#     value {
#       s: "{}"
#     }
#   }
# }
# node {
#   name: "SimpleCNN/MaxPool2d[pool1]/input.5"
#   op: "aten::max_pool2d"
#   input: "SimpleCNN/ReLU[relu1]/input.3"
#   input: "SimpleCNN/MaxPool2d[pool1]/180"
#   input: "SimpleCNN/MaxPool2d[pool1]/181"
#   input: "SimpleCNN/MaxPool2d[pool1]/182"
#   input: "SimpleCNN/MaxPool2d[pool1]/183"
#   input: "SimpleCNN/MaxPool2d[pool1]/176"
#   attr {
#     key: "attr"
#     value {
#       s: "{}"
#     }
#   }
#   attr {
#     key: "_output_shapes"
#     value {
#       list {
#         shape {
#           dim {
#             size: 1
#           }
#           dim {
#             size: 16
#           }
#           dim {
#             size: 16
#           }
#           dim {
#             size: 16
#           }
#         }
#       }
#     }
#   }
# }
# node {
#   name: "SimpleCNN/Conv2d[conv2]/185"
#   op: "prim::Constant"
#   attr {
#     key: "attr"
#     value {
#       s: "{ value : 1}"
#     }
#   }
# }
# node {
#   name: "SimpleCNN/Conv2d[conv2]/186"
#   op: "prim::Constant"
#   attr {
#     key: "attr"
#     value {
#       s: "{ value : 0}"
#     }
#   }
# }
# node {
#   name: "SimpleCNN/Conv2d[conv2]/187"
#   op: "prim::Constant"
#   attr {
#     key: "attr"
#     value {
#       s: "{ value : 0}"
#     }
#   }
# }
# node {
#   name: "SimpleCNN/Conv2d[conv2]/188"
#   op: "prim::Constant"
#   attr {
#     key: "attr"
#     value {
#       s: "{ value : 1}"
#     }
#   }
# }
# node {
#   name: "SimpleCNN/Conv2d[conv2]/bias/bias.7"
#   op: "prim::GetAttr"
#   input: "SimpleCNN/Conv2d[conv2]/weight/conv2"
#   attr {
#     key: "attr"
#     value {
#       s: "{ name :  bias }"
#     }
#   }
# }
# node {
#   name: "SimpleCNN/Conv2d[conv2]/weight/weight.7"
#   op: "prim::GetAttr"
#   input: "SimpleCNN/Conv2d[conv2]/weight/conv2"
#   attr {
#     key: "attr"
#     value {
#       s: "{ name :  weight }"
#     }
#   }
# }
# node {
#   name: "SimpleCNN/Conv2d[conv2]/191"
#   op: "prim::ListConstruct"
#   input: "SimpleCNN/Conv2d[conv2]/188"
#   input: "SimpleCNN/Conv2d[conv2]/188"
#   attr {
#     key: "attr"
#     value {
#       s: "{}"
#     }
#   }
# }
# node {
#   name: "SimpleCNN/Conv2d[conv2]/192"
#   op: "prim::ListConstruct"
#   input: "SimpleCNN/Conv2d[conv2]/188"
#   input: "SimpleCNN/Conv2d[conv2]/188"
#   attr {
#     key: "attr"
#     value {
#       s: "{}"
#     }
#   }
# }
# node {
#   name: "SimpleCNN/Conv2d[conv2]/193"
#   op: "prim::ListConstruct"
#   input: "SimpleCNN/Conv2d[conv2]/188"
#   input: "SimpleCNN/Conv2d[conv2]/188"
#   attr {
#     key: "attr"
#     value {
#       s: "{}"
#     }
#   }
# }
# node {
#   name: "SimpleCNN/Conv2d[conv2]/194"
#   op: "prim::ListConstruct"
#   input: "SimpleCNN/Conv2d[conv2]/186"
#   input: "SimpleCNN/Conv2d[conv2]/186"
#   attr {
#     key: "attr"
#     value {
#       s: "{}"
#     }
#   }
# }
# node {
#   name: "SimpleCNN/Conv2d[conv2]/input.7"
#   op: "aten::_convolution"
#   input: "SimpleCNN/MaxPool2d[pool1]/input.5"
#   input: "SimpleCNN/Conv2d[conv2]/weight/weight.7"
#   input: "SimpleCNN/Conv2d[conv2]/bias/bias.7"
#   input: "SimpleCNN/Conv2d[conv2]/191"
#   input: "SimpleCNN/Conv2d[conv2]/192"
#   input: "SimpleCNN/Conv2d[conv2]/193"
#   input: "SimpleCNN/Conv2d[conv2]/187"
#   input: "SimpleCNN/Conv2d[conv2]/194"
#   input: "SimpleCNN/Conv2d[conv2]/188"
#   input: "SimpleCNN/Conv2d[conv2]/187"
#   input: "SimpleCNN/Conv2d[conv2]/187"
#   input: "SimpleCNN/Conv2d[conv2]/185"
#   input: "SimpleCNN/Conv2d[conv2]/185"
#   attr {
#     key: "attr"
#     value {
#       s: "{}"
#     }
#   }
#   attr {
#     key: "_output_shapes"
#     value {
#       list {
#         shape {
#           dim {
#             size: 1
#           }
#           dim {
#             size: 32
#           }
#           dim {
#             size: 16
#           }
#           dim {
#             size: 16
#           }
#         }
#       }
#     }
#   }
# }
# node {
#   name: "SimpleCNN/ReLU[relu2]/input.9"
#   op: "aten::relu"
#   input: "SimpleCNN/Conv2d[conv2]/input.7"
#   attr {
#     key: "attr"
#     value {
#       s: "{}"
#     }
#   }
#   attr {
#     key: "_output_shapes"
#     value {
#       list {
#         shape {
#           dim {
#             size: 1
#           }
#           dim {
#             size: 32
#           }
#           dim {
#             size: 16
#           }
#           dim {
#             size: 16
#           }
#         }
#       }
#     }
#   }
# }
# node {
#   name: "SimpleCNN/MaxPool2d[pool2]/197"
#   op: "prim::Constant"
#   attr {
#     key: "attr"
#     value {
#       s: "{ value : 0}"
#     }
#   }
# }
# node {
#   name: "SimpleCNN/MaxPool2d[pool2]/198"
#   op: "prim::Constant"
#   attr {
#     key: "attr"
#     value {
#       s: "{ value : 1}"
#     }
#   }
# }
# node {
#   name: "SimpleCNN/MaxPool2d[pool2]/199"
#   op: "prim::Constant"
#   attr {
#     key: "attr"
#     value {
#       s: "{ value : 0}"
#     }
#   }
# }
# node {
#   name: "SimpleCNN/MaxPool2d[pool2]/200"
#   op: "prim::Constant"
#   attr {
#     key: "attr"
#     value {
#       s: "{ value : 2}"
#     }
#   }
# }
# node {
#   name: "SimpleCNN/MaxPool2d[pool2]/201"
#   op: "prim::ListConstruct"
#   input: "SimpleCNN/MaxPool2d[pool2]/200"
#   input: "SimpleCNN/MaxPool2d[pool2]/200"
#   attr {
#     key: "attr"
#     value {
#       s: "{}"
#     }
#   }
# }
# node {
#   name: "SimpleCNN/MaxPool2d[pool2]/202"
#   op: "prim::ListConstruct"
#   input: "SimpleCNN/MaxPool2d[pool2]/200"
#   input: "SimpleCNN/MaxPool2d[pool2]/200"
#   attr {
#     key: "attr"
#     value {
#       s: "{}"
#     }
#   }
# }
# node {
#   name: "SimpleCNN/MaxPool2d[pool2]/203"
#   op: "prim::ListConstruct"
#   input: "SimpleCNN/MaxPool2d[pool2]/199"
#   input: "SimpleCNN/MaxPool2d[pool2]/199"
#   attr {
#     key: "attr"
#     value {
#       s: "{}"
#     }
#   }
# }
# node {
#   name: "SimpleCNN/MaxPool2d[pool2]/204"
#   op: "prim::ListConstruct"
#   input: "SimpleCNN/MaxPool2d[pool2]/198"
#   input: "SimpleCNN/MaxPool2d[pool2]/198"
#   attr {
#     key: "attr"
#     value {
#       s: "{}"
#     }
#   }
# }
# node {
#   name: "SimpleCNN/MaxPool2d[pool2]/input.11"
#   op: "aten::max_pool2d"
#   input: "SimpleCNN/ReLU[relu2]/input.9"
#   input: "SimpleCNN/MaxPool2d[pool2]/201"
#   input: "SimpleCNN/MaxPool2d[pool2]/202"
#   input: "SimpleCNN/MaxPool2d[pool2]/203"
#   input: "SimpleCNN/MaxPool2d[pool2]/204"
#   input: "SimpleCNN/MaxPool2d[pool2]/197"
#   attr {
#     key: "attr"
#     value {
#       s: "{}"
#     }
#   }
#   attr {
#     key: "_output_shapes"
#     value {
#       list {
#         shape {
#           dim {
#             size: 1
#           }
#           dim {
#             size: 32
#           }
#           dim {
#             size: 8
#           }
#           dim {
#             size: 8
#           }
#         }
#       }
#     }
#   }
# }
# node {
#   name: "SimpleCNN/Flatten[flatten]/206"
#   op: "prim::Constant"
#   attr {
#     key: "attr"
#     value {
#       s: "{ value : -1}"
#     }
#   }
# }
# node {
#   name: "SimpleCNN/Flatten[flatten]/207"
#   op: "prim::Constant"
#   attr {
#     key: "attr"
#     value {
#       s: "{ value : 1}"
#     }
#   }
# }
# node {
#   name: "SimpleCNN/Flatten[flatten]/input.13"
#   op: "aten::flatten"
#   input: "SimpleCNN/MaxPool2d[pool2]/input.11"
#   input: "SimpleCNN/Flatten[flatten]/207"
#   input: "SimpleCNN/Flatten[flatten]/206"
#   attr {
#     key: "attr"
#     value {
#       s: "{}"
#     }
#   }
#   attr {
#     key: "_output_shapes"
#     value {
#       list {
#         shape {
#           dim {
#             size: 1
#           }
#           dim {
#             size: 2048
#           }
#         }
#       }
#     }
#   }
# }
# node {
#   name: "SimpleCNN/Linear[fc1]/bias/bias.9"
#   op: "prim::GetAttr"
#   input: "SimpleCNN/Linear[fc1]/weight/fc1"
#   attr {
#     key: "attr"
#     value {
#       s: "{ name :  bias }"
#     }
#   }
# }
# node {
#   name: "SimpleCNN/Linear[fc1]/weight/weight.9"
#   op: "prim::GetAttr"
#   input: "SimpleCNN/Linear[fc1]/weight/fc1"
#   attr {
#     key: "attr"
#     value {
#       s: "{ name :  weight }"
#     }
#   }
# }
# node {
#   name: "SimpleCNN/Linear[fc1]/input.15"
#   op: "aten::linear"
#   input: "SimpleCNN/Flatten[flatten]/input.13"
#   input: "SimpleCNN/Linear[fc1]/weight/weight.9"
#   input: "SimpleCNN/Linear[fc1]/bias/bias.9"
#   attr {
#     key: "attr"
#     value {
#       s: "{}"
#     }
#   }
#   attr {
#     key: "_output_shapes"
#     value {
#       list {
#         shape {
#           dim {
#             size: 1
#           }
#           dim {
#             size: 128
#           }
#         }
#       }
#     }
#   }
# }
# node {
#   name: "SimpleCNN/ReLU[relu3]/input"
#   op: "aten::relu"
#   input: "SimpleCNN/Linear[fc1]/input.15"
#   attr {
#     key: "attr"
#     value {
#       s: "{}"
#     }
#   }
#   attr {
#     key: "_output_shapes"
#     value {
#       list {
#         shape {
#           dim {
#             size: 1
#           }
#           dim {
#             size: 128
#           }
#         }
#       }
#     }
#   }
# }
# node {
#   name: "SimpleCNN/Linear[fc2]/bias/bias"
#   op: "prim::GetAttr"
#   input: "SimpleCNN/Linear[fc2]/weight/fc2"
#   attr {
#     key: "attr"
#     value {
#       s: "{ name :  bias }"
#     }
#   }
# }
# node {
#   name: "SimpleCNN/Linear[fc2]/weight/weight"
#   op: "prim::GetAttr"
#   input: "SimpleCNN/Linear[fc2]/weight/fc2"
#   attr {
#     key: "attr"
#     value {
#       s: "{ name :  weight }"
#     }
#   }
# }
# node {
#   name: "SimpleCNN/Linear[fc2]/215"
#   op: "aten::linear"
#   input: "SimpleCNN/ReLU[relu3]/input"
#   input: "SimpleCNN/Linear[fc2]/weight/weight"
#   input: "SimpleCNN/Linear[fc2]/bias/bias"
#   attr {
#     key: "attr"
#     value {
#       s: "{}"
#     }
#   }
#   attr {
#     key: "_output_shapes"
#     value {
#       list {
#         shape {
#           dim {
#             size: 1
#           }
#           dim {
#             size: 4
#           }
#         }
#       }
#     }
#   }
# }
# versions {
#   producer: 22
# }

# %%
data_dict = MessageToDict(model_graph)
cleaned_data_dict = clean_graphdef_attributes(data_dict) # This step fixes it

# %%
data_dict
# Out:
# {'node': [{'name': 'input/x',
#    'op': 'IO Node',
#    'attr': {'attr': {'s': ''},
#     '_output_shapes': {'list': {'shape': [{'dim': [{'size': '1'},
#          {'size': '3'},
#          {'size': '32'},
#          {'size': '32'}]}]}}}},
#   {'name': 'output/output.1',
#    'op': 'IO Node',
#    'input': ['SimpleCNN/Linear[fc2]/215'],
#    'attr': {'attr': {'s': ''},
#     '_output_shapes': {'list': {'shape': [{'dim': [{'size': '1'},
#          {'size': '4'}]}]}}}},
#   {'name': 'SimpleCNN/Conv2d[conv1]/164',
#    'op': 'prim::Constant',
#    'attr': {'attr': {'s': '{ value : 1}'}}},
#   {'name': 'SimpleCNN/Conv2d[conv1]/165',
#    'op': 'prim::Constant',
#    'attr': {'attr': {'s': '{ value : 0}'}}},
#   {'name': 'SimpleCNN/Conv2d[conv1]/166',
#    'op': 'prim::Constant',
#    'attr': {'attr': {'s': '{ value : 0}'}}},
#   {'name': 'SimpleCNN/Conv2d[conv1]/167',
#    'op': 'prim::Constant',
#    'attr': {'attr': {'s': '{ value : 1}'}}},
#   {'name': 'SimpleCNN/Conv2d[conv1]/bias/bias.5',
#    'op': 'prim::GetAttr',
#    'input': ['SimpleCNN/Conv2d[conv1]/weight/conv1'],
#    'attr': {'attr': {'s': '{ name :  bias }'}}},
#   {'name': 'SimpleCNN/Conv2d[conv1]/weight/weight.5',
#    'op': 'prim::GetAttr',
#    'input': ['SimpleCNN/Conv2d[conv1]/weight/conv1'],
#    'attr': {'attr': {'s': '{ name :  weight }'}}},
#   {'name': 'SimpleCNN/Conv2d[conv1]/170',
#    'op': 'prim::ListConstruct',
#    'input': ['SimpleCNN/Conv2d[conv1]/167', 'SimpleCNN/Conv2d[conv1]/167'],
#    'attr': {'attr': {'s': '{}'}}},
#   {'name': 'SimpleCNN/Conv2d[conv1]/171',
#    'op': 'prim::ListConstruct',
#    'input': ['SimpleCNN/Conv2d[conv1]/167', 'SimpleCNN/Conv2d[conv1]/167'],
#    'attr': {'attr': {'s': '{}'}}},
#   {'name': 'SimpleCNN/Conv2d[conv1]/172',
#    'op': 'prim::ListConstruct',
#    'input': ['SimpleCNN/Conv2d[conv1]/167', 'SimpleCNN/Conv2d[conv1]/167'],
#    'attr': {'attr': {'s': '{}'}}},
#   {'name': 'SimpleCNN/Conv2d[conv1]/173',
#    'op': 'prim::ListConstruct',
#    'input': ['SimpleCNN/Conv2d[conv1]/165', 'SimpleCNN/Conv2d[conv1]/165'],
#    'attr': {'attr': {'s': '{}'}}},
#   {'name': 'SimpleCNN/Conv2d[conv1]/input.1',
#    'op': 'aten::_convolution',
#    'input': ['input/x',
#     'SimpleCNN/Conv2d[conv1]/weight/weight.5',
#     'SimpleCNN/Conv2d[conv1]/bias/bias.5',
#     'SimpleCNN/Conv2d[conv1]/170',
#     'SimpleCNN/Conv2d[conv1]/171',
#     'SimpleCNN/Conv2d[conv1]/172',
#     'SimpleCNN/Conv2d[conv1]/166',
#     'SimpleCNN/Conv2d[conv1]/173',
#     'SimpleCNN/Conv2d[conv1]/167',
#     'SimpleCNN/Conv2d[conv1]/166',
#     'SimpleCNN/Conv2d[conv1]/166',
#     'SimpleCNN/Conv2d[conv1]/164',
#     'SimpleCNN/Conv2d[conv1]/164'],
#    'attr': {'attr': {'s': '{}'},
#     '_output_shapes': {'list': {'shape': [{'dim': [{'size': '1'},
#          {'size': '16'},
#          {'size': '32'},
#          {'size': '32'}]}]}}}},
#   {'name': 'SimpleCNN/ReLU[relu1]/input.3',
#    'op': 'aten::relu',
#    'input': ['SimpleCNN/Conv2d[conv1]/input.1'],
#    'attr': {'attr': {'s': '{}'},
#     '_output_shapes': {'list': {'shape': [{'dim': [{'size': '1'},
#          {'size': '16'},
#          {'size': '32'},
#          {'size': '32'}]}]}}}},
#   {'name': 'SimpleCNN/MaxPool2d[pool1]/176',
#    'op': 'prim::Constant',
#    'attr': {'attr': {'s': '{ value : 0}'}}},
#   {'name': 'SimpleCNN/MaxPool2d[pool1]/177',
#    'op': 'prim::Constant',
#    'attr': {'attr': {'s': '{ value : 1}'}}},
#   {'name': 'SimpleCNN/MaxPool2d[pool1]/178',
#    'op': 'prim::Constant',
#    'attr': {'attr': {'s': '{ value : 0}'}}},
#   {'name': 'SimpleCNN/MaxPool2d[pool1]/179',
#    'op': 'prim::Constant',
#    'attr': {'attr': {'s': '{ value : 2}'}}},
#   {'name': 'SimpleCNN/MaxPool2d[pool1]/180',
#    'op': 'prim::ListConstruct',
#    'input': ['SimpleCNN/MaxPool2d[pool1]/179',
#     'SimpleCNN/MaxPool2d[pool1]/179'],
#    'attr': {'attr': {'s': '{}'}}},
#   {'name': 'SimpleCNN/MaxPool2d[pool1]/181',
#    'op': 'prim::ListConstruct',
#    'input': ['SimpleCNN/MaxPool2d[pool1]/179',
#     'SimpleCNN/MaxPool2d[pool1]/179'],
#    'attr': {'attr': {'s': '{}'}}},
#   {'name': 'SimpleCNN/MaxPool2d[pool1]/182',
#    'op': 'prim::ListConstruct',
#    'input': ['SimpleCNN/MaxPool2d[pool1]/178',
#     'SimpleCNN/MaxPool2d[pool1]/178'],
#    'attr': {'attr': {'s': '{}'}}},
#   {'name': 'SimpleCNN/MaxPool2d[pool1]/183',
#    'op': 'prim::ListConstruct',
#    'input': ['SimpleCNN/MaxPool2d[pool1]/177',
#     'SimpleCNN/MaxPool2d[pool1]/177'],
#    'attr': {'attr': {'s': '{}'}}},
#   {'name': 'SimpleCNN/MaxPool2d[pool1]/input.5',
#    'op': 'aten::max_pool2d',
#    'input': ['SimpleCNN/ReLU[relu1]/input.3',
#     'SimpleCNN/MaxPool2d[pool1]/180',
#     'SimpleCNN/MaxPool2d[pool1]/181',
#     'SimpleCNN/MaxPool2d[pool1]/182',
#     'SimpleCNN/MaxPool2d[pool1]/183',
#     'SimpleCNN/MaxPool2d[pool1]/176'],
#    'attr': {'attr': {'s': '{}'},
#     '_output_shapes': {'list': {'shape': [{'dim': [{'size': '1'},
#          {'size': '16'},
#          {'size': '16'},
#          {'size': '16'}]}]}}}},
#   {'name': 'SimpleCNN/Conv2d[conv2]/185',
#    'op': 'prim::Constant',
#    'attr': {'attr': {'s': '{ value : 1}'}}},
#   {'name': 'SimpleCNN/Conv2d[conv2]/186',
#    'op': 'prim::Constant',
#    'attr': {'attr': {'s': '{ value : 0}'}}},
#   {'name': 'SimpleCNN/Conv2d[conv2]/187',
#    'op': 'prim::Constant',
#    'attr': {'attr': {'s': '{ value : 0}'}}},
#   {'name': 'SimpleCNN/Conv2d[conv2]/188',
#    'op': 'prim::Constant',
#    'attr': {'attr': {'s': '{ value : 1}'}}},
#   {'name': 'SimpleCNN/Conv2d[conv2]/bias/bias.7',
#    'op': 'prim::GetAttr',
#    'input': ['SimpleCNN/Conv2d[conv2]/weight/conv2'],
#    'attr': {'attr': {'s': '{ name :  bias }'}}},
#   {'name': 'SimpleCNN/Conv2d[conv2]/weight/weight.7',
#    'op': 'prim::GetAttr',
#    'input': ['SimpleCNN/Conv2d[conv2]/weight/conv2'],
#    'attr': {'attr': {'s': '{ name :  weight }'}}},
#   {'name': 'SimpleCNN/Conv2d[conv2]/191',
#    'op': 'prim::ListConstruct',
#    'input': ['SimpleCNN/Conv2d[conv2]/188', 'SimpleCNN/Conv2d[conv2]/188'],
#    'attr': {'attr': {'s': '{}'}}},
#   {'name': 'SimpleCNN/Conv2d[conv2]/192',
#    'op': 'prim::ListConstruct',
#    'input': ['SimpleCNN/Conv2d[conv2]/188', 'SimpleCNN/Conv2d[conv2]/188'],
#    'attr': {'attr': {'s': '{}'}}},
#   {'name': 'SimpleCNN/Conv2d[conv2]/193',
#    'op': 'prim::ListConstruct',
#    'input': ['SimpleCNN/Conv2d[conv2]/188', 'SimpleCNN/Conv2d[conv2]/188'],
#    'attr': {'attr': {'s': '{}'}}},
#   {'name': 'SimpleCNN/Conv2d[conv2]/194',
#    'op': 'prim::ListConstruct',
#    'input': ['SimpleCNN/Conv2d[conv2]/186', 'SimpleCNN/Conv2d[conv2]/186'],
#    'attr': {'attr': {'s': '{}'}}},
#   {'name': 'SimpleCNN/Conv2d[conv2]/input.7',
#    'op': 'aten::_convolution',
#    'input': ['SimpleCNN/MaxPool2d[pool1]/input.5',
#     'SimpleCNN/Conv2d[conv2]/weight/weight.7',
#     'SimpleCNN/Conv2d[conv2]/bias/bias.7',
#     'SimpleCNN/Conv2d[conv2]/191',
#     'SimpleCNN/Conv2d[conv2]/192',
#     'SimpleCNN/Conv2d[conv2]/193',
#     'SimpleCNN/Conv2d[conv2]/187',
#     'SimpleCNN/Conv2d[conv2]/194',
#     'SimpleCNN/Conv2d[conv2]/188',
#     'SimpleCNN/Conv2d[conv2]/187',
#     'SimpleCNN/Conv2d[conv2]/187',
#     'SimpleCNN/Conv2d[conv2]/185',
#     'SimpleCNN/Conv2d[conv2]/185'],
#    'attr': {'attr': {'s': '{}'},
#     '_output_shapes': {'list': {'shape': [{'dim': [{'size': '1'},
#          {'size': '32'},
#          {'size': '16'},
#          {'size': '16'}]}]}}}},
#   {'name': 'SimpleCNN/ReLU[relu2]/input.9',
#    'op': 'aten::relu',
#    'input': ['SimpleCNN/Conv2d[conv2]/input.7'],
#    'attr': {'attr': {'s': '{}'},
#     '_output_shapes': {'list': {'shape': [{'dim': [{'size': '1'},
#          {'size': '32'},
#          {'size': '16'},
#          {'size': '16'}]}]}}}},
#   {'name': 'SimpleCNN/MaxPool2d[pool2]/197',
#    'op': 'prim::Constant',
#    'attr': {'attr': {'s': '{ value : 0}'}}},
#   {'name': 'SimpleCNN/MaxPool2d[pool2]/198',
#    'op': 'prim::Constant',
#    'attr': {'attr': {'s': '{ value : 1}'}}},
#   {'name': 'SimpleCNN/MaxPool2d[pool2]/199',
#    'op': 'prim::Constant',
#    'attr': {'attr': {'s': '{ value : 0}'}}},
#   {'name': 'SimpleCNN/MaxPool2d[pool2]/200',
#    'op': 'prim::Constant',
#    'attr': {'attr': {'s': '{ value : 2}'}}},
#   {'name': 'SimpleCNN/MaxPool2d[pool2]/201',
#    'op': 'prim::ListConstruct',
#    'input': ['SimpleCNN/MaxPool2d[pool2]/200',
#     'SimpleCNN/MaxPool2d[pool2]/200'],
#    'attr': {'attr': {'s': '{}'}}},
#   {'name': 'SimpleCNN/MaxPool2d[pool2]/202',
#    'op': 'prim::ListConstruct',
#    'input': ['SimpleCNN/MaxPool2d[pool2]/200',
#     'SimpleCNN/MaxPool2d[pool2]/200'],
#    'attr': {'attr': {'s': '{}'}}},
#   {'name': 'SimpleCNN/MaxPool2d[pool2]/203',
#    'op': 'prim::ListConstruct',
#    'input': ['SimpleCNN/MaxPool2d[pool2]/199',
#     'SimpleCNN/MaxPool2d[pool2]/199'],
#    'attr': {'attr': {'s': '{}'}}},
#   {'name': 'SimpleCNN/MaxPool2d[pool2]/204',
#    'op': 'prim::ListConstruct',
#    'input': ['SimpleCNN/MaxPool2d[pool2]/198',
#     'SimpleCNN/MaxPool2d[pool2]/198'],
#    'attr': {'attr': {'s': '{}'}}},
#   {'name': 'SimpleCNN/MaxPool2d[pool2]/input.11',
#    'op': 'aten::max_pool2d',
#    'input': ['SimpleCNN/ReLU[relu2]/input.9',
#     'SimpleCNN/MaxPool2d[pool2]/201',
#     'SimpleCNN/MaxPool2d[pool2]/202',
#     'SimpleCNN/MaxPool2d[pool2]/203',
#     'SimpleCNN/MaxPool2d[pool2]/204',
#     'SimpleCNN/MaxPool2d[pool2]/197'],
#    'attr': {'attr': {'s': '{}'},
#     '_output_shapes': {'list': {'shape': [{'dim': [{'size': '1'},
#          {'size': '32'},
#          {'size': '8'},
#          {'size': '8'}]}]}}}},
#   {'name': 'SimpleCNN/Flatten[flatten]/206',
#    'op': 'prim::Constant',
#    'attr': {'attr': {'s': '{ value : -1}'}}},
#   {'name': 'SimpleCNN/Flatten[flatten]/207',
#    'op': 'prim::Constant',
#    'attr': {'attr': {'s': '{ value : 1}'}}},
#   {'name': 'SimpleCNN/Flatten[flatten]/input.13',
#    'op': 'aten::flatten',
#    'input': ['SimpleCNN/MaxPool2d[pool2]/input.11',
#     'SimpleCNN/Flatten[flatten]/207',
#     'SimpleCNN/Flatten[flatten]/206'],
#    'attr': {'attr': {'s': '{}'},
#     '_output_shapes': {'list': {'shape': [{'dim': [{'size': '1'},
#          {'size': '2048'}]}]}}}},
#   {'name': 'SimpleCNN/Linear[fc1]/bias/bias.9',
#    'op': 'prim::GetAttr',
#    'input': ['SimpleCNN/Linear[fc1]/weight/fc1'],
#    'attr': {'attr': {'s': '{ name :  bias }'}}},
#   {'name': 'SimpleCNN/Linear[fc1]/weight/weight.9',
#    'op': 'prim::GetAttr',
#    'input': ['SimpleCNN/Linear[fc1]/weight/fc1'],
#    'attr': {'attr': {'s': '{ name :  weight }'}}},
#   {'name': 'SimpleCNN/Linear[fc1]/input.15',
#    'op': 'aten::linear',
#    'input': ['SimpleCNN/Flatten[flatten]/input.13',
#     'SimpleCNN/Linear[fc1]/weight/weight.9',
#     'SimpleCNN/Linear[fc1]/bias/bias.9'],
#    'attr': {'attr': {'s': '{}'},
#     '_output_shapes': {'list': {'shape': [{'dim': [{'size': '1'},
#          {'size': '128'}]}]}}}},
#   {'name': 'SimpleCNN/ReLU[relu3]/input',
#    'op': 'aten::relu',
#    'input': ['SimpleCNN/Linear[fc1]/input.15'],
#    'attr': {'attr': {'s': '{}'},
#     '_output_shapes': {'list': {'shape': [{'dim': [{'size': '1'},
#          {'size': '128'}]}]}}}},
#   {'name': 'SimpleCNN/Linear[fc2]/bias/bias',
#    'op': 'prim::GetAttr',
#    'input': ['SimpleCNN/Linear[fc2]/weight/fc2'],
#    'attr': {'attr': {'s': '{ name :  bias }'}}},
#   {'name': 'SimpleCNN/Linear[fc2]/weight/weight',
#    'op': 'prim::GetAttr',
#    'input': ['SimpleCNN/Linear[fc2]/weight/fc2'],
#    'attr': {'attr': {'s': '{ name :  weight }'}}},
#   {'name': 'SimpleCNN/Linear[fc2]/215',
#    'op': 'aten::linear',
#    'input': ['SimpleCNN/ReLU[relu3]/input',
#     'SimpleCNN/Linear[fc2]/weight/weight',
#     'SimpleCNN/Linear[fc2]/bias/bias'],
#    'attr': {'attr': {'s': '{}'},
#     '_output_shapes': {'list': {'shape': [{'dim': [{'size': '1'},
#          {'size': '4'}]}]}}}}],
#  'versions': {'producer': 22}}

# %%
import json
with open("output.json", "w", encoding="utf-8") as f:
    json.dump(data_dict, f, ensure_ascii=False, indent=4)

# %%
import torchvision
vgg = torchvision.models.resnet18(weights='IMAGENET1K_V1')
vgg
# Out:
# ResNet(
#   (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer2): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(64, 128, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer3): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(128, 256, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer4): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#   (fc): Linear(in_features=512, out_features=1000, bias=True)
# )

# %%
dummy_input = torch.randn(1, 3, 224, 224)

writer = SummaryWriter("runs/vgg_test")
writer.add_graph(vgg, dummy_input)   
model_graph = graph(vgg,dummy_input,True)[0]
# Out:
# graph(%self.1 : __torch__.torchvision.models.resnet.___torch_mangle_265.ResNet,
#       %x.1 : Float(1, 3, 224, 224, strides=[150528, 50176, 224, 1], requires_grad=0, device=cpu)):
#   %fc : __torch__.torch.nn.modules.linear.___torch_mangle_264.Linear = prim::GetAttr[name="fc"](%self.1)
#   %avgpool : __torch__.torch.nn.modules.pooling.___torch_mangle_263.AdaptiveAvgPool2d = prim::GetAttr[name="avgpool"](%self.1)
#   %layer4 : __torch__.torch.nn.modules.container.___torch_mangle_262.Sequential = prim::GetAttr[name="layer4"](%self.1)
#   %layer3 : __torch__.torch.nn.modules.container.___torch_mangle_246.Sequential = prim::GetAttr[name="layer3"](%self.1)
#   %layer2 : __torch__.torch.nn.modules.container.___torch_mangle_230.Sequential = prim::GetAttr[name="layer2"](%self.1)
#   %layer1 : __torch__.torch.nn.modules.container.___torch_mangle_214.Sequential = prim::GetAttr[name="layer1"](%self.1)
#   %maxpool : __torch__.torch.nn.modules.pooling.___torch_mangle_201.MaxPool2d = prim::GetAttr[name="maxpool"](%self.1)
#   %relu.1 : __torch__.torch.nn.modules.activation.___torch_mangle_200.ReLU = prim::GetAttr[name="relu"](%self.1)
#   %bn1.1 : __torch__.torch.nn.modules.batchnorm.___torch_mangle_199.BatchNorm2d = prim::GetAttr[name="bn1"](%self.1)
#   %conv1.1 : __torch__.torch.nn.modules.conv.___torch_mangle_198.Conv2d = prim::GetAttr[name="conv1"](%self.1)
#   %1223 : bool = prim::Constant[value=1](), scope: __module.conv1 # /home/coder/Playground/.venv/lib/python3.10/site-packages/torch/nn/modules/conv.py:543:0
#   %1224 : int = prim::Constant[value=0](), scope: __module.conv1 # /home/coder/Playground/.venv/lib/python3.10/site-packages/torch/nn/modules/conv.py:543:0
#   %1225 : bool = prim::Constant[value=0](), scope: __module.conv1 # /home/coder/Playground/.venv/lib/python3.10/site-packages/torch/nn/modules/conv.py:543:0
#   %1226 : int = prim::Constant[value=1](), scope: __module.conv1 # /home/coder/Playground/.venv/lib/python3.10/site-packages/torch/nn/modules/conv.py:543:0
#   %1227 : int = prim::Constant[value=3](), scope: __module.conv1 # /home/coder/Playground/.venv/lib/python3.10/site-packages/torch/nn/modules/conv.py:543:0
#   %1228 : int = prim::Constant[value=2](), scope: __module.conv1 # /home/coder/Playground/.venv/lib/python3.10/site-packages/torch/nn/modules/conv.py:543:0
#   %1229 : NoneType = prim::Constant(), scope: __module.conv1
#   %weight.81 : Tensor = prim::GetAttr[name="weight"](%conv1.1)
#   %1231 : int[] = prim::ListConstruct(%1228, %1228), scope: __module.conv1
#   %1232 : int[] = prim::ListConstruct(%1227, %1227), scope: __module.conv1
#   %1233 : int[] = prim::ListConstruct(%1226, %1226), scope: __module.conv1
#   %1234 : int[] = prim::ListConstruct(%1224, %1224), scope: __module.conv1
#   %input.1 : Float(1, 64, 112, 112, strides=[802816, 12544, 112, 1], requires_grad=0, device=cpu) = aten::_convolution(%x.1, %weight.81, %1229, %1231, %1232, %1233, %1225, %1234, %1226, %1225, %1225, %1223, %1223), scope: __module.conv1 # /home/coder/Playground/.venv/lib/python3.10/site-packages/torch/nn/modules/conv.py:543:0
#   %1236 : bool = prim::Constant[value=1](), scope: __module.bn1 # /home/coder/Playground/.venv/lib/python3.10/site-packages/torch/nn/functional.py:2813:0
#   %1237 : float = prim::Constant[value=1.0000000000000001e-05](), scope: __module.bn1 # /home/coder/Playground/.venv/lib/python3.10/site-packages/torch/nn/functional.py:2813:0
#   %1238 : float = prim::Constant[value=0.10000000000000001](), scope: __module.bn1 # /home/coder/Playground/.venv/lib/python3.10/site-packages/torch/nn/functional.py:2813:0
#   %1239 : bool = prim::Constant[value=0](), scope: __module.bn1 # /home/coder/Playground/.venv/lib/python3.10/site-packages/torch/nn/functional.py:2813:0
#   %running_var.41 : Tensor = prim::GetAttr[name="running_var"](%bn1.1)
#   %running_mean.41 : Tensor = prim::GetAttr[name="running_mean"](%bn1.1)
#   %bias.41 : Tensor = prim::GetAttr[name="bias"](%bn1.1)
#   %weight.83 : Tensor = prim::GetAttr[name="weight"](%bn1.1)
#   %input.3 : Float(1, 64, 112, 112, strides=[802816, 12544, 112, 1], requires_grad=1, device=cpu) = aten::batch_norm(%input.1, %weight.83, %bias.41, %running_mean.41, %running_var.41, %1239, %1238, %1237, %1236), scope: __module.bn1 # /home/coder/Playground/.venv/lib/python3.10/site-packages/torch/nn/functional.py:2813:0
#   %input.5 : Float(1, 64, 112, 112, strides=[802816, 12544, 112, 1], requires_grad=1, device=cpu) = aten::relu_(%input.3), scope: __module.relu # /home/coder/Playground/.venv/lib/python3.10/site-packages/torch/nn/functional.py:1695:0
#   %1246 : bool = prim::Constant[value=0](), scope: __module.maxpool # /home/coder/Playground/.venv/lib/python3.10/site-packages/torch/nn/functional.py:823:0
#   %1247 : int = prim::Constant[value=1](), scope: __module.maxpool # /home/coder/Playground/.venv/lib/python3.10/site-packages/torch/nn/functional.py:823:0
#   %1248 : int = prim::Constant[value=2](), scope: __module.maxpool # /home/coder/Playground/.venv/lib/python3.10/site-packages/torch/nn/functional.py:823:0
#   %1249 : int = prim::Constant[value=3](), scope: __module.maxpool # /home/coder/Playground/.venv/lib/python3.10/site-packages/torch/nn/functional.py:823:0
#   %1250 : int[] = prim::ListConstruct(%1249, %1249), scope: __module.maxpool
#   %1251 : int[] = prim::ListConstruct(%1248, %1248), scope: __module.maxpool
#   %1252 : int[] = prim::ListConstruct(%1247, %1247), scope: __module.maxpool
#   %1253 : int[] = prim::ListConstruct(%1247, %1247), scope: __module.maxpool
#   %input.7 : Float(1, 64, 56, 56, strides=[200704, 3136, 56, 1], requires_grad=1, device=cpu) = aten::max_pool2d(%input.5, %1250, %1251, %1252, %1253, %1246), scope: __module.maxpool # /home/coder/Playground/.venv/lib/python3.10/site-packages/torch/nn/functional.py:823:0
#   %1255 : bool = prim::Constant[value=1](), scope: __module.layer1/__module.layer1.0/__module.layer1.0.conv1 # /home/coder/Playground/.venv/lib/python3.10/site-packages/torch/nn/modules/conv.py:543:0
#   %1256 : int = prim::Constant[value=0](), scope: __module.layer1/__module.layer1.0/__module.layer1.0.conv1 # /home/coder/Playground/.venv/lib/python3.10/site-packages/torch/nn/modules/conv.py:543:0
#   %1257 : bool = prim::Constant[value=0](), scope: __module.layer1/__module.layer1.0/__module.layer1.0.conv1 # /home/coder/Playground/.venv/lib/python3.10/site-packages/torch/nn/modules/conv.py:543:0
#   %1258 : int = prim::Constant[value=1](), scope: __module.layer1/__module.layer1.0/__module.layer1.0.conv1 # /home/coder/Playground/.venv/lib/python3.10/site-packages/torch/nn/modules/conv.py:543:0
#   %1259 : NoneType = prim::Constant(), scope: __module.layer1/__module.layer1.0/__module.layer1.0.conv1
#   %1260 : float = prim::Constant[value=1.0000000000000001e-05](), scope: __module.layer1/__module.layer1.0/__module.layer1.0.bn1 # /home/coder/Playground/.venv/lib/python3.10/site-packages/torch/nn/functional.py:2813:0
#   %1261 : float = prim::Constant[value=0.10000000000000001](), scope: __module.layer1/__module.layer1.0/__module.layer1.0.bn1 # /home/coder/Playground/.venv/lib/python3.10/site-packages/torch/nn/functional.py:2813:0
#   %_1.1 : __torch__.torchvision.models.resnet.___torch_mangle_213.BasicBlock = prim::GetAttr[name="1"](%layer1)
#   %_0.1 : __torch__.torchvision.models.resnet.___torch_mangle_207.BasicBlock = prim::GetAttr[name="0"](%layer1)
#   %bn2.1 : __torch__.torch.nn.modules.batchnorm.___torch_mangle_206.BatchNorm2d = prim::GetAttr[name="bn2"](%_0.1)
#   %conv2.1 : __torch__.torch.nn.modules.conv.___torch_mangle_205.Conv2d = prim::GetAttr[name="conv2"](%_0.1)
#   %relu.3 : __torch__.torch.nn.modules.activation.___torch_mangle_204.ReLU = prim::GetAttr[name="relu"](%_0.1)
#   %bn1.3 : __torch__.torch.nn.modules.batchnorm.___torch_mangle_203.BatchNorm2d = prim::GetAttr[name="bn1"](%_0.1)
#   %conv1.3 : __torch__.torch.nn.modules.conv.___torch_mangle_202.Conv2d = prim::GetAttr[name="conv1"](%_0.1)
#   %weight.85 : Tensor = prim::GetAttr[name="weight"](%conv1.3)
#   %1270 : int[] = prim::ListConstruct(%1258, %1258), scope: __module.layer1/__module.layer1.0/__module.layer1.0.conv1
#   %1271 : int[] = prim::ListConstruct(%1258, %1258), scope: __module.layer1/__module.layer1.0/__module.layer1.0.conv1
#   %1272 : int[] = prim::ListConstruct(%1258, %1258), scope: __module.layer1/__module.layer1.0/__module.layer1.0.conv1
#   %1273 : int[] = prim::ListConstruct(%1256, %1256), scope: __module.layer1/__module.layer1.0/__module.layer1.0.conv1
#   %input.9 : Float(1, 64, 56, 56, strides=[200704, 3136, 56, 1], requires_grad=0, device=cpu) = aten::_convolution(%input.7, %weight.85, %1259, %1270, %1271, %1272, %1257, %1273, %1258, %1257, %1257, %1255, %1255), scope: __module.layer1/__module.layer1.0/__module.layer1.0.conv1 # /home/coder/Playground/.venv/lib/python3.10/site-packages/torch/nn/modules/conv.py:543:0
#   %running_var.43 : Tensor = prim::GetAttr[name="running_var"](%bn1.3)
#   %running_mean.43 : Tensor = prim::GetAttr[name="running_mean"](%bn1.3)
#   %bias.43 : Tensor = prim::GetAttr[name="bias"](%bn1.3)
#   %weight.87 : Tensor = prim::GetAttr[name="weight"](%bn1.3)
#   %input.11 : Float(1, 64, 56, 56, strides=[200704, 3136, 56, 1], requires_grad=1, device=cpu) = aten::batch_norm(%input.9, %weight.87, %bias.43, %running_mean.43, %running_var.43, %1257, %1261, %1260, %1255), scope: __module.layer1/__module.layer1.0/__module.layer1.0.bn1 # /home/coder/Playground/.venv/lib/python3.10/site-packages/torch/nn/functional.py:2813:0
#   %input.13 : Float(1, 64, 56, 56, strides=[200704, 3136, 56, 1], requires_grad=1, device=cpu) = aten::relu_(%input.11), scope: __module.layer1/__module.layer1.0/__module.layer1.0.relu # /home/coder/Playground/.venv/lib/python3.10/site-packages/torch/nn/functional.py:1695:0
#   %weight.89 : Tensor = prim::GetAttr[name="weight"](%conv2.1)
#   %1282 : int[] = prim::ListConstruct(%1258, %1258), scope: __module.layer1/__module.layer1.0/__module.layer1.0.conv2
#   %1283 : int[] = prim::ListConstruct(%1258, %1258), scope: __module.layer1/__module.layer1.0/__module.layer1.0.conv2
#   %1284 : int[] = prim::ListConstruct(%1258, %1258), scope: __module.layer1/__module.layer1.0/__module.layer1.0.conv2
#   %1285 : int[] = prim::ListConstruct(%1256, %1256), scope: __module.layer1/__module.layer1.0/__module.layer1.0.conv2
#   %input.15 : Float(1, 64, 56, 56, strides=[200704, 3136, 56, 1], requires_grad=0, device=cpu) = aten::_convolution(%input.13, %weight.89, %1259, %1282, %1283, %1284, %1257, %1285, %1258, %1257, %1257, %1255, %1255), scope: __module.layer1/__module.layer1.0/__module.layer1.0.conv2 # /home/coder/Playground/.venv/lib/python3.10/site-packages/torch/nn/modules/conv.py:543:0
#   %running_var.45 : Tensor = prim::GetAttr[name="running_var"](%bn2.1)
#   %running_mean.45 : Tensor = prim::GetAttr[name="running_mean"](%bn2.1)
#   %bias.45 : Tensor = prim::GetAttr[name="bias"](%bn2.1)
#   %weight.91 : Tensor = prim::GetAttr[name="weight"](%bn2.1)
#   %out.1 : Float(1, 64, 56, 56, strides=[200704, 3136, 56, 1], requires_grad=1, device=cpu) = aten::batch_norm(%input.15, %weight.91, %bias.45, %running_mean.45, %running_var.45, %1257, %1261, %1260, %1255), scope: __module.layer1/__module.layer1.0/__module.layer1.0.bn2 # /home/coder/Playground/.venv/lib/python3.10/site-packages/torch/nn/functional.py:2813:0
#   %input.17 : Float(1, 64, 56, 56, strides=[200704, 3136, 56, 1], requires_grad=1, device=cpu) = aten::add_(%out.1, %input.7, %1258), scope: __module.layer1/__module.layer1.0 # /home/coder/Playground/.venv/lib/python3.10/site-packages/torchvision/models/resnet.py:102:0
#   %input.19 : Float(1, 64, 56, 56, strides=[200704, 3136, 56, 1], requires_grad=1, device=cpu) = aten::relu_(%input.17), scope: __module.layer1/__module.layer1.0/__module.layer1.0.relu # /home/coder/Playground/.venv/lib/python3.10/site-packages/torch/nn/functional.py:1695:0
#   %bn2.3 : __torch__.torch.nn.modules.batchnorm.___torch_mangle_212.BatchNorm2d = prim::GetAttr[name="bn2"](%_1.1)
#   %conv2.3 : __torch__.torch.nn.modules.conv.___torch_mangle_211.Conv2d = prim::GetAttr[name="conv2"](%_1.1)
#   %relu.5 : __torch__.torch.nn.modules.activation.___torch_mangle_210.ReLU = prim::GetAttr[name="relu"](%_1.1)
#   %bn1.5 : __torch__.torch.nn.modules.batchnorm.___torch_mangle_209.BatchNorm2d = prim::GetAttr[name="bn1"](%_1.1)
#   %conv1.5 : __torch__.torch.nn.modules.conv.___torch_mangle_208.Conv2d = prim::GetAttr[name="conv1"](%_1.1)
#   %weight.93 : Tensor = prim::GetAttr[name="weight"](%conv1.5)
#   %1300 : int[] = prim::ListConstruct(%1258, %1258), scope: __module.layer1/__module.layer1.1/__module.layer1.1.conv1
#   %1301 : int[] = prim::ListConstruct(%1258, %1258), scope: __module.layer1/__module.layer1.1/__module.layer1.1.conv1
#   %1302 : int[] = prim::ListConstruct(%1258, %1258), scope: __module.layer1/__module.layer1.1/__module.layer1.1.conv1
#   %1303 : int[] = prim::ListConstruct(%1256, %1256), scope: __module.layer1/__module.layer1.1/__module.layer1.1.conv1
#   %input.21 : Float(1, 64, 56, 56, strides=[200704, 3136, 56, 1], requires_grad=0, device=cpu) = aten::_convolution(%input.19, %weight.93, %1259, %1300, %1301, %1302, %1257, %1303, %1258, %1257, %1257, %1255, %1255), scope: __module.layer1/__module.layer1.1/__module.layer1.1.conv1 # /home/coder/Playground/.venv/lib/python3.10/site-packages/torch/nn/modules/conv.py:543:0
#   %running_var.47 : Tensor = prim::GetAttr[name="running_var"](%bn1.5)
#   %running_mean.47 : Tensor = prim::GetAttr[name="running_mean"](%bn1.5)
#   %bias.47 : Tensor = prim::GetAttr[name="bias"](%bn1.5)
#   %weight.95 : Tensor = prim::GetAttr[name="weight"](%bn1.5)
#   %input.23 : Float(1, 64, 56, 56, strides=[200704, 3136, 56, 1], requires_grad=1, device=cpu) = aten::batch_norm(%input.21, %weight.95, %bias.47, %running_mean.47, %running_var.47, %1257, %1261, %1260, %1255), scope: __module.layer1/__module.layer1.1/__module.layer1.1.bn1 # /home/coder/Playground/.venv/lib/python3.10/site-packages/torch/nn/functional.py:2813:0
#   %input.25 : Float(1, 64, 56, 56, strides=[200704, 3136, 56, 1], requires_grad=1, device=cpu) = aten::relu_(%input.23), scope: __module.layer1/__module.layer1.1/__module.layer1.1.relu # /home/coder/Playground/.venv/lib/python3.10/site-packages/torch/nn/functional.py:1695:0
#   %weight.97 : Tensor = prim::GetAttr[name="weight"](%conv2.3)
#   %1312 : int[] = prim::ListConstruct(%1258, %1258), scope: __module.layer1/__module.layer1.1/__module.layer1.1.conv2
#   %1313 : int[] = prim::ListConstruct(%1258, %1258), scope: __module.layer1/__module.layer1.1/__module.layer1.1.conv2
#   %1314 : int[] = prim::ListConstruct(%1258, %1258), scope: __module.layer1/__module.layer1.1/__module.layer1.1.conv2
#   %1315 : int[] = prim::ListConstruct(%1256, %1256), scope: __module.layer1/__module.layer1.1/__module.layer1.1.conv2
#   %input.27 : Float(1, 64, 56, 56, strides=[200704, 3136, 56, 1], requires_grad=0, device=cpu) = aten::_convolution(%input.25, %weight.97, %1259, %1312, %1313, %1314, %1257, %1315, %1258, %1257, %1257, %1255, %1255), scope: __module.layer1/__module.layer1.1/__module.layer1.1.conv2 # /home/coder/Playground/.venv/lib/python3.10/site-packages/torch/nn/modules/conv.py:543:0
#   %running_var.49 : Tensor = prim::GetAttr[name="running_var"](%bn2.3)
#   %running_mean.49 : Tensor = prim::GetAttr[name="running_mean"](%bn2.3)
#   %bias.49 : Tensor = prim::GetAttr[name="bias"](%bn2.3)
#   %weight.99 : Tensor = prim::GetAttr[name="weight"](%bn2.3)
#   %out.3 : Float(1, 64, 56, 56, strides=[200704, 3136, 56, 1], requires_grad=1, device=cpu) = aten::batch_norm(%input.27, %weight.99, %bias.49, %running_mean.49, %running_var.49, %1257, %1261, %1260, %1255), scope: __module.layer1/__module.layer1.1/__module.layer1.1.bn2 # /home/coder/Playground/.venv/lib/python3.10/site-packages/torch/nn/functional.py:2813:0
#   %input.29 : Float(1, 64, 56, 56, strides=[200704, 3136, 56, 1], requires_grad=1, device=cpu) = aten::add_(%out.3, %input.19, %1258), scope: __module.layer1/__module.layer1.1 # /home/coder/Playground/.venv/lib/python3.10/site-packages/torchvision/models/resnet.py:102:0
#   %input.31 : Float(1, 64, 56, 56, strides=[200704, 3136, 56, 1], requires_grad=1, device=cpu) = aten::relu_(%input.29), scope: __module.layer1/__module.layer1.1/__module.layer1.1.relu # /home/coder/Playground/.venv/lib/python3.10/site-packages/torch/nn/functional.py:1695:0
#   %1324 : bool = prim::Constant[value=1](), scope: __module.layer2/__module.layer2.0/__module.layer2.0.conv1 # /home/coder/Playground/.venv/lib/python3.10/site-packages/torch/nn/modules/conv.py:543:0
#   %1325 : int = prim::Constant[value=0](), scope: __module.layer2/__module.layer2.0/__module.layer2.0.conv1 # /home/coder/Playground/.venv/lib/python3.10/site-packages/torch/nn/modules/conv.py:543:0
#   %1326 : bool = prim::Constant[value=0](), scope: __module.layer2/__module.layer2.0/__module.layer2.0.conv1 # /home/coder/Playground/.venv/lib/python3.10/site-packages/torch/nn/modules/conv.py:543:0
#   %1327 : int = prim::Constant[value=1](), scope: __module.layer2/__module.layer2.0/__module.layer2.0.conv1 # /home/coder/Playground/.venv/lib/python3.10/site-packages/torch/nn/modules/conv.py:543:0
#   %1328 : int = prim::Constant[value=2](), scope: __module.layer2/__module.layer2.0/__module.layer2.0.conv1 # /home/coder/Playground/.venv/lib/python3.10/site-packages/torch/nn/modules/conv.py:543:0
#   %1329 : NoneType = prim::Constant(), scope: __module.layer2/__module.layer2.0/__module.layer2.0.conv1
#   %1330 : float = prim::Constant[value=1.0000000000000001e-05](), scope: __module.layer2/__module.layer2.0/__module.layer2.0.bn1 # /home/coder/Playground/.venv/lib/python3.10/site-packages/torch/nn/functional.py:2813:0
#   %1331 : float = prim::Constant[value=0.10000000000000001](), scope: __module.layer2/__module.layer2.0/__module.layer2.0.bn1 # /home/coder/Playground/.venv/lib/python3.10/site-packages/torch/nn/functional.py:2813:0
#   %_1.5 : __torch__.torchvision.models.resnet.___torch_mangle_229.BasicBlock = prim::GetAttr[name="1"](%layer2)
#   %_0.5 : __torch__.torchvision.models.resnet.___torch_mangle_223.BasicBlock = prim::GetAttr[name="0"](%layer2)
#   %downsample.1 : __torch__.torch.nn.modules.container.___torch_mangle_222.Sequential = prim::GetAttr[name="downsample"](%_0.5)
#   %bn2.5 : __torch__.torch.nn.modules.batchnorm.___torch_mangle_219.BatchNorm2d = prim::GetAttr[name="bn2"](%_0.5)
#   %conv2.5 : __torch__.torch.nn.modules.conv.___torch_mangle_218.Conv2d = prim::GetAttr[name="conv2"](%_0.5)
#   %relu.7 : __torch__.torch.nn.modules.activation.___torch_mangle_217.ReLU = prim::GetAttr[name="relu"](%_0.5)
#   %bn1.7 : __torch__.torch.nn.modules.batchnorm.___torch_mangle_216.BatchNorm2d = prim::GetAttr[name="bn1"](%_0.5)
#   %conv1.7 : __torch__.torch.nn.modules.conv.___torch_mangle_215.Conv2d = prim::GetAttr[name="conv1"](%_0.5)
#   %weight.101 : Tensor = prim::GetAttr[name="weight"](%conv1.7)
#   %1341 : int[] = prim::ListConstruct(%1328, %1328), scope: __module.layer2/__module.layer2.0/__module.layer2.0.conv1
#   %1342 : int[] = prim::ListConstruct(%1327, %1327), scope: __module.layer2/__module.layer2.0/__module.layer2.0.conv1
#   %1343 : int[] = prim::ListConstruct(%1327, %1327), scope: __module.layer2/__module.layer2.0/__module.layer2.0.conv1
#   %1344 : int[] = prim::ListConstruct(%1325, %1325), scope: __module.layer2/__module.layer2.0/__module.layer2.0.conv1
#   %input.33 : Float(1, 128, 28, 28, strides=[100352, 784, 28, 1], requires_grad=0, device=cpu) = aten::_convolution(%input.31, %weight.101, %1329, %1341, %1342, %1343, %1326, %1344, %1327, %1326, %1326, %1324, %1324), scope: __module.layer2/__module.layer2.0/__module.layer2.0.conv1 # /home/coder/Playground/.venv/lib/python3.10/site-packages/torch/nn/modules/conv.py:543:0
#   %running_var.51 : Tensor = prim::GetAttr[name="running_var"](%bn1.7)
#   %running_mean.51 : Tensor = prim::GetAttr[name="running_mean"](%bn1.7)
#   %bias.51 : Tensor = prim::GetAttr[name="bias"](%bn1.7)
#   %weight.103 : Tensor = prim::GetAttr[name="weight"](%bn1.7)
#   %input.35 : Float(1, 128, 28, 28, strides=[100352, 784, 28, 1], requires_grad=1, device=cpu) = aten::batch_norm(%input.33, %weight.103, %bias.51, %running_mean.51, %running_var.51, %1326, %1331, %1330, %1324), scope: __module.layer2/__module.layer2.0/__module.layer2.0.bn1 # /home/coder/Playground/.venv/lib/python3.10/site-packages/torch/nn/functional.py:2813:0
#   %input.37 : Float(1, 128, 28, 28, strides=[100352, 784, 28, 1], requires_grad=1, device=cpu) = aten::relu_(%input.35), scope: __module.layer2/__module.layer2.0/__module.layer2.0.relu # /home/coder/Playground/.venv/lib/python3.10/site-packages/torch/nn/functional.py:1695:0
#   %weight.105 : Tensor = prim::GetAttr[name="weight"](%conv2.5)
#   %1353 : int[] = prim::ListConstruct(%1327, %1327), scope: __module.layer2/__module.layer2.0/__module.layer2.0.conv2
#   %1354 : int[] = prim::ListConstruct(%1327, %1327), scope: __module.layer2/__module.layer2.0/__module.layer2.0.conv2
#   %1355 : int[] = prim::ListConstruct(%1327, %1327), scope: __module.layer2/__module.layer2.0/__module.layer2.0.conv2
#   %1356 : int[] = prim::ListConstruct(%1325, %1325), scope: __module.layer2/__module.layer2.0/__module.layer2.0.conv2
#   %input.39 : Float(1, 128, 28, 28, strides=[100352, 784, 28, 1], requires_grad=0, device=cpu) = aten::_convolution(%input.37, %weight.105, %1329, %1353, %1354, %1355, %1326, %1356, %1327, %1326, %1326, %1324, %1324), scope: __module.layer2/__module.layer2.0/__module.layer2.0.conv2 # /home/coder/Playground/.venv/lib/python3.10/site-packages/torch/nn/modules/conv.py:543:0
#   %running_var.53 : Tensor = prim::GetAttr[name="running_var"](%bn2.5)
#   %running_mean.53 : Tensor = prim::GetAttr[name="running_mean"](%bn2.5)
#   %bias.53 : Tensor = prim::GetAttr[name="bias"](%bn2.5)
#   %weight.107 : Tensor = prim::GetAttr[name="weight"](%bn2.5)
#   %out.5 : Float(1, 128, 28, 28, strides=[100352, 784, 28, 1], requires_grad=1, device=cpu) = aten::batch_norm(%input.39, %weight.107, %bias.53, %running_mean.53, %running_var.53, %1326, %1331, %1330, %1324), scope: __module.layer2/__module.layer2.0/__module.layer2.0.bn2 # /home/coder/Playground/.venv/lib/python3.10/site-packages/torch/nn/functional.py:2813:0
#   %_1.3 : __torch__.torch.nn.modules.batchnorm.___torch_mangle_221.BatchNorm2d = prim::GetAttr[name="1"](%downsample.1)
#   %_0.3 : __torch__.torch.nn.modules.conv.___torch_mangle_220.Conv2d = prim::GetAttr[name="0"](%downsample.1)
#   %weight.109 : Tensor = prim::GetAttr[name="weight"](%_0.3)
#   %1366 : int[] = prim::ListConstruct(%1328, %1328), scope: __module.layer2/__module.layer2.0/__module.layer2.0.downsample/__module.layer2.0.downsample.0
#   %1367 : int[] = prim::ListConstruct(%1325, %1325), scope: __module.layer2/__module.layer2.0/__module.layer2.0.downsample/__module.layer2.0.downsample.0
#   %1368 : int[] = prim::ListConstruct(%1327, %1327), scope: __module.layer2/__module.layer2.0/__module.layer2.0.downsample/__module.layer2.0.downsample.0
#   %1369 : int[] = prim::ListConstruct(%1325, %1325), scope: __module.layer2/__module.layer2.0/__module.layer2.0.downsample/__module.layer2.0.downsample.0
#   %input.41 : Float(1, 128, 28, 28, strides=[100352, 784, 28, 1], requires_grad=0, device=cpu) = aten::_convolution(%input.31, %weight.109, %1329, %1366, %1367, %1368, %1326, %1369, %1327, %1326, %1326, %1324, %1324), scope: __module.layer2/__module.layer2.0/__module.layer2.0.downsample/__module.layer2.0.downsample.0 # /home/coder/Playground/.venv/lib/python3.10/site-packages/torch/nn/modules/conv.py:543:0
#   %running_var.55 : Tensor = prim::GetAttr[name="running_var"](%_1.3)
#   %running_mean.55 : Tensor = prim::GetAttr[name="running_mean"](%_1.3)
#   %bias.55 : Tensor = prim::GetAttr[name="bias"](%_1.3)
#   %weight.111 : Tensor = prim::GetAttr[name="weight"](%_1.3)
#   %identity.1 : Float(1, 128, 28, 28, strides=[100352, 784, 28, 1], requires_grad=1, device=cpu) = aten::batch_norm(%input.41, %weight.111, %bias.55, %running_mean.55, %running_var.55, %1326, %1331, %1330, %1324), scope: __module.layer2/__module.layer2.0/__module.layer2.0.downsample/__module.layer2.0.downsample.1 # /home/coder/Playground/.venv/lib/python3.10/site-packages/torch/nn/functional.py:2813:0
#   %input.43 : Float(1, 128, 28, 28, strides=[100352, 784, 28, 1], requires_grad=1, device=cpu) = aten::add_(%out.5, %identity.1, %1327), scope: __module.layer2/__module.layer2.0 # /home/coder/Playground/.venv/lib/python3.10/site-packages/torchvision/models/resnet.py:102:0
#   %input.45 : Float(1, 128, 28, 28, strides=[100352, 784, 28, 1], requires_grad=1, device=cpu) = aten::relu_(%input.43), scope: __module.layer2/__module.layer2.0/__module.layer2.0.relu # /home/coder/Playground/.venv/lib/python3.10/site-packages/torch/nn/functional.py:1695:0
#   %bn2.7 : __torch__.torch.nn.modules.batchnorm.___torch_mangle_228.BatchNorm2d = prim::GetAttr[name="bn2"](%_1.5)
#   %conv2.7 : __torch__.torch.nn.modules.conv.___torch_mangle_227.Conv2d = prim::GetAttr[name="conv2"](%_1.5)
#   %relu.9 : __torch__.torch.nn.modules.activation.___torch_mangle_226.ReLU = prim::GetAttr[name="relu"](%_1.5)
#   %bn1.9 : __torch__.torch.nn.modules.batchnorm.___torch_mangle_225.BatchNorm2d = prim::GetAttr[name="bn1"](%_1.5)
#   %conv1.9 : __torch__.torch.nn.modules.conv.___torch_mangle_224.Conv2d = prim::GetAttr[name="conv1"](%_1.5)
#   %weight.113 : Tensor = prim::GetAttr[name="weight"](%conv1.9)
#   %1384 : int[] = prim::ListConstruct(%1327, %1327), scope: __module.layer2/__module.layer2.1/__module.layer2.1.conv1
#   %1385 : int[] = prim::ListConstruct(%1327, %1327), scope: __module.layer2/__module.layer2.1/__module.layer2.1.conv1
#   %1386 : int[] = prim::ListConstruct(%1327, %1327), scope: __module.layer2/__module.layer2.1/__module.layer2.1.conv1
#   %1387 : int[] = prim::ListConstruct(%1325, %1325), scope: __module.layer2/__module.layer2.1/__module.layer2.1.conv1
#   %input.47 : Float(1, 128, 28, 28, strides=[100352, 784, 28, 1], requires_grad=0, device=cpu) = aten::_convolution(%input.45, %weight.113, %1329, %1384, %1385, %1386, %1326, %1387, %1327, %1326, %1326, %1324, %1324), scope: __module.layer2/__module.layer2.1/__module.layer2.1.conv1 # /home/coder/Playground/.venv/lib/python3.10/site-packages/torch/nn/modules/conv.py:543:0
#   %running_var.57 : Tensor = prim::GetAttr[name="running_var"](%bn1.9)
#   %running_mean.57 : Tensor = prim::GetAttr[name="running_mean"](%bn1.9)
#   %bias.57 : Tensor = prim::GetAttr[name="bias"](%bn1.9)
#   %weight.115 : Tensor = prim::GetAttr[name="weight"](%bn1.9)
#   %input.49 : Float(1, 128, 28, 28, strides=[100352, 784, 28, 1], requires_grad=1, device=cpu) = aten::batch_norm(%input.47, %weight.115, %bias.57, %running_mean.57, %running_var.57, %1326, %1331, %1330, %1324), scope: __module.layer2/__module.layer2.1/__module.layer2.1.bn1 # /home/coder/Playground/.venv/lib/python3.10/site-packages/torch/nn/functional.py:2813:0
#   %input.51 : Float(1, 128, 28, 28, strides=[100352, 784, 28, 1], requires_grad=1, device=cpu) = aten::relu_(%input.49), scope: __module.layer2/__module.layer2.1/__module.layer2.1.relu # /home/coder/Playground/.venv/lib/python3.10/site-packages/torch/nn/functional.py:1695:0
#   %weight.117 : Tensor = prim::GetAttr[name="weight"](%conv2.7)
#   %1396 : int[] = prim::ListConstruct(%1327, %1327), scope: __module.layer2/__module.layer2.1/__module.layer2.1.conv2
#   %1397 : int[] = prim::ListConstruct(%1327, %1327), scope: __module.layer2/__module.layer2.1/__module.layer2.1.conv2
#   %1398 : int[] = prim::ListConstruct(%1327, %1327), scope: __module.layer2/__module.layer2.1/__module.layer2.1.conv2
#   %1399 : int[] = prim::ListConstruct(%1325, %1325), scope: __module.layer2/__module.layer2.1/__module.layer2.1.conv2
#   %input.53 : Float(1, 128, 28, 28, strides=[100352, 784, 28, 1], requires_grad=0, device=cpu) = aten::_convolution(%input.51, %weight.117, %1329, %1396, %1397, %1398, %1326, %1399, %1327, %1326, %1326, %1324, %1324), scope: __module.layer2/__module.layer2.1/__module.layer2.1.conv2 # /home/coder/Playground/.venv/lib/python3.10/site-packages/torch/nn/modules/conv.py:543:0
#   %running_var.59 : Tensor = prim::GetAttr[name="running_var"](%bn2.7)
#   %running_mean.59 : Tensor = prim::GetAttr[name="running_mean"](%bn2.7)
#   %bias.59 : Tensor = prim::GetAttr[name="bias"](%bn2.7)
#   %weight.119 : Tensor = prim::GetAttr[name="weight"](%bn2.7)
#   %out.7 : Float(1, 128, 28, 28, strides=[100352, 784, 28, 1], requires_grad=1, device=cpu) = aten::batch_norm(%input.53, %weight.119, %bias.59, %running_mean.59, %running_var.59, %1326, %1331, %1330, %1324), scope: __module.layer2/__module.layer2.1/__module.layer2.1.bn2 # /home/coder/Playground/.venv/lib/python3.10/site-packages/torch/nn/functional.py:2813:0
#   %input.55 : Float(1, 128, 28, 28, strides=[100352, 784, 28, 1], requires_grad=1, device=cpu) = aten::add_(%out.7, %input.45, %1327), scope: __module.layer2/__module.layer2.1 # /home/coder/Playground/.venv/lib/python3.10/site-packages/torchvision/models/resnet.py:102:0
#   %input.57 : Float(1, 128, 28, 28, strides=[100352, 784, 28, 1], requires_grad=1, device=cpu) = aten::relu_(%input.55), scope: __module.layer2/__module.layer2.1/__module.layer2.1.relu # /home/coder/Playground/.venv/lib/python3.10/site-packages/torch/nn/functional.py:1695:0
#   %1408 : bool = prim::Constant[value=1](), scope: __module.layer3/__module.layer3.0/__module.layer3.0.conv1 # /home/coder/Playground/.venv/lib/python3.10/site-packages/torch/nn/modules/conv.py:543:0
#   %1409 : int = prim::Constant[value=0](), scope: __module.layer3/__module.layer3.0/__module.layer3.0.conv1 # /home/coder/Playground/.venv/lib/python3.10/site-packages/torch/nn/modules/conv.py:543:0
#   %1410 : bool = prim::Constant[value=0](), scope: __module.layer3/__module.layer3.0/__module.layer3.0.conv1 # /home/coder/Playground/.venv/lib/python3.10/site-packages/torch/nn/modules/conv.py:543:0
#   %1411 : int = prim::Constant[value=1](), scope: __module.layer3/__module.layer3.0/__module.layer3.0.conv1 # /home/coder/Playground/.venv/lib/python3.10/site-packages/torch/nn/modules/conv.py:543:0
#   %1412 : int = prim::Constant[value=2](), scope: __module.layer3/__module.layer3.0/__module.layer3.0.conv1 # /home/coder/Playground/.venv/lib/python3.10/site-packages/torch/nn/modules/conv.py:543:0
#   %1413 : NoneType = prim::Constant(), scope: __module.layer3/__module.layer3.0/__module.layer3.0.conv1
#   %1414 : float = prim::Constant[value=1.0000000000000001e-05](), scope: __module.layer3/__module.layer3.0/__module.layer3.0.bn1 # /home/coder/Playground/.venv/lib/python3.10/site-packages/torch/nn/functional.py:2813:0
#   %1415 : float = prim::Constant[value=0.10000000000000001](), scope: __module.layer3/__module.layer3.0/__module.layer3.0.bn1 # /home/coder/Playground/.venv/lib/python3.10/site-packages/torch/nn/functional.py:2813:0
#   %_1.9 : __torch__.torchvision.models.resnet.___torch_mangle_245.BasicBlock = prim::GetAttr[name="1"](%layer3)
#   %_0.9 : __torch__.torchvision.models.resnet.___torch_mangle_239.BasicBlock = prim::GetAttr[name="0"](%layer3)
#   %downsample.3 : __torch__.torch.nn.modules.container.___torch_mangle_238.Sequential = prim::GetAttr[name="downsample"](%_0.9)
#   %bn2.9 : __torch__.torch.nn.modules.batchnorm.___torch_mangle_235.BatchNorm2d = prim::GetAttr[name="bn2"](%_0.9)
#   %conv2.9 : __torch__.torch.nn.modules.conv.___torch_mangle_234.Conv2d = prim::GetAttr[name="conv2"](%_0.9)
#   %relu.11 : __torch__.torch.nn.modules.activation.___torch_mangle_233.ReLU = prim::GetAttr[name="relu"](%_0.9)
#   %bn1.11 : __torch__.torch.nn.modules.batchnorm.___torch_mangle_232.BatchNorm2d = prim::GetAttr[name="bn1"](%_0.9)
#   %conv1.11 : __torch__.torch.nn.modules.conv.___torch_mangle_231.Conv2d = prim::GetAttr[name="conv1"](%_0.9)
#   %weight.121 : Tensor = prim::GetAttr[name="weight"](%conv1.11)
#   %1425 : int[] = prim::ListConstruct(%1412, %1412), scope: __module.layer3/__module.layer3.0/__module.layer3.0.conv1
#   %1426 : int[] = prim::ListConstruct(%1411, %1411), scope: __module.layer3/__module.layer3.0/__module.layer3.0.conv1
#   %1427 : int[] = prim::ListConstruct(%1411, %1411), scope: __module.layer3/__module.layer3.0/__module.layer3.0.conv1
#   %1428 : int[] = prim::ListConstruct(%1409, %1409), scope: __module.layer3/__module.layer3.0/__module.layer3.0.conv1
#   %input.59 : Float(1, 256, 14, 14, strides=[50176, 196, 14, 1], requires_grad=0, device=cpu) = aten::_convolution(%input.57, %weight.121, %1413, %1425, %1426, %1427, %1410, %1428, %1411, %1410, %1410, %1408, %1408), scope: __module.layer3/__module.layer3.0/__module.layer3.0.conv1 # /home/coder/Playground/.venv/lib/python3.10/site-packages/torch/nn/modules/conv.py:543:0
#   %running_var.61 : Tensor = prim::GetAttr[name="running_var"](%bn1.11)
#   %running_mean.61 : Tensor = prim::GetAttr[name="running_mean"](%bn1.11)
#   %bias.61 : Tensor = prim::GetAttr[name="bias"](%bn1.11)
#   %weight.123 : Tensor = prim::GetAttr[name="weight"](%bn1.11)
#   %input.61 : Float(1, 256, 14, 14, strides=[50176, 196, 14, 1], requires_grad=1, device=cpu) = aten::batch_norm(%input.59, %weight.123, %bias.61, %running_mean.61, %running_var.61, %1410, %1415, %1414, %1408), scope: __module.layer3/__module.layer3.0/__module.layer3.0.bn1 # /home/coder/Playground/.venv/lib/python3.10/site-packages/torch/nn/functional.py:2813:0
#   %input.63 : Float(1, 256, 14, 14, strides=[50176, 196, 14, 1], requires_grad=1, device=cpu) = aten::relu_(%input.61), scope: __module.layer3/__module.layer3.0/__module.layer3.0.relu # /home/coder/Playground/.venv/lib/python3.10/site-packages/torch/nn/functional.py:1695:0
#   %weight.125 : Tensor = prim::GetAttr[name="weight"](%conv2.9)
#   %1437 : int[] = prim::ListConstruct(%1411, %1411), scope: __module.layer3/__module.layer3.0/__module.layer3.0.conv2
#   %1438 : int[] = prim::ListConstruct(%1411, %1411), scope: __module.layer3/__module.layer3.0/__module.layer3.0.conv2
#   %1439 : int[] = prim::ListConstruct(%1411, %1411), scope: __module.layer3/__module.layer3.0/__module.layer3.0.conv2
#   %1440 : int[] = prim::ListConstruct(%1409, %1409), scope: __module.layer3/__module.layer3.0/__module.layer3.0.conv2
#   %input.65 : Float(1, 256, 14, 14, strides=[50176, 196, 14, 1], requires_grad=0, device=cpu) = aten::_convolution(%input.63, %weight.125, %1413, %1437, %1438, %1439, %1410, %1440, %1411, %1410, %1410, %1408, %1408), scope: __module.layer3/__module.layer3.0/__module.layer3.0.conv2 # /home/coder/Playground/.venv/lib/python3.10/site-packages/torch/nn/modules/conv.py:543:0
#   %running_var.63 : Tensor = prim::GetAttr[name="running_var"](%bn2.9)
#   %running_mean.63 : Tensor = prim::GetAttr[name="running_mean"](%bn2.9)
#   %bias.63 : Tensor = prim::GetAttr[name="bias"](%bn2.9)
#   %weight.127 : Tensor = prim::GetAttr[name="weight"](%bn2.9)
#   %out.9 : Float(1, 256, 14, 14, strides=[50176, 196, 14, 1], requires_grad=1, device=cpu) = aten::batch_norm(%input.65, %weight.127, %bias.63, %running_mean.63, %running_var.63, %1410, %1415, %1414, %1408), scope: __module.layer3/__module.layer3.0/__module.layer3.0.bn2 # /home/coder/Playground/.venv/lib/python3.10/site-packages/torch/nn/functional.py:2813:0
#   %_1.7 : __torch__.torch.nn.modules.batchnorm.___torch_mangle_237.BatchNorm2d = prim::GetAttr[name="1"](%downsample.3)
#   %_0.7 : __torch__.torch.nn.modules.conv.___torch_mangle_236.Conv2d = prim::GetAttr[name="0"](%downsample.3)
#   %weight.129 : Tensor = prim::GetAttr[name="weight"](%_0.7)
#   %1450 : int[] = prim::ListConstruct(%1412, %1412), scope: __module.layer3/__module.layer3.0/__module.layer3.0.downsample/__module.layer3.0.downsample.0
#   %1451 : int[] = prim::ListConstruct(%1409, %1409), scope: __module.layer3/__module.layer3.0/__module.layer3.0.downsample/__module.layer3.0.downsample.0
#   %1452 : int[] = prim::ListConstruct(%1411, %1411), scope: __module.layer3/__module.layer3.0/__module.layer3.0.downsample/__module.layer3.0.downsample.0
#   %1453 : int[] = prim::ListConstruct(%1409, %1409), scope: __module.layer3/__module.layer3.0/__module.layer3.0.downsample/__module.layer3.0.downsample.0
#   %input.67 : Float(1, 256, 14, 14, strides=[50176, 196, 14, 1], requires_grad=0, device=cpu) = aten::_convolution(%input.57, %weight.129, %1413, %1450, %1451, %1452, %1410, %1453, %1411, %1410, %1410, %1408, %1408), scope: __module.layer3/__module.layer3.0/__module.layer3.0.downsample/__module.layer3.0.downsample.0 # /home/coder/Playground/.venv/lib/python3.10/site-packages/torch/nn/modules/conv.py:543:0
#   %running_var.65 : Tensor = prim::GetAttr[name="running_var"](%_1.7)
#   %running_mean.65 : Tensor = prim::GetAttr[name="running_mean"](%_1.7)
#   %bias.65 : Tensor = prim::GetAttr[name="bias"](%_1.7)
#   %weight.131 : Tensor = prim::GetAttr[name="weight"](%_1.7)
#   %identity.3 : Float(1, 256, 14, 14, strides=[50176, 196, 14, 1], requires_grad=1, device=cpu) = aten::batch_norm(%input.67, %weight.131, %bias.65, %running_mean.65, %running_var.65, %1410, %1415, %1414, %1408), scope: __module.layer3/__module.layer3.0/__module.layer3.0.downsample/__module.layer3.0.downsample.1 # /home/coder/Playground/.venv/lib/python3.10/site-packages/torch/nn/functional.py:2813:0
#   %input.69 : Float(1, 256, 14, 14, strides=[50176, 196, 14, 1], requires_grad=1, device=cpu) = aten::add_(%out.9, %identity.3, %1411), scope: __module.layer3/__module.layer3.0 # /home/coder/Playground/.venv/lib/python3.10/site-packages/torchvision/models/resnet.py:102:0
#   %input.71 : Float(1, 256, 14, 14, strides=[50176, 196, 14, 1], requires_grad=1, device=cpu) = aten::relu_(%input.69), scope: __module.layer3/__module.layer3.0/__module.layer3.0.relu # /home/coder/Playground/.venv/lib/python3.10/site-packages/torch/nn/functional.py:1695:0
#   %bn2.11 : __torch__.torch.nn.modules.batchnorm.___torch_mangle_244.BatchNorm2d = prim::GetAttr[name="bn2"](%_1.9)
#   %conv2.11 : __torch__.torch.nn.modules.conv.___torch_mangle_243.Conv2d = prim::GetAttr[name="conv2"](%_1.9)
#   %relu.13 : __torch__.torch.nn.modules.activation.___torch_mangle_242.ReLU = prim::GetAttr[name="relu"](%_1.9)
#   %bn1.13 : __torch__.torch.nn.modules.batchnorm.___torch_mangle_241.BatchNorm2d = prim::GetAttr[name="bn1"](%_1.9)
#   %conv1.13 : __torch__.torch.nn.modules.conv.___torch_mangle_240.Conv2d = prim::GetAttr[name="conv1"](%_1.9)
#   %weight.133 : Tensor = prim::GetAttr[name="weight"](%conv1.13)
#   %1468 : int[] = prim::ListConstruct(%1411, %1411), scope: __module.layer3/__module.layer3.1/__module.layer3.1.conv1
#   %1469 : int[] = prim::ListConstruct(%1411, %1411), scope: __module.layer3/__module.layer3.1/__module.layer3.1.conv1
#   %1470 : int[] = prim::ListConstruct(%1411, %1411), scope: __module.layer3/__module.layer3.1/__module.layer3.1.conv1
#   %1471 : int[] = prim::ListConstruct(%1409, %1409), scope: __module.layer3/__module.layer3.1/__module.layer3.1.conv1
#   %input.73 : Float(1, 256, 14, 14, strides=[50176, 196, 14, 1], requires_grad=0, device=cpu) = aten::_convolution(%input.71, %weight.133, %1413, %1468, %1469, %1470, %1410, %1471, %1411, %1410, %1410, %1408, %1408), scope: __module.layer3/__module.layer3.1/__module.layer3.1.conv1 # /home/coder/Playground/.venv/lib/python3.10/site-packages/torch/nn/modules/conv.py:543:0
#   %running_var.67 : Tensor = prim::GetAttr[name="running_var"](%bn1.13)
#   %running_mean.67 : Tensor = prim::GetAttr[name="running_mean"](%bn1.13)
#   %bias.67 : Tensor = prim::GetAttr[name="bias"](%bn1.13)
#   %weight.135 : Tensor = prim::GetAttr[name="weight"](%bn1.13)
#   %input.75 : Float(1, 256, 14, 14, strides=[50176, 196, 14, 1], requires_grad=1, device=cpu) = aten::batch_norm(%input.73, %weight.135, %bias.67, %running_mean.67, %running_var.67, %1410, %1415, %1414, %1408), scope: __module.layer3/__module.layer3.1/__module.layer3.1.bn1 # /home/coder/Playground/.venv/lib/python3.10/site-packages/torch/nn/functional.py:2813:0
#   %input.77 : Float(1, 256, 14, 14, strides=[50176, 196, 14, 1], requires_grad=1, device=cpu) = aten::relu_(%input.75), scope: __module.layer3/__module.layer3.1/__module.layer3.1.relu # /home/coder/Playground/.venv/lib/python3.10/site-packages/torch/nn/functional.py:1695:0
#   %weight.137 : Tensor = prim::GetAttr[name="weight"](%conv2.11)
#   %1480 : int[] = prim::ListConstruct(%1411, %1411), scope: __module.layer3/__module.layer3.1/__module.layer3.1.conv2
#   %1481 : int[] = prim::ListConstruct(%1411, %1411), scope: __module.layer3/__module.layer3.1/__module.layer3.1.conv2
#   %1482 : int[] = prim::ListConstruct(%1411, %1411), scope: __module.layer3/__module.layer3.1/__module.layer3.1.conv2
#   %1483 : int[] = prim::ListConstruct(%1409, %1409), scope: __module.layer3/__module.layer3.1/__module.layer3.1.conv2
#   %input.79 : Float(1, 256, 14, 14, strides=[50176, 196, 14, 1], requires_grad=0, device=cpu) = aten::_convolution(%input.77, %weight.137, %1413, %1480, %1481, %1482, %1410, %1483, %1411, %1410, %1410, %1408, %1408), scope: __module.layer3/__module.layer3.1/__module.layer3.1.conv2 # /home/coder/Playground/.venv/lib/python3.10/site-packages/torch/nn/modules/conv.py:543:0
#   %running_var.69 : Tensor = prim::GetAttr[name="running_var"](%bn2.11)
#   %running_mean.69 : Tensor = prim::GetAttr[name="running_mean"](%bn2.11)
#   %bias.69 : Tensor = prim::GetAttr[name="bias"](%bn2.11)
#   %weight.139 : Tensor = prim::GetAttr[name="weight"](%bn2.11)
#   %out.11 : Float(1, 256, 14, 14, strides=[50176, 196, 14, 1], requires_grad=1, device=cpu) = aten::batch_norm(%input.79, %weight.139, %bias.69, %running_mean.69, %running_var.69, %1410, %1415, %1414, %1408), scope: __module.layer3/__module.layer3.1/__module.layer3.1.bn2 # /home/coder/Playground/.venv/lib/python3.10/site-packages/torch/nn/functional.py:2813:0
#   %input.81 : Float(1, 256, 14, 14, strides=[50176, 196, 14, 1], requires_grad=1, device=cpu) = aten::add_(%out.11, %input.71, %1411), scope: __module.layer3/__module.layer3.1 # /home/coder/Playground/.venv/lib/python3.10/site-packages/torchvision/models/resnet.py:102:0
#   %input.83 : Float(1, 256, 14, 14, strides=[50176, 196, 14, 1], requires_grad=1, device=cpu) = aten::relu_(%input.81), scope: __module.layer3/__module.layer3.1/__module.layer3.1.relu # /home/coder/Playground/.venv/lib/python3.10/site-packages/torch/nn/functional.py:1695:0
#   %1492 : bool = prim::Constant[value=1](), scope: __module.layer4/__module.layer4.0/__module.layer4.0.conv1 # /home/coder/Playground/.venv/lib/python3.10/site-packages/torch/nn/modules/conv.py:543:0
#   %1493 : int = prim::Constant[value=0](), scope: __module.layer4/__module.layer4.0/__module.layer4.0.conv1 # /home/coder/Playground/.venv/lib/python3.10/site-packages/torch/nn/modules/conv.py:543:0
#   %1494 : bool = prim::Constant[value=0](), scope: __module.layer4/__module.layer4.0/__module.layer4.0.conv1 # /home/coder/Playground/.venv/lib/python3.10/site-packages/torch/nn/modules/conv.py:543:0
#   %1495 : int = prim::Constant[value=1](), scope: __module.layer4/__module.layer4.0/__module.layer4.0.conv1 # /home/coder/Playground/.venv/lib/python3.10/site-packages/torch/nn/modules/conv.py:543:0
#   %1496 : int = prim::Constant[value=2](), scope: __module.layer4/__module.layer4.0/__module.layer4.0.conv1 # /home/coder/Playground/.venv/lib/python3.10/site-packages/torch/nn/modules/conv.py:543:0
#   %1497 : NoneType = prim::Constant(), scope: __module.layer4/__module.layer4.0/__module.layer4.0.conv1
#   %1498 : float = prim::Constant[value=1.0000000000000001e-05](), scope: __module.layer4/__module.layer4.0/__module.layer4.0.bn1 # /home/coder/Playground/.venv/lib/python3.10/site-packages/torch/nn/functional.py:2813:0
#   %1499 : float = prim::Constant[value=0.10000000000000001](), scope: __module.layer4/__module.layer4.0/__module.layer4.0.bn1 # /home/coder/Playground/.venv/lib/python3.10/site-packages/torch/nn/functional.py:2813:0
#   %_1 : __torch__.torchvision.models.resnet.___torch_mangle_261.BasicBlock = prim::GetAttr[name="1"](%layer4)
#   %_0 : __torch__.torchvision.models.resnet.___torch_mangle_255.BasicBlock = prim::GetAttr[name="0"](%layer4)
#   %downsample : __torch__.torch.nn.modules.container.___torch_mangle_254.Sequential = prim::GetAttr[name="downsample"](%_0)
#   %bn2.13 : __torch__.torch.nn.modules.batchnorm.___torch_mangle_251.BatchNorm2d = prim::GetAttr[name="bn2"](%_0)
#   %conv2.13 : __torch__.torch.nn.modules.conv.___torch_mangle_250.Conv2d = prim::GetAttr[name="conv2"](%_0)
#   %relu.15 : __torch__.torch.nn.modules.activation.___torch_mangle_249.ReLU = prim::GetAttr[name="relu"](%_0)
#   %bn1.15 : __torch__.torch.nn.modules.batchnorm.___torch_mangle_248.BatchNorm2d = prim::GetAttr[name="bn1"](%_0)
#   %conv1.15 : __torch__.torch.nn.modules.conv.___torch_mangle_247.Conv2d = prim::GetAttr[name="conv1"](%_0)
#   %weight.141 : Tensor = prim::GetAttr[name="weight"](%conv1.15)
#   %1509 : int[] = prim::ListConstruct(%1496, %1496), scope: __module.layer4/__module.layer4.0/__module.layer4.0.conv1
#   %1510 : int[] = prim::ListConstruct(%1495, %1495), scope: __module.layer4/__module.layer4.0/__module.layer4.0.conv1
#   %1511 : int[] = prim::ListConstruct(%1495, %1495), scope: __module.layer4/__module.layer4.0/__module.layer4.0.conv1
#   %1512 : int[] = prim::ListConstruct(%1493, %1493), scope: __module.layer4/__module.layer4.0/__module.layer4.0.conv1
#   %input.85 : Float(1, 512, 7, 7, strides=[25088, 49, 7, 1], requires_grad=0, device=cpu) = aten::_convolution(%input.83, %weight.141, %1497, %1509, %1510, %1511, %1494, %1512, %1495, %1494, %1494, %1492, %1492), scope: __module.layer4/__module.layer4.0/__module.layer4.0.conv1 # /home/coder/Playground/.venv/lib/python3.10/site-packages/torch/nn/modules/conv.py:543:0
#   %running_var.71 : Tensor = prim::GetAttr[name="running_var"](%bn1.15)
#   %running_mean.71 : Tensor = prim::GetAttr[name="running_mean"](%bn1.15)
#   %bias.71 : Tensor = prim::GetAttr[name="bias"](%bn1.15)
#   %weight.143 : Tensor = prim::GetAttr[name="weight"](%bn1.15)
#   %input.87 : Float(1, 512, 7, 7, strides=[25088, 49, 7, 1], requires_grad=1, device=cpu) = aten::batch_norm(%input.85, %weight.143, %bias.71, %running_mean.71, %running_var.71, %1494, %1499, %1498, %1492), scope: __module.layer4/__module.layer4.0/__module.layer4.0.bn1 # /home/coder/Playground/.venv/lib/python3.10/site-packages/torch/nn/functional.py:2813:0
#   %input.89 : Float(1, 512, 7, 7, strides=[25088, 49, 7, 1], requires_grad=1, device=cpu) = aten::relu_(%input.87), scope: __module.layer4/__module.layer4.0/__module.layer4.0.relu # /home/coder/Playground/.venv/lib/python3.10/site-packages/torch/nn/functional.py:1695:0
#   %weight.145 : Tensor = prim::GetAttr[name="weight"](%conv2.13)
#   %1521 : int[] = prim::ListConstruct(%1495, %1495), scope: __module.layer4/__module.layer4.0/__module.layer4.0.conv2
#   %1522 : int[] = prim::ListConstruct(%1495, %1495), scope: __module.layer4/__module.layer4.0/__module.layer4.0.conv2
#   %1523 : int[] = prim::ListConstruct(%1495, %1495), scope: __module.layer4/__module.layer4.0/__module.layer4.0.conv2
#   %1524 : int[] = prim::ListConstruct(%1493, %1493), scope: __module.layer4/__module.layer4.0/__module.layer4.0.conv2
#   %input.91 : Float(1, 512, 7, 7, strides=[25088, 49, 7, 1], requires_grad=0, device=cpu) = aten::_convolution(%input.89, %weight.145, %1497, %1521, %1522, %1523, %1494, %1524, %1495, %1494, %1494, %1492, %1492), scope: __module.layer4/__module.layer4.0/__module.layer4.0.conv2 # /home/coder/Playground/.venv/lib/python3.10/site-packages/torch/nn/modules/conv.py:543:0
#   %running_var.73 : Tensor = prim::GetAttr[name="running_var"](%bn2.13)
#   %running_mean.73 : Tensor = prim::GetAttr[name="running_mean"](%bn2.13)
#   %bias.73 : Tensor = prim::GetAttr[name="bias"](%bn2.13)
#   %weight.147 : Tensor = prim::GetAttr[name="weight"](%bn2.13)
#   %out.13 : Float(1, 512, 7, 7, strides=[25088, 49, 7, 1], requires_grad=1, device=cpu) = aten::batch_norm(%input.91, %weight.147, %bias.73, %running_mean.73, %running_var.73, %1494, %1499, %1498, %1492), scope: __module.layer4/__module.layer4.0/__module.layer4.0.bn2 # /home/coder/Playground/.venv/lib/python3.10/site-packages/torch/nn/functional.py:2813:0
#   %_1.11 : __torch__.torch.nn.modules.batchnorm.___torch_mangle_253.BatchNorm2d = prim::GetAttr[name="1"](%downsample)
#   %_0.11 : __torch__.torch.nn.modules.conv.___torch_mangle_252.Conv2d = prim::GetAttr[name="0"](%downsample)
#   %weight.149 : Tensor = prim::GetAttr[name="weight"](%_0.11)
#   %1534 : int[] = prim::ListConstruct(%1496, %1496), scope: __module.layer4/__module.layer4.0/__module.layer4.0.downsample/__module.layer4.0.downsample.0
#   %1535 : int[] = prim::ListConstruct(%1493, %1493), scope: __module.layer4/__module.layer4.0/__module.layer4.0.downsample/__module.layer4.0.downsample.0
#   %1536 : int[] = prim::ListConstruct(%1495, %1495), scope: __module.layer4/__module.layer4.0/__module.layer4.0.downsample/__module.layer4.0.downsample.0
#   %1537 : int[] = prim::ListConstruct(%1493, %1493), scope: __module.layer4/__module.layer4.0/__module.layer4.0.downsample/__module.layer4.0.downsample.0
#   %input.93 : Float(1, 512, 7, 7, strides=[25088, 49, 7, 1], requires_grad=0, device=cpu) = aten::_convolution(%input.83, %weight.149, %1497, %1534, %1535, %1536, %1494, %1537, %1495, %1494, %1494, %1492, %1492), scope: __module.layer4/__module.layer4.0/__module.layer4.0.downsample/__module.layer4.0.downsample.0 # /home/coder/Playground/.venv/lib/python3.10/site-packages/torch/nn/modules/conv.py:543:0
#   %running_var.75 : Tensor = prim::GetAttr[name="running_var"](%_1.11)
#   %running_mean.75 : Tensor = prim::GetAttr[name="running_mean"](%_1.11)
#   %bias.75 : Tensor = prim::GetAttr[name="bias"](%_1.11)
#   %weight.151 : Tensor = prim::GetAttr[name="weight"](%_1.11)
#   %identity : Float(1, 512, 7, 7, strides=[25088, 49, 7, 1], requires_grad=1, device=cpu) = aten::batch_norm(%input.93, %weight.151, %bias.75, %running_mean.75, %running_var.75, %1494, %1499, %1498, %1492), scope: __module.layer4/__module.layer4.0/__module.layer4.0.downsample/__module.layer4.0.downsample.1 # /home/coder/Playground/.venv/lib/python3.10/site-packages/torch/nn/functional.py:2813:0
#   %input.95 : Float(1, 512, 7, 7, strides=[25088, 49, 7, 1], requires_grad=1, device=cpu) = aten::add_(%out.13, %identity, %1495), scope: __module.layer4/__module.layer4.0 # /home/coder/Playground/.venv/lib/python3.10/site-packages/torchvision/models/resnet.py:102:0
#   %input.97 : Float(1, 512, 7, 7, strides=[25088, 49, 7, 1], requires_grad=1, device=cpu) = aten::relu_(%input.95), scope: __module.layer4/__module.layer4.0/__module.layer4.0.relu # /home/coder/Playground/.venv/lib/python3.10/site-packages/torch/nn/functional.py:1695:0
#   %bn2 : __torch__.torch.nn.modules.batchnorm.___torch_mangle_260.BatchNorm2d = prim::GetAttr[name="bn2"](%_1)
#   %conv2 : __torch__.torch.nn.modules.conv.___torch_mangle_259.Conv2d = prim::GetAttr[name="conv2"](%_1)
#   %relu : __torch__.torch.nn.modules.activation.___torch_mangle_258.ReLU = prim::GetAttr[name="relu"](%_1)
#   %bn1 : __torch__.torch.nn.modules.batchnorm.___torch_mangle_257.BatchNorm2d = prim::GetAttr[name="bn1"](%_1)
#   %conv1 : __torch__.torch.nn.modules.conv.___torch_mangle_256.Conv2d = prim::GetAttr[name="conv1"](%_1)
#   %weight.153 : Tensor = prim::GetAttr[name="weight"](%conv1)
#   %1552 : int[] = prim::ListConstruct(%1495, %1495), scope: __module.layer4/__module.layer4.1/__module.layer4.1.conv1
#   %1553 : int[] = prim::ListConstruct(%1495, %1495), scope: __module.layer4/__module.layer4.1/__module.layer4.1.conv1
#   %1554 : int[] = prim::ListConstruct(%1495, %1495), scope: __module.layer4/__module.layer4.1/__module.layer4.1.conv1
#   %1555 : int[] = prim::ListConstruct(%1493, %1493), scope: __module.layer4/__module.layer4.1/__module.layer4.1.conv1
#   %input.99 : Float(1, 512, 7, 7, strides=[25088, 49, 7, 1], requires_grad=0, device=cpu) = aten::_convolution(%input.97, %weight.153, %1497, %1552, %1553, %1554, %1494, %1555, %1495, %1494, %1494, %1492, %1492), scope: __module.layer4/__module.layer4.1/__module.layer4.1.conv1 # /home/coder/Playground/.venv/lib/python3.10/site-packages/torch/nn/modules/conv.py:543:0
#   %running_var.77 : Tensor = prim::GetAttr[name="running_var"](%bn1)
#   %running_mean.77 : Tensor = prim::GetAttr[name="running_mean"](%bn1)
#   %bias.77 : Tensor = prim::GetAttr[name="bias"](%bn1)
#   %weight.155 : Tensor = prim::GetAttr[name="weight"](%bn1)
#   %input.101 : Float(1, 512, 7, 7, strides=[25088, 49, 7, 1], requires_grad=1, device=cpu) = aten::batch_norm(%input.99, %weight.155, %bias.77, %running_mean.77, %running_var.77, %1494, %1499, %1498, %1492), scope: __module.layer4/__module.layer4.1/__module.layer4.1.bn1 # /home/coder/Playground/.venv/lib/python3.10/site-packages/torch/nn/functional.py:2813:0
#   %input.103 : Float(1, 512, 7, 7, strides=[25088, 49, 7, 1], requires_grad=1, device=cpu) = aten::relu_(%input.101), scope: __module.layer4/__module.layer4.1/__module.layer4.1.relu # /home/coder/Playground/.venv/lib/python3.10/site-packages/torch/nn/functional.py:1695:0
#   %weight.157 : Tensor = prim::GetAttr[name="weight"](%conv2)
#   %1564 : int[] = prim::ListConstruct(%1495, %1495), scope: __module.layer4/__module.layer4.1/__module.layer4.1.conv2
#   %1565 : int[] = prim::ListConstruct(%1495, %1495), scope: __module.layer4/__module.layer4.1/__module.layer4.1.conv2
#   %1566 : int[] = prim::ListConstruct(%1495, %1495), scope: __module.layer4/__module.layer4.1/__module.layer4.1.conv2
#   %1567 : int[] = prim::ListConstruct(%1493, %1493), scope: __module.layer4/__module.layer4.1/__module.layer4.1.conv2
#   %input.105 : Float(1, 512, 7, 7, strides=[25088, 49, 7, 1], requires_grad=0, device=cpu) = aten::_convolution(%input.103, %weight.157, %1497, %1564, %1565, %1566, %1494, %1567, %1495, %1494, %1494, %1492, %1492), scope: __module.layer4/__module.layer4.1/__module.layer4.1.conv2 # /home/coder/Playground/.venv/lib/python3.10/site-packages/torch/nn/modules/conv.py:543:0
#   %running_var : Tensor = prim::GetAttr[name="running_var"](%bn2)
#   %running_mean : Tensor = prim::GetAttr[name="running_mean"](%bn2)
#   %bias.79 : Tensor = prim::GetAttr[name="bias"](%bn2)
#   %weight.159 : Tensor = prim::GetAttr[name="weight"](%bn2)
#   %out : Float(1, 512, 7, 7, strides=[25088, 49, 7, 1], requires_grad=1, device=cpu) = aten::batch_norm(%input.105, %weight.159, %bias.79, %running_mean, %running_var, %1494, %1499, %1498, %1492), scope: __module.layer4/__module.layer4.1/__module.layer4.1.bn2 # /home/coder/Playground/.venv/lib/python3.10/site-packages/torch/nn/functional.py:2813:0
#   %input.107 : Float(1, 512, 7, 7, strides=[25088, 49, 7, 1], requires_grad=1, device=cpu) = aten::add_(%out, %input.97, %1495), scope: __module.layer4/__module.layer4.1 # /home/coder/Playground/.venv/lib/python3.10/site-packages/torchvision/models/resnet.py:102:0
#   %input.109 : Float(1, 512, 7, 7, strides=[25088, 49, 7, 1], requires_grad=1, device=cpu) = aten::relu_(%input.107), scope: __module.layer4/__module.layer4.1/__module.layer4.1.relu # /home/coder/Playground/.venv/lib/python3.10/site-packages/torch/nn/functional.py:1695:0
#   %1576 : int = prim::Constant[value=1](), scope: __module.avgpool # /home/coder/Playground/.venv/lib/python3.10/site-packages/torch/nn/functional.py:1375:0
#   %1577 : int[] = prim::ListConstruct(%1576, %1576), scope: __module.avgpool
#   %x : Float(1, 512, 1, 1, strides=[512, 1, 1, 1], requires_grad=1, device=cpu) = aten::adaptive_avg_pool2d(%input.109, %1577), scope: __module.avgpool # /home/coder/Playground/.venv/lib/python3.10/site-packages/torch/nn/functional.py:1375:0
#   %890 : int = prim::Constant[value=1]() # /home/coder/Playground/.venv/lib/python3.10/site-packages/torchvision/models/resnet.py:279:0
#   %891 : int = prim::Constant[value=-1]() # /home/coder/Playground/.venv/lib/python3.10/site-packages/torchvision/models/resnet.py:279:0
#   %input : Float(1, 512, strides=[512, 1], requires_grad=1, device=cpu) = aten::flatten(%x, %890, %891) # /home/coder/Playground/.venv/lib/python3.10/site-packages/torchvision/models/resnet.py:279:0
#   %bias : Tensor = prim::GetAttr[name="bias"](%fc)
#   %weight : Tensor = prim::GetAttr[name="weight"](%fc)
#   %1581 : Float(1, 1000, strides=[1000, 1], requires_grad=1, device=cpu) = aten::linear(%input, %weight, %bias), scope: __module.fc # /home/coder/Playground/.venv/lib/python3.10/site-packages/torch/nn/modules/linear.py:134:0
#   return (%1581)
#
# { value : 1}
# { value : 0}
# { value : 0}
# { value : 1}
# { value : 3}
# { value : 2}
# {}
# { name :  weight }
# {}
# {}
# {}
# {}
# {}
# { value : 1}
# { value : 1e-05}
# { value : 0.1}
# { value : 0}
# { name :  running_var }
# { name :  running_mean }
# { name :  bias }
# { name :  weight }
# {}
# {}
# { value : 0}
# { value : 1}
# { value : 2}
# { value : 3}
# {}
# {}
# {}
# {}
# {}
# { value : 1}
# { value : 0}
# { value : 0}
# { value : 1}
# {}
# { value : 1e-05}
# { value : 0.1}
# { name :  weight }
# {}
# {}
# {}
# {}
# {}
# { name :  running_var }
# { name :  running_mean }
# { name :  bias }
# { name :  weight }
# {}
# {}
# { name :  weight }
# {}
# {}
# {}
# {}
# {}
# { name :  running_var }
# { name :  running_mean }
# { name :  bias }
# { name :  weight }
# {}
# {}
# {}
# { name :  weight }
# {}
# {}
# {}
# {}
# {}
# { name :  running_var }
# { name :  running_mean }
# { name :  bias }
# { name :  weight }
# {}
# {}
# { name :  weight }
# {}
# {}
# {}
# {}
# {}
# { name :  running_var }
# { name :  running_mean }
# { name :  bias }
# { name :  weight }
# {}
# {}
# {}
# { value : 1}
# { value : 0}
# { value : 0}
# { value : 1}
# { value : 2}
# {}
# { value : 1e-05}
# { value : 0.1}
# { name :  weight }
# {}
# {}
# {}
# {}
# {}
# { name :  running_var }
# { name :  running_mean }
# { name :  bias }
# { name :  weight }
# {}
# {}
# { name :  weight }
# {}
# {}
# {}
# {}
# {}
# { name :  running_var }
# { name :  running_mean }
# { name :  bias }
# { name :  weight }
# {}
# { name :  weight }
# {}
# {}
# {}
# {}
# {}
# { name :  running_var }
# { name :  running_mean }
# { name :  bias }
# { name :  weight }
# {}
# {}
# {}
# { name :  weight }
# {}
# {}
# {}
# {}
# {}
# { name :  running_var }
# { name :  running_mean }
# { name :  bias }
# { name :  weight }
# {}
# {}
# { name :  weight }
# {}
# {}
# {}
# {}
# {}
# { name :  running_var }
# { name :  running_mean }
# { name :  bias }
# { name :  weight }
# {}
# {}
# {}
# { value : 1}
# { value : 0}
# { value : 0}
# { value : 1}
# { value : 2}
# {}
# { value : 1e-05}
# { value : 0.1}
# { name :  weight }
# {}
# {}
# {}
# {}
# {}
# { name :  running_var }
# { name :  running_mean }
# { name :  bias }
# { name :  weight }
# {}
# {}
# { name :  weight }
# {}
# {}
# {}
# {}
# {}
# { name :  running_var }
# { name :  running_mean }
# { name :  bias }
# { name :  weight }
# {}
# { name :  weight }
# {}
# {}
# {}
# {}
# {}
# { name :  running_var }
# { name :  running_mean }
# { name :  bias }
# { name :  weight }
# {}
# {}
# {}
# { name :  weight }
# {}
# {}
# {}
# {}
# {}
# { name :  running_var }
# { name :  running_mean }
# { name :  bias }
# { name :  weight }
# {}
# {}
# { name :  weight }
# {}
# {}
# {}
# {}
# {}
# { name :  running_var }
# { name :  running_mean }
# { name :  bias }
# { name :  weight }
# {}
# {}
# {}
# { value : 1}
# { value : 0}
# { value : 0}
# { value : 1}
# { value : 2}
# {}
# { value : 1e-05}
# { value : 0.1}
# { name :  weight }
# {}
# {}
# {}
# {}
# {}
# { name :  running_var }
# { name :  running_mean }
# { name :  bias }
# { name :  weight }
# {}
# {}
# { name :  weight }
# {}
# {}
# {}
# {}
# {}
# { name :  running_var }
# { name :  running_mean }
# { name :  bias }
# { name :  weight }
# {}
# { name :  weight }
# {}
# {}
# {}
# {}
# {}
# { name :  running_var }
# { name :  running_mean }
# { name :  bias }
# { name :  weight }
# {}
# {}
# {}
# { name :  weight }
# {}
# {}
# {}
# {}
# {}
# { name :  running_var }
# { name :  running_mean }
# { name :  bias }
# { name :  weight }
# {}
# {}
# { name :  weight }
# {}
# {}
# {}
# {}
# {}
# { name :  running_var }
# { name :  running_mean }
# { name :  bias }
# { name :  weight }
# {}
# {}
# {}
# { value : 1}
# {}
# {}
# { value : 1}
# { value : -1}
# {}
# { name :  bias }
# { name :  weight }
# {}

# %%
model_graph
# Out:
# node {
#   name: "input/x.1"
#   op: "IO Node"
#   attr {
#     key: "attr"
#     value {
#       s: ""
#     }
#   }
#   attr {
#     key: "_output_shapes"
#     value {
#       list {
#         shape {
#           dim {
#             size: 1
#           }
#           dim {
#             size: 3
#           }
#           dim {
#             size: 224
#           }
#           dim {
#             size: 224
#           }
#         }
#       }
#     }
#   }
# }
# node {
#   name: "output/output.1"
#   op: "IO Node"
#   input: "ResNet/Linear[fc]/1581"
#   attr {
#     key: "attr"
#     value {
#       s: ""
#     }
#   }
#   attr {
#     key: "_output_shapes"
#     value {
#       list {
#         shape {
#           dim {
#             size: 1
#           }
#           dim {
#             size: 1000
#           }
#         }
#       }
#     }
#   }
# }
# node {
#   name: "ResNet/Conv2d[conv1]/1223"
#   op: "prim::Constant"
#   attr {
#     key: "attr"
#     value {
#       s: "{ value : 1}"
#     }
#   }
# }
# node {
#   name: "ResNet/Conv2d[conv1]/1224"
#   op: "prim::Constant"
#   attr {
#     key: "attr"
#     value {
#       s: "{ value : 0}"
#     }
#   }
# }
# node {
#   name: "ResNet/Conv2d[conv1]/1225"
#   op: "prim::Constant"
#   attr {
#     key: "attr"
#     value {
#       s: "{ value : 0}"
#     }
#   }
# }
# node {
#   name: "ResNet/Conv2d[conv1]/1226"
#   op: "prim::Constant"
#   attr {
#     key: "attr"
#     value {
#       s: "{ value : 1}"
#     }
#   }
# }
# node {
#   name: "ResNet/Conv2d[conv1]/1227"
#   op: "prim::Constant"
#   attr {
#     key: "attr"
#     value {
#       s: "{ value : 3}"
#     }
#   }
# }
# node {
#   name: "ResNet/Conv2d[conv1]/1228"
#   op: "prim::Constant"
#   attr {
#     key: "attr"
#     value {
#       s: "{ value : 2}"
#     }
#   }
# }
# node {
#   name: "ResNet/Conv2d[conv1]/1229"
#   op: "prim::Constant"
#   attr {
#     key: "attr"
#     value {
#       s: "{}"
#     }
#   }
# }
# node {
#   name: "ResNet/Conv2d[conv1]/weight/weight.81"
#   op: "prim::GetAttr"
#   input: "ResNet/Conv2d[conv1]/weight/conv1.1"
#   attr {
#     key: "attr"
#     value {
#       s: "{ name :  weight }"
#     }
#   }
# }
# node {
#   name: "ResNet/Conv2d[conv1]/1231"
#   op: "prim::ListConstruct"
#   input: "ResNet/Conv2d[conv1]/1228"
#   input: "ResNet/Conv2d[conv1]/1228"
#   attr {
#     key: "attr"
#     value {
#       s: "{}"
#     }
#   }
# }
# node {
#   name: "ResNet/Conv2d[conv1]/1232"
#   op: "prim::ListConstruct"
#   input: "ResNet/Conv2d[conv1]/1227"
#   input: "ResNet/Conv2d[conv1]/1227"
#   attr {
#     key: "attr"
#     value {
#       s: "{}"
#     }
#   }
# }
# node {
#   name: "ResNet/Conv2d[conv1]/1233"
#   op: "prim::ListConstruct"
#   input: "ResNet/Conv2d[conv1]/1226"
#   input: "ResNet/Conv2d[conv1]/1226"
#   attr {
#     key: "attr"
#     value {
#       s: "{}"
#     }
#   }
# }
# node {
#   name: "ResNet/Conv2d[conv1]/1234"
#   op: "prim::ListConstruct"
#   input: "ResNet/Conv2d[conv1]/1224"
#   input: "ResNet/Conv2d[conv1]/1224"
#   attr {
#     key: "attr"
#     value {
#       s: "{}"
#     }
#   }
# }
# node {
#   name: "ResNet/Conv2d[conv1]/input.1"
#   op: "aten::_convolution"
#   input: "input/x.1"
#   input: "ResNet/Conv2d[conv1]/weight/weight.81"
#   input: "ResNet/Conv2d[conv1]/1229"
#   input: "ResNet/Conv2d[conv1]/1231"
#   input: "ResNet/Conv2d[conv1]/1232"
#   input: "ResNet/Conv2d[conv1]/1233"
#   input: "ResNet/Conv2d[conv1]/1225"
#   input: "ResNet/Conv2d[conv1]/1234"
#   input: "ResNet/Conv2d[conv1]/1226"
#   input: "ResNet/Conv2d[conv1]/1225"
#   input: "ResNet/Conv2d[conv1]/1225"
#   input: "ResNet/Conv2d[conv1]/1223"
#   input: "ResNet/Conv2d[conv1]/1223"
#   attr {
#     key: "attr"
#     value {
#       s: "{}"
#     }
#   }
#   attr {
#     key: "_output_shapes"
#     value {
#       list {
#         shape {
#           dim {
#             size: 1
#           }
#           dim {
#             size: 64
#           }
#           dim {
#             size: 112
#           }
#           dim {
#             size: 112
#           }
#         }
#       }
#     }
#   }
# }
# node {
#   name: "ResNet/BatchNorm2d[bn1]/1236"
#   op: "prim::Constant"
#   attr {
#     key: "attr"
#     value {
#       s: "{ value : 1}"
#     }
#   }
# }
# node {
#   name: "ResNet/BatchNorm2d[bn1]/1237"
#   op: "prim::Constant"
#   attr {
#     key: "attr"
#     value {
#       s: "{ value : 1e-05}"
#     }
#   }
# }
# node {
#   name: "ResNet/BatchNorm2d[bn1]/1238"
#   op: "prim::Constant"
#   attr {
#     key: "attr"
#     value {
#       s: "{ value : 0.1}"
#     }
#   }
# }
# node {
#   name: "ResNet/BatchNorm2d[bn1]/1239"
#   op: "prim::Constant"
#   attr {
#     key: "attr"
#     value {
#       s: "{ value : 0}"
#     }
#   }
# }
# node {
#   name: "ResNet/BatchNorm2d[bn1]/running_var/running_var.41"
#   op: "prim::GetAttr"
#   input: "ResNet/BatchNorm2d[bn1]/weight/bn1.1"
#   attr {
#     key: "attr"
#     value {
#       s: "{ name :  running_var }"
#     }
#   }
# }
# node {
#   name: "ResNet/BatchNorm2d[bn1]/running_mean/running_mean.41"
#   op: "prim::GetAttr"
#   input: "ResNet/BatchNorm2d[bn1]/weight/bn1.1"
#   attr {
#     key: "attr"
#     value {
#       s: "{ name :  running_mean }"
#     }
#   }
# }
# node {
#   name: "ResNet/BatchNorm2d[bn1]/bias/bias.41"
#   op: "prim::GetAttr"
#   input: "ResNet/BatchNorm2d[bn1]/weight/bn1.1"
#   attr {
#     key: "attr"
#     value {
#       s: "{ name :  bias }"
#     }
#   }
# }
# node {
#   name: "ResNet/BatchNorm2d[bn1]/weight/weight.83"
#   op: "prim::GetAttr"
#   input: "ResNet/BatchNorm2d[bn1]/weight/bn1.1"
#   attr {
#     key: "attr"
#     value {
#       s: "{ name :  weight }"
#     }
#   }
# }
# node {
#   name: "ResNet/BatchNorm2d[bn1]/input.3"
#   op: "aten::batch_norm"
#   input: "ResNet/Conv2d[conv1]/input.1"
#   input: "ResNet/BatchNorm2d[bn1]/weight/weight.83"
#   input: "ResNet/BatchNorm2d[bn1]/bias/bias.41"
#   input: "ResNet/BatchNorm2d[bn1]/running_mean/running_mean.41"
#   input: "ResNet/BatchNorm2d[bn1]/running_var/running_var.41"
#   input: "ResNet/BatchNorm2d[bn1]/1239"
#   input: "ResNet/BatchNorm2d[bn1]/1238"
#   input: "ResNet/BatchNorm2d[bn1]/1237"
#   input: "ResNet/BatchNorm2d[bn1]/1236"
#   attr {
#     key: "attr"
#     value {
#       s: "{}"
#     }
#   }
#   attr {
#     key: "_output_shapes"
#     value {
#       list {
#         shape {
#           dim {
#             size: 1
#           }
#           dim {
#             size: 64
#           }
#           dim {
#             size: 112
#           }
#           dim {
#             size: 112
#           }
#         }
#       }
#     }
#   }
# }
# node {
#   name: "ResNet/ReLU[relu]/input.5"
#   op: "aten::relu_"
#   input: "ResNet/BatchNorm2d[bn1]/input.3"
#   attr {
#     key: "attr"
#     value {
#       s: "{}"
#     }
#   }
#   attr {
#     key: "_output_shapes"
#     value {
#       list {
#         shape {
#           dim {
#             size: 1
#           }
#           dim {
#             size: 64
#           }
#           dim {
#             size: 112
#           }
#           dim {
#             size: 112
#           }
#         }
#       }
#     }
#   }
# }
# node {
#   name: "ResNet/MaxPool2d[maxpool]/1246"
#   op: "prim::Constant"
#   attr {
#     key: "attr"
#     value {
#       s: "{ value : 0}"
#     }
#   }
# }
# node {
#   name: "ResNet/MaxPool2d[maxpool]/1247"
#   op: "prim::Constant"
#   attr {
#     key: "attr"
#     value {
#       s: "{ value : 1}"
#     }
#   }
# }
# node {
#   name: "ResNet/MaxPool2d[maxpool]/1248"
#   op: "prim::Constant"
#   attr {
#     key: "attr"
#     value {
#       s: "{ value : 2}"
#     }
#   }
# }
# node {
#   name: "ResNet/MaxPool2d[maxpool]/1249"
#   op: "prim::Constant"
#   attr {
#     key: "attr"
#     value {
#       s: "{ value : 3}"
#     }
#   }
# }
# node {
#   name: "ResNet/MaxPool2d[maxpool]/1250"
#   op: "prim::ListConstruct"
#   input: "ResNet/MaxPool2d[maxpool]/1249"
#   input: "ResNet/MaxPool2d[maxpool]/1249"
#   attr {
#     key: "attr"
#     value {
#       s: "{}"
#     }
#   }
# }
# node {
#   name: "ResNet/MaxPool2d[maxpool]/1251"
#   op: "prim::ListConstruct"
#   input: "ResNet/MaxPool2d[maxpool]/1248"
#   input: "ResNet/MaxPool2d[maxpool]/1248"
#   attr {
#     key: "attr"
#     value {
#       s: "{}"
#     }
#   }
# }
# node {
#   name: "ResNet/MaxPool2d[maxpool]/1252"
#   op: "prim::ListConstruct"
#   input: "ResNet/MaxPool2d[maxpool]/1247"
#   input: "ResNet/MaxPool2d[maxpool]/1247"
#   attr {
#     key: "attr"
#     value {
#       s: "{}"
#     }
#   }
# }
# node {
#   name: "ResNet/MaxPool2d[maxpool]/1253"
#   op: "prim::ListConstruct"
#   input: "ResNet/MaxPool2d[maxpool]/1247"
#   input: "ResNet/MaxPool2d[maxpool]/1247"
#   attr {
#     key: "attr"
#     value {
#       s: "{}"
#     }
#   }
# }
# node {
#   name: "ResNet/MaxPool2d[maxpool]/input.7"
#   op: "aten::max_pool2d"
#   input: "ResNet/ReLU[relu]/input.5"
#   input: "ResNet/MaxPool2d[maxpool]/1250"
#   input: "ResNet/MaxPool2d[maxpool]/1251"
#   input: "ResNet/MaxPool2d[maxpool]/1252"
#   input: "ResNet/MaxPool2d[maxpool]/1253"
#   input: "ResNet/MaxPool2d[maxpool]/1246"
#   attr {
#     key: "attr"
#     value {
#       s: "{}"
#     }
#   }
#   attr {
#     key: "_output_shapes"
#     value {
#       list {
#         shape {
#           dim {
#             size: 1
#           }
#           dim {
#             size: 64
#           }
#           dim {
#             size: 56
#           }
#           dim {
#             size: 56
#           }
#         }
#       }
#     }
#   }
# }
# node {
#   name: "ResNet/Sequential[layer1]/BasicBlock[0]/Conv2d[conv1]/1255"
#   op: "prim::Constant"
#   attr {
#     key: "attr"
#     value {
#       s: "{ value : 1}"
#     }
#   }
# }
# node {
#   name: "ResNet/Sequential[layer1]/BasicBlock[0]/Conv2d[conv1]/1256"
#   op: "prim::Constant"
#   attr {
#     key: "attr"
#     value {
#       s: "{ value : 0}"
#     }
#   }
# }
# node {
#   name: "ResNet/Sequential[layer1]/BasicBlock[0]/Conv2d[conv1]/1257"
#   op: "prim::Constant"
#   attr {
#     key: "attr"
#     value {
#       s: "{ value : 0}"
#     }
#   }
# }
# node {
#   name: "ResNet/Sequential[layer1]/BasicBlock[0]/Conv2d[conv1]/1258"
#   op: "prim::Constant"
#   attr {
#     key: "attr"
#     value {
#       s: "{ value : 1}"
#     }
#   }
# }
# node {
#   name: "ResNet/Sequential[layer1]/BasicBlock[0]/Conv2d[conv1]/1259"
#   op: "prim::Constant"
#   attr {
#     key: "attr"
#     value {
#       s: "{}"
#     }
#   }
# }
# node {
#   name: "ResNet/Sequential[layer1]/BasicBlock[0]/BatchNorm2d[bn1]/1260"
#   op: "prim::Constant"
#   attr {
#     key: "attr"
#     value {
#       s: "{ value : 1e-05}"
#     }
#   }
# }
# node {
#   name: "ResNet/Sequential[layer1]/BasicBlock[0]/BatchNorm2d[bn1]/1261"
#   op: "prim::Constant"
#   attr {
#     key: "attr"
#     value {
#       s: "{ value : 0.1}"
#     }
#   }
# }
# node {
#   name: "ResNet/Sequential[layer1]/BasicBlock[0]/Conv2d[conv1]/weight/weight.85"
#   op: "prim::GetAttr"
#   input: "ResNet/Sequential[layer1]/BasicBlock[0]/Conv2d[conv1]/weight/conv1.3"
#   attr {
#     key: "attr"
#     value {
#       s: "{ name :  weight }"
#     }
#   }
# }
# node {
#   name: "ResNet/Sequential[layer1]/BasicBlock[0]/Conv2d[conv1]/1270"
#   op: "prim::ListConstruct"
#   input: "ResNet/Sequential[layer1]/BasicBlock[0]/Conv2d[conv1]/1258"
#   input: "ResNet/Sequential[layer1]/BasicBlock[0]/Conv2d[conv1]/1258"
#   attr {
#     key: "attr"
#     value {
#       s: "{}"
#     }
#   }
# }
# node {
#   name: "ResNet/Sequential[layer1]/BasicBlock[0]/Conv2d[conv1]/1271"
#   op: "prim::ListConstruct"
#   input: "ResNet/Sequential[layer1]/BasicBlock[0]/Conv2d[conv1]/1258"
#   input: "ResNet/Sequential[layer1]/BasicBlock[0]/Conv2d[conv1]/1258"
#   attr {
#     key: "attr"
#     value {
#       s: "{}"
#     }
#   }
# }
# node {
#   name: "ResNet/Sequential[layer1]/BasicBlock[0]/Conv2d[conv1]/1272"
#   op: "prim::ListConstruct"
#   input: "ResNet/Sequential[layer1]/BasicBlock[0]/Conv2d[conv1]/1258"
#   input: "ResNet/Sequential[layer1]/BasicBlock[0]/Conv2d[conv1]/1258"
#   attr {
#     key: "attr"
#     value {
#       s: "{}"
#     }
#   }
# }
# node {
#   name: "ResNet/Sequential[layer1]/BasicBlock[0]/Conv2d[conv1]/1273"
#   op: "prim::ListConstruct"
#   input: "ResNet/Sequential[layer1]/BasicBlock[0]/Conv2d[conv1]/1256"
#   input: "ResNet/Sequential[layer1]/BasicBlock[0]/Conv2d[conv1]/1256"
#   attr {
#     key: "attr"
#     value {
#       s: "{}"
#     }
#   }
# }
# node {
#   name: "ResNet/Sequential[layer1]/BasicBlock[0]/Conv2d[conv1]/input.9"
#   op: "aten::_convolution"
#   input: "ResNet/MaxPool2d[maxpool]/input.7"
#   input: "ResNet/Sequential[layer1]/BasicBlock[0]/Conv2d[conv1]/weight/weight.85"
#   input: "ResNet/Sequential[layer1]/BasicBlock[0]/Conv2d[conv1]/1259"
#   input: "ResNet/Sequential[layer1]/BasicBlock[0]/Conv2d[conv1]/1270"
#   input: "ResNet/Sequential[layer1]/BasicBlock[0]/Conv2d[conv1]/1271"
#   input: "ResNet/Sequential[layer1]/BasicBlock[0]/Conv2d[conv1]/1272"
#   input: "ResNet/Sequential[layer1]/BasicBlock[0]/Conv2d[conv1]/1257"
#   input: "ResNet/Sequential[layer1]/BasicBlock[0]/Conv2d[conv1]/1273"
#   input: "ResNet/Sequential[layer1]/BasicBlock[0]/Conv2d[conv1]/1258"
#   input: "ResNet/Sequential[layer1]/BasicBlock[0]/Conv2d[conv1]/1257"
#   input: "ResNet/Sequential[layer1]/BasicBlock[0]/Conv2d[conv1]/1257"
#   input: "ResNet/Sequential[layer1]/BasicBlock[0]/Conv2d[conv1]/1255"
#   input: "ResNet/Sequential[layer1]/BasicBlock[0]/Conv2d[conv1]/1255"
#   attr {
#     key: "attr"
#     value {
#       s: "{}"
#     }
#   }
#   attr {
#     key: "_output_shapes"
#     value {
#       list {
#         shape {
#           dim {
#             size: 1
#           }
#           dim {
#             size: 64
#           }
#           dim {
#             size: 56
#           }
#           dim {
#             size: 56
#           }
#         }
#       }
#     }
#   }
# }
# node {
#   name: "ResNet/Sequential[layer1]/BasicBlock[0]/BatchNorm2d[bn1]/running_var/running_var.43"
#   op: "prim::GetAttr"
#   input: "ResNet/Sequential[layer1]/BasicBlock[0]/BatchNorm2d[bn1]/weight/bn1.3"
#   attr {
#     key: "attr"
#     value {
#       s: "{ name :  running_var }"
#     }
#   }
# }
# node {
#   name: "ResNet/Sequential[layer1]/BasicBlock[0]/BatchNorm2d[bn1]/running_mean/running_mean.43"
#   op: "prim::GetAttr"
#   input: "ResNet/Sequential[layer1]/BasicBlock[0]/BatchNorm2d[bn1]/weight/bn1.3"
#   attr {
#     key: "attr"
#     value {
#       s: "{ name :  running_mean }"
#     }
#   }
# }
# node {
#   name: "ResNet/Sequential[layer1]/BasicBlock[0]/BatchNorm2d[bn1]/bias/bias.43"
#   op: "prim::GetAttr"
#   input: "ResNet/Sequential[layer1]/BasicBlock[0]/BatchNorm2d[bn1]/weight/bn1.3"
#   attr {
#     key: "attr"
#     value {
#       s: "{ name :  bias }"
#     }
#   }
# }
# node {
#   name: "ResNet/Sequential[layer1]/BasicBlock[0]/BatchNorm2d[bn1]/weight/weight.87"
#   op: "prim::GetAttr"
#   input: "ResNet/Sequential[layer1]/BasicBlock[0]/BatchNorm2d[bn1]/weight/bn1.3"
#   attr {
#     key: "attr"
#     value {
#       s: "{ name :  weight }"
#     }
#   }
# }
# node {
#   name: "ResNet/Sequential[layer1]/BasicBlock[0]/BatchNorm2d[bn1]/input.11"
#   op: "aten::batch_norm"
#   input: "ResNet/Sequential[layer1]/BasicBlock[0]/Conv2d[conv1]/input.9"
#   input: "ResNet/Sequential[layer1]/BasicBlock[0]/BatchNorm2d[bn1]/weight/weight.87"
#   input: "ResNet/Sequential[layer1]/BasicBlock[0]/BatchNorm2d[bn1]/bias/bias.43"
#   input: "ResNet/Sequential[layer1]/BasicBlock[0]/BatchNorm2d[bn1]/running_mean/running_mean.43"
#   input: "ResNet/Sequential[layer1]/BasicBlock[0]/BatchNorm2d[bn1]/running_var/running_var.43"
#   input: "ResNet/Sequential[layer1]/BasicBlock[0]/Conv2d[conv1]/1257"
#   input: "ResNet/Sequential[layer1]/BasicBlock[0]/BatchNorm2d[bn1]/1261"
#   input: "ResNet/Sequential[layer1]/BasicBlock[0]/BatchNorm2d[bn1]/1260"
#   input: "ResNet/Sequential[layer1]/BasicBlock[0]/Conv2d[conv1]/1255"
#   attr {
#     key: "attr"
#     value {
#       s: "{}"
#     }
#   }
#   attr {
#     key: "_output_shapes"
#     value {
#       list {
#         shape {
#           dim {
#             size: 1
#           }
#           dim {
#             size: 64
#           }
#           dim {
#             size: 56
#           }
#           dim {
#             size: 56
#           }
#         }
#       }
#     }
#   }
# }
# node {
#   name: "ResNet/Sequential[layer1]/BasicBlock[0]/ReLU[relu]/input.13"
#   op: "aten::relu_"
#   input: "ResNet/Sequential[layer1]/BasicBlock[0]/BatchNorm2d[bn1]/input.11"
#   attr {
#     key: "attr"
#     value {
#       s: "{}"
#     }
#   }
#   attr {
#     key: "_output_shapes"
#     value {
#       list {
#         shape {
#           dim {
#             size: 1
#           }
#           dim {
#             size: 64
#           }
#           dim {
#             size: 56
#           }
#           dim {
#             size: 56
#           }
#         }
#       }
#     }
#   }
# }
# node {
#   name: "ResNet/Sequential[layer1]/BasicBlock[0]/Conv2d[conv2]/weight/weight.89"
#   op: "prim::GetAttr"
#   input: "ResNet/Sequential[layer1]/BasicBlock[0]/Conv2d[conv2]/weight/conv2.1"
#   attr {
#     key: "attr"
#     value {
#       s: "{ name :  weight }"
#     }
#   }
# }
# node {
#   name: "ResNet/Sequential[layer1]/BasicBlock[0]/Conv2d[conv2]/1282"
#   op: "prim::ListConstruct"
#   input: "ResNet/Sequential[layer1]/BasicBlock[0]/Conv2d[conv1]/1258"
#   input: "ResNet/Sequential[layer1]/BasicBlock[0]/Conv2d[conv1]/1258"
#   attr {
#     key: "attr"
#     value {
#       s: "{}"
#     }
#   }
# }
# node {
#   name: "ResNet/Sequential[layer1]/BasicBlock[0]/Conv2d[conv2]/1283"
#   op: "prim::ListConstruct"
#   input: "ResNet/Sequential[layer1]/BasicBlock[0]/Conv2d[conv1]/1258"
#   input: "ResNet/Sequential[layer1]/BasicBlock[0]/Conv2d[conv1]/1258"
#   attr {
#     key: "attr"
#     value {
#       s: "{}"
#     }
#   }
# }
# node {
#   name: "ResNet/Sequential[layer1]/BasicBlock[0]/Conv2d[conv2]/1284"
#   op: "prim::ListConstruct"
#   input: "ResNet/Sequential[layer1]/BasicBlock[0]/Conv2d[conv1]/1258"
#   input: "ResNet/Sequential[layer1]/BasicBlock[0]/Conv2d[conv1]/1258"
#   attr {
#     key: "attr"
#     value {
#       s: "{}"
#     }
#   }
# }
# node {
#   name: "ResNet/Sequential[layer1]/BasicBlock[0]/Conv2d[conv2]/1285"
#   op: "prim::ListConstruct"
#   input: "ResNet/Sequential[layer1]/BasicBlock[0]/Conv2d[conv1]/1256"
#   input: "ResNet/Sequential[layer1]/BasicBlock[0]/Conv2d[conv1]/1256"
#   attr {
#     key: "attr"
#     value {
#       s: "{}"
#     }
#   }
# }
# node {
#   name: "ResNet/Sequential[layer1]/BasicBlock[0]/Conv2d[conv2]/input.15"
#   op: "aten::_convolution"
#   input: "ResNet/Sequential[layer1]/BasicBlock[0]/ReLU[relu]/input.13"
#   input: "ResNet/Sequential[layer1]/BasicBlock[0]/Conv2d[conv2]/weight/weight.89"
#   input: "ResNet/Sequential[layer1]/BasicBlock[0]/Conv2d[conv1]/1259"
#   input: "ResNet/Sequential[layer1]/BasicBlock[0]/Conv2d[conv2]/1282"
#   input: "ResNet/Sequential[layer1]/BasicBlock[0]/Conv2d[conv2]/1283"
#   input: "ResNet/Sequential[layer1]/BasicBlock[0]/Conv2d[conv2]/1284"
#   input: "ResNet/Sequential[layer1]/BasicBlock[0]/Conv2d[conv1]/1257"
#   input: "ResNet/Sequential[layer1]/BasicBlock[0]/Conv2d[conv2]/1285"
#   input: "ResNet/Sequential[layer1]/BasicBlock[0]/Conv2d[conv1]/1258"
#   input: "ResNet/Sequential[layer1]/BasicBlock[0]/Conv2d[conv1]/1257"
#   input: "ResNet/Sequential[layer1]/BasicBlock[0]/Conv2d[conv1]/1257"
#   input: "ResNet/Sequential[layer1]/BasicBlock[0]/Conv2d[conv1]/1255"
#   input: "ResNet/Sequential[layer1]/BasicBlock[0]/Conv2d[conv1]/1255"
#   attr {
#     key: "attr"
#     value {
#       s: "{}"
#     }
#   }
#   attr {
#     key: "_output_shapes"
#     value {
#       list {
#         shape {
#           dim {
#             size: 1
#           }
#           dim {
#             size: 64
#           }
#           dim {
#             size: 56
#           }
#           dim {
#             size: 56
#           }
#         }
#       }
#     }
#   }
# }
# node {
#   name: "ResNet/Sequential[layer1]/BasicBlock[0]/BatchNorm2d[bn2]/running_var/running_var.45"
#   op: "prim::GetAttr"
#   input: "ResNet/Sequential[layer1]/BasicBlock[0]/BatchNorm2d[bn2]/weight/bn2.1"
#   attr {
#     key: "attr"
#     value {
#       s: "{ name :  running_var }"
#     }
#   }
# }
# node {
#   name: "ResNet/Sequential[layer1]/BasicBlock[0]/BatchNorm2d[bn2]/running_mean/running_mean.45"
#   op: "prim::GetAttr"
#   input: "ResNet/Sequential[layer1]/BasicBlock[0]/BatchNorm2d[bn2]/weight/bn2.1"
#   attr {
#     key: "attr"
#     value {
#       s: "{ name :  running_mean }"
#     }
#   }
# }
# node {
#   name: "ResNet/Sequential[layer1]/BasicBlock[0]/BatchNorm2d[bn2]/bias/bias.45"
#   op: "prim::GetAttr"
#   input: "ResNet/Sequential[layer1]/BasicBlock[0]/BatchNorm2d[bn2]/weight/bn2.1"
#   attr {
#     key: "attr"
#     value {
#       s: "{ name :  bias }"
#     }
#   }
# }
# node {
#   name: "ResNet/Sequential[layer1]/BasicBlock[0]/BatchNorm2d[bn2]/weight/weight.91"
#   op: "prim::GetAttr"
#   input: "ResNet/Sequential[layer1]/BasicBlock[0]/BatchNorm2d[bn2]/weight/bn2.1"
#   attr {
#     key: "attr"
#     value {
#       s: "{ name :  weight }"
#     }
#   }
# }
# node {
#   name: "ResNet/Sequential[layer1]/BasicBlock[0]/BatchNorm2d[bn2]/out.1"
#   op: "aten::batch_norm"
#   input: "ResNet/Sequential[layer1]/BasicBlock[0]/Conv2d[conv2]/input.15"
#   input: "ResNet/Sequential[layer1]/BasicBlock[0]/BatchNorm2d[bn2]/weight/weight.91"
#   input: "ResNet/Sequential[layer1]/BasicBlock[0]/BatchNorm2d[bn2]/bias/bias.45"
#   input: "ResNet/Sequential[layer1]/BasicBlock[0]/BatchNorm2d[bn2]/running_mean/running_mean.45"
#   input: "ResNet/Sequential[layer1]/BasicBlock[0]/BatchNorm2d[bn2]/running_var/running_var.45"
#   input: "ResNet/Sequential[layer1]/BasicBlock[0]/Conv2d[conv1]/1257"
#   input: "ResNet/Sequential[layer1]/BasicBlock[0]/BatchNorm2d[bn1]/1261"
#   input: "ResNet/Sequential[layer1]/BasicBlock[0]/BatchNorm2d[bn1]/1260"
#   input: "ResNet/Sequential[layer1]/BasicBlock[0]/Conv2d[conv1]/1255"
#   attr {
#     key: "attr"
#     value {
#       s: "{}"
#     }
#   }
#   attr {
#     key: "_output_shapes"
#     value {
#       list {
#         shape {
#           dim {
#             size: 1
#           }
#           dim {
#             size: 64
#           }
#           dim {
#             size: 56
#           }
#           dim {
#             size: 56
#           }
#         }
#       }
#     }
#   }
# }
# node {
#   name: "ResNet/Sequential[layer1]/BasicBlock[0]/input.17"
#   op: "aten::add_"
#   input: "ResNet/Sequential[layer1]/BasicBlock[0]/BatchNorm2d[bn2]/out.1"
#   input: "ResNet/MaxPool2d[maxpool]/input.7"
#   input: "ResNet/Sequential[layer1]/BasicBlock[0]/Conv2d[conv1]/1258"
#   attr {
#     key: "attr"
#     value {
#       s: "{}"
#     }
#   }
#   attr {
#     key: "_output_shapes"
#     value {
#       list {
#         shape {
#           dim {
#             size: 1
#           }
#           dim {
#             size: 64
#           }
#           dim {
#             size: 56
#           }
#           dim {
#             size: 56
#           }
#         }
#       }
#     }
#   }
# }
# node {
#   name: "ResNet/Sequential[layer1]/BasicBlock[0]/ReLU[relu]/input.19"
#   op: "aten::relu_"
#   input: "ResNet/Sequential[layer1]/BasicBlock[0]/input.17"
#   attr {
#     key: "attr"
#     value {
#       s: "{}"
#     }
#   }
#   attr {
#     key: "_output_shapes"
#     value {
#       list {
#         shape {
#           dim {
#             size: 1
#           }
#           dim {
#             size: 64
#           }
#           dim {
#             size: 56
#           }
#           dim {
#             size: 56
#           }
#         }
#       }
#     }
#   }
# }
# node {
#   name: "ResNet/Sequential[layer1]/BasicBlock[1]/Conv2d[conv1]/weight/weight.93"
#   op: "prim::GetAttr"
#   input: "ResNet/Sequential[layer1]/BasicBlock[1]/Conv2d[conv1]/weight/conv1.5"
#   attr {
#     key: "attr"
#     value {
#       s: "{ name :  weight }"
#     }
#   }
# }
# node {
#   name: "ResNet/Sequential[layer1]/BasicBlock[1]/Conv2d[conv1]/1300"
#   op: "prim::ListConstruct"
#   input: "ResNet/Sequential[layer1]/BasicBlock[0]/Conv2d[conv1]/1258"
#   input: "ResNet/Sequential[layer1]/BasicBlock[0]/Conv2d[conv1]/1258"
#   attr {
#     key: "attr"
#     value {
#       s: "{}"
#     }
#   }
# }
# node {
#   name: "ResNet/Sequential[layer1]/BasicBlock[1]/Conv2d[conv1]/1301"
#   op: "prim::ListConstruct"
#   input: "ResNet/Sequential[layer1]/BasicBlock[0]/Conv2d[conv1]/1258"
#   input: "ResNet/Sequential[layer1]/BasicBlock[0]/Conv2d[conv1]/1258"
#   attr {
#     key: "attr"
#     value {
#       s: "{}"
#     }
#   }
# }
# node {
#   name: "ResNet/Sequential[layer1]/BasicBlock[1]/Conv2d[conv1]/1302"
#   op: "prim::ListConstruct"
#   input: "ResNet/Sequential[layer1]/BasicBlock[0]/Conv2d[conv1]/1258"
#   input: "ResNet/Sequential[layer1]/BasicBlock[0]/Conv2d[conv1]/1258"
#   attr {
#     key: "attr"
#     value {
#       s: "{}"
#     }
#   }
# }
# node {
#   name: "ResNet/Sequential[layer1]/BasicBlock[1]/Conv2d[conv1]/1303"
#   op: "prim::ListConstruct"
#   input: "ResNet/Sequential[layer1]/BasicBlock[0]/Conv2d[conv1]/1256"
#   input: "ResNet/Sequential[layer1]/BasicBlock[0]/Conv2d[conv1]/1256"
#   attr {
#     key: "attr"
#     value {
#       s: "{}"
#     }
#   }
# }
# node {
#   name: "ResNet/Sequential[layer1]/BasicBlock[1]/Conv2d[conv1]/input.21"
#   op: "aten::_convolution"
#   input: "ResNet/Sequential[layer1]/BasicBlock[0]/ReLU[relu]/input.19"
#   input: "ResNet/Sequential[layer1]/BasicBlock[1]/Conv2d[conv1]/weight/weight.93"
#   input: "ResNet/Sequential[layer1]/BasicBlock[0]/Conv2d[conv1]/1259"
#   input: "ResNet/Sequential[layer1]/BasicBlock[1]/Conv2d[conv1]/1300"
#   input: "ResNet/Sequential[layer1]/BasicBlock[1]/Conv2d[conv1]/1301"
#   input: "ResNet/Sequential[layer1]/BasicBlock[1]/Conv2d[conv1]/1302"
#   input: "ResNet/Sequential[layer1]/BasicBlock[0]/Conv2d[conv1]/1257"
#   input: "ResNet/Sequential[layer1]/BasicBlock[1]/Conv2d[conv1]/1303"
#   input: "ResNet/Sequential[layer1]/BasicBlock[0]/Conv2d[conv1]/1258"
#   input: "ResNet/Sequential[layer1]/BasicBlock[0]/Conv2d[conv1]/1257"
#   input: "ResNet/Sequential[layer1]/BasicBlock[0]/Conv2d[conv1]/1257"
#   input: "ResNet/Sequential[layer1]/BasicBlock[0]/Conv2d[conv1]/1255"
#   input: "ResNet/Sequential[layer1]/BasicBlock[0]/Conv2d[conv1]/1255"
#   attr {
#     key: "attr"
#     value {
#       s: "{}"
#     }
#   }
#   attr {
#     key: "_output_shapes"
#     value {
#       list {
#         shape {
#           dim {
#             size: 1
#           }
#           dim {
#             size: 64
#           }
#           dim {
#             size: 56
#           }
#           dim {
#             size: 56
#           }
#         }
#       }
#     }
#   }
# }
# node {
#   name: "ResNet/Sequential[layer1]/BasicBlock[1]/BatchNorm2d[bn1]/running_var/running_var.47"
#   op: "prim::GetAttr"
#   input: "ResNet/Sequential[layer1]/BasicBlock[1]/BatchNorm2d[bn1]/weight/bn1.5"
#   attr {
#     key: "attr"
#     value {
#       s: "{ name :  running_var }"
#     }
#   }
# }
# node {
#   name: "ResNet/Sequential[layer1]/BasicBlock[1]/BatchNorm2d[bn1]/running_mean/running_mean.47"
#   op: "prim::GetAttr"
#   input: "ResNet/Sequential[layer1]/BasicBlock[1]/BatchNorm2d[bn1]/weight/bn1.5"
#   attr {
#     key: "attr"
#     value {
#       s: "{ name :  running_mean }"
#     }
#   }
# }
# node {
#   name: "ResNet/Sequential[layer1]/BasicBlock[1]/BatchNorm2d[bn1]/bias/bias.47"
#   op: "prim::GetAttr"
#   input: "ResNet/Sequential[layer1]/BasicBlock[1]/BatchNorm2d[bn1]/weight/bn1.5"
#   attr {
#     key: "attr"
#     value {
#       s: "{ name :  bias }"
#     }
#   }
# }
# node {
#   name: "ResNet/Sequential[layer1]/BasicBlock[1]/BatchNorm2d[bn1]/weight/weight.95"
#   op: "prim::GetAttr"
#   input: "ResNet/Sequential[layer1]/BasicBlock[1]/BatchNorm2d[bn1]/weight/bn1.5"
#   attr {
#     key: "attr"
#     value {
#       s: "{ name :  weight }"
#     }
#   }
# }
# node {
#   name: "ResNet/Sequential[layer1]/BasicBlock[1]/BatchNorm2d[bn1]/input.23"
#   op: "aten::batch_norm"
#   input: "ResNet/Sequential[layer1]/BasicBlock[1]/Conv2d[conv1]/input.21"
#   input: "ResNet/Sequential[layer1]/BasicBlock[1]/BatchNorm2d[bn1]/weight/weight.95"
#   input: "ResNet/Sequential[layer1]/BasicBlock[1]/BatchNorm2d[bn1]/bias/bias.47"
#   input: "ResNet/Sequential[layer1]/BasicBlock[1]/BatchNorm2d[bn1]/running_mean/running_mean.47"
#   input: "ResNet/Sequential[layer1]/BasicBlock[1]/BatchNorm2d[bn1]/running_var/running_var.47"
#   input: "ResNet/Sequential[layer1]/BasicBlock[0]/Conv2d[conv1]/1257"
#   input: "ResNet/Sequential[layer1]/BasicBlock[0]/BatchNorm2d[bn1]/1261"
#   input: "ResNet/Sequential[layer1]/BasicBlock[0]/BatchNorm2d[bn1]/1260"
#   input: "ResNet/Sequential[layer1]/BasicBlock[0]/Conv2d[conv1]/1255"
#   attr {
#     key: "attr"
#     value {
#       s: "{}"
#     }
#   }
#   attr {
#     key: "_output_shapes"
#     value {
#       list {
#         shape {
#           dim {
#             size: 1
#           }
#           dim {
#             size: 64
#           }
#           dim {
#             size: 56
#           }
#           dim {
#             size: 56
#           }
#         }
#       }
#     }
#   }
# }
# node {
#   name: "ResNet/Sequential[layer1]/BasicBlock[1]/ReLU[relu]/input.25"
#   op: "aten::relu_"
#   input: "ResNet/Sequential[layer1]/BasicBlock[1]/BatchNorm2d[bn1]/input.23"
#   attr {
#     key: "attr"
#     value {
#       s: "{}"
#     }
#   }
#   attr {
#     key: "_output_shapes"
#     value {
#       list {
#         shape {
#           dim {
#             size: 1
#           }
#           dim {
#             size: 64
#           }
#           dim {
#             size: 56
#           }
#           dim {
#             size: 56
#           }
#         }
#       }
#     }
#   }
# }
# node {
#   name: "ResNet/Sequential[layer1]/BasicBlock[1]/Conv2d[conv2]/weight/weight.97"
#   op: "prim::GetAttr"
#   input: "ResNet/Sequential[layer1]/BasicBlock[1]/Conv2d[conv2]/weight/conv2.3"
#   attr {
#     key: "attr"
#     value {
#       s: "{ name :  weight }"
#     }
#   }
# }
# node {
#   name: "ResNet/Sequential[layer1]/BasicBlock[1]/Conv2d[conv2]/1312"
#   op: "prim::ListConstruct"
#   input: "ResNet/Sequential[layer1]/BasicBlock[0]/Conv2d[conv1]/1258"
#   input: "ResNet/Sequential[layer1]/BasicBlock[0]/Conv2d[conv1]/1258"
#   attr {
#     key: "attr"
#     value {
#       s: "{}"
#     }
#   }
# }
# node {
#   name: "ResNet/Sequential[layer1]/BasicBlock[1]/Conv2d[conv2]/1313"
#   op: "prim::ListConstruct"
#   input: "ResNet/Sequential[layer1]/BasicBlock[0]/Conv2d[conv1]/1258"
#   input: "ResNet/Sequential[layer1]/BasicBlock[0]/Conv2d[conv1]/1258"
#   attr {
#     key: "attr"
#     value {
#       s: "{}"
#     }
#   }
# }
# node {
#   name: "ResNet/Sequential[layer1]/BasicBlock[1]/Conv2d[conv2]/1314"
#   op: "prim::ListConstruct"
#   input: "ResNet/Sequential[layer1]/BasicBlock[0]/Conv2d[conv1]/1258"
#   input: "ResNet/Sequential[layer1]/BasicBlock[0]/Conv2d[conv1]/1258"
#   attr {
#     key: "attr"
#     value {
#       s: "{}"
#     }
#   }
# }
# node {
#   name: "ResNet/Sequential[layer1]/BasicBlock[1]/Conv2d[conv2]/1315"
#   op: "prim::ListConstruct"
#   input: "ResNet/Sequential[layer1]/BasicBlock[0]/Conv2d[conv1]/1256"
#   input: "ResNet/Sequential[layer1]/BasicBlock[0]/Conv2d[conv1]/1256"
#   attr {
#     key: "attr"
#     value {
#       s: "{}"
#     }
#   }
# }
# node {
#   name: "ResNet/Sequential[layer1]/BasicBlock[1]/Conv2d[conv2]/input.27"
#   op: "aten::_convolution"
#   input: "ResNet/Sequential[layer1]/BasicBlock[1]/ReLU[relu]/input.25"
#   input: "ResNet/Sequential[layer1]/BasicBlock[1]/Conv2d[conv2]/weight/weight.97"
#   input: "ResNet/Sequential[layer1]/BasicBlock[0]/Conv2d[conv1]/1259"
#   input: "ResNet/Sequential[layer1]/BasicBlock[1]/Conv2d[conv2]/1312"
#   input: "ResNet/Sequential[layer1]/BasicBlock[1]/Conv2d[conv2]/1313"
#   input: "ResNet/Sequential[layer1]/BasicBlock[1]/Conv2d[conv2]/1314"
#   input: "ResNet/Sequential[layer1]/BasicBlock[0]/Conv2d[conv1]/1257"
#   input: "ResNet/Sequential[layer1]/BasicBlock[1]/Conv2d[conv2]/1315"
#   input: "ResNet/Sequential[layer1]/BasicBlock[0]/Conv2d[conv1]/1258"
#   input: "ResNet/Sequential[layer1]/BasicBlock[0]/Conv2d[conv1]/1257"
#   input: "ResNet/Sequential[layer1]/BasicBlock[0]/Conv2d[conv1]/1257"
#   input: "ResNet/Sequential[layer1]/BasicBlock[0]/Conv2d[conv1]/1255"
#   input: "ResNet/Sequential[layer1]/BasicBlock[0]/Conv2d[conv1]/1255"
#   attr {
#     key: "attr"
#     value {
#       s: "{}"
#     }
#   }
#   attr {
#     key: "_output_shapes"
#     value {
#       list {
#         shape {
#           dim {
#             size: 1
#           }
#           dim {
#             size: 64
#           }
#           dim {
#             size: 56
#           }
#           dim {
#             size: 56
#           }
#         }
#       }
#     }
#   }
# }
# node {
#   name: "ResNet/Sequential[layer1]/BasicBlock[1]/BatchNorm2d[bn2]/running_var/running_var.49"
#   op: "prim::GetAttr"
#   input: "ResNet/Sequential[layer1]/BasicBlock[1]/BatchNorm2d[bn2]/weight/bn2.3"
#   attr {
#     key: "attr"
#     value {
#       s: "{ name :  running_var }"
#     }
#   }
# }
# node {
#   name: "ResNet/Sequential[layer1]/BasicBlock[1]/BatchNorm2d[bn2]/running_mean/running_mean.49"
#   op: "prim::GetAttr"
#   input: "ResNet/Sequential[layer1]/BasicBlock[1]/BatchNorm2d[bn2]/weight/bn2.3"
#   attr {
#     key: "attr"
#     value {
#       s: "{ name :  running_mean }"
#     }
#   }
# }
# node {
#   name: "ResNet/Sequential[layer1]/BasicBlock[1]/BatchNorm2d[bn2]/bias/bias.49"
#   op: "prim::GetAttr"
#   input: "ResNet/Sequential[layer1]/BasicBlock[1]/BatchNorm2d[bn2]/weight/bn2.3"
#   attr {
#     key: "attr"
#     value {
#       s: "{ name :  bias }"
#     }
#   }
# }
# node {
#   name: "ResNet/Sequential[layer1]/BasicBlock[1]/BatchNorm2d[bn2]/weight/weight.99"
#   op: "prim::GetAttr"
#   input: "ResNet/Sequential[layer1]/BasicBlock[1]/BatchNorm2d[bn2]/weight/bn2.3"
#   attr {
#     key: "attr"
#     value {
#       s: "{ name :  weight }"
#     }
#   }
# }
# node {
#   name: "ResNet/Sequential[layer1]/BasicBlock[1]/BatchNorm2d[bn2]/out.3"
#   op: "aten::batch_norm"
#   input: "ResNet/Sequential[layer1]/BasicBlock[1]/Conv2d[conv2]/input.27"
#   input: "ResNet/Sequential[layer1]/BasicBlock[1]/BatchNorm2d[bn2]/weight/weight.99"
#   input: "ResNet/Sequential[layer1]/BasicBlock[1]/BatchNorm2d[bn2]/bias/bias.49"
#   input: "ResNet/Sequential[layer1]/BasicBlock[1]/BatchNorm2d[bn2]/running_mean/running_mean.49"
#   input: "ResNet/Sequential[layer1]/BasicBlock[1]/BatchNorm2d[bn2]/running_var/running_var.49"
#   input: "ResNet/Sequential[layer1]/BasicBlock[0]/Conv2d[conv1]/1257"
#   input: "ResNet/Sequential[layer1]/BasicBlock[0]/BatchNorm2d[bn1]/1261"
#   input: "ResNet/Sequential[layer1]/BasicBlock[0]/BatchNorm2d[bn1]/1260"
#   input: "ResNet/Sequential[layer1]/BasicBlock[0]/Conv2d[conv1]/1255"
#   attr {
#     key: "attr"
#     value {
#       s: "{}"
#     }
#   }
#   attr {
#     key: "_output_shapes"
#     value {
#       list {
#         shape {
#           dim {
#             size: 1
#           }
#           dim {
#             size: 64
#           }
#           dim {
#             size: 56
#           }
#           dim {
#             size: 56
#           }
#         }
#       }
#     }
#   }
# }
# node {
#   name: "ResNet/Sequential[layer1]/BasicBlock[1]/input.29"
#   op: "aten::add_"
#   input: "ResNet/Sequential[layer1]/BasicBlock[1]/BatchNorm2d[bn2]/out.3"
#   input: "ResNet/Sequential[layer1]/BasicBlock[0]/ReLU[relu]/input.19"
#   input: "ResNet/Sequential[layer1]/BasicBlock[0]/Conv2d[conv1]/1258"
#   attr {
#     key: "attr"
#     value {
#       s: "{}"
#     }
#   }
#   attr {
#     key: "_output_shapes"
#     value {
#       list {
#         shape {
#           dim {
#             size: 1
#           }
#           dim {
#             size: 64
#           }
#           dim {
#             size: 56
#           }
#           dim {
#             size: 56
#           }
#         }
#       }
#     }
#   }
# }
# node {
#   name: "ResNet/Sequential[layer1]/BasicBlock[1]/ReLU[relu]/input.31"
#   op: "aten::relu_"
#   input: "ResNet/Sequential[layer1]/BasicBlock[1]/input.29"
#   attr {
#     key: "attr"
#     value {
#       s: "{}"
#     }
#   }
#   attr {
#     key: "_output_shapes"
#     value {
#       list {
#         shape {
#           dim {
#             size: 1
#           }
#           dim {
#             size: 64
#           }
#           dim {
#             size: 56
#           }
#           dim {
#             size: 56
#           }
#         }
#       }
#     }
#   }
# }
# node {
#   name: "ResNet/Sequential[layer2]/BasicBlock[0]/Conv2d[conv1]/1324"
#   op: "prim::Constant"
#   attr {
#     key: "attr"
#     value {
#       s: "{ value : 1}"
#     }
#   }
# }
# node {
#   name: "ResNet/Sequential[layer2]/BasicBlock[0]/Conv2d[conv1]/1325"
#   op: "prim::Constant"
#   attr {
#     key: "attr"
#     value {
#       s: "{ value : 0}"
#     }
#   }
# }
# node {
#   name: "ResNet/Sequential[layer2]/BasicBlock[0]/Conv2d[conv1]/1326"
#   op: "prim::Constant"
#   attr {
#     key: "attr"
#     value {
#       s: "{ value : 0}"
#     }
#   }
# }
# node {
#   name: "ResNet/Sequential[layer2]/BasicBlock[0]/Conv2d[conv1]/1327"
#   op: "prim::Constant"
#   attr {
#     key: "attr"
#     value {
#       s: "{ value : 1}"
#     }
#   }
# }
# node {
#   name: "ResNet/Sequential[layer2]/BasicBlock[0]/Conv2d[conv1]/1328"
#   op: "prim::Constant"
#   attr {
#     key: "attr"
#     value {
#       s: "{ value : 2}"
#     }
#   }
# }
# node {
#   name: "ResNet/Sequential[layer2]/BasicBlock[0]/Conv2d[conv1]/1329"
#   op: "prim::Constant"
#   attr {
#     key: "attr"
#     value {
#       s: "{}"
#     }
#   }
# }
# node {
#   name: "ResNet/Sequential[layer2]/BasicBlock[0]/BatchNorm2d[bn1]/1330"
#   op: "prim::Constant"
#   attr {
#     key: "attr"
#     value {
#       s: "{ value : 1e-05}"
#     }
#   }
# }
# node {
#   name: "ResNet/Sequential[layer2]/BasicBlock[0]/BatchNorm2d[bn1]/1331"
#   op: "prim::Constant"
#   attr {
#     key: "attr"
#     value {
#       s: "{ value : 0.1}"
#     }
#   }
# }
# node {
#   name: "ResNet/Sequential[layer2]/BasicBlock[0]/Conv2d[conv1]/weight/weight.101"
#   op: "prim::GetAttr"
#   input: "ResNet/Sequential[layer2]/BasicBlock[0]/Conv2d[conv1]/weight/conv1.7"
#   attr {
#     key: "attr"
#     value {
#       s: "{ name :  weight }"
#     }
#   }
# }
# node {
#   name: "ResNet/Sequential[layer2]/BasicBlock[0]/Conv2d[conv1]/1341"
#   op: "prim::ListConstruct"
#   input: "ResNet/Sequential[layer2]/BasicBlock[0]/Conv2d[conv1]/1328"
#   input: "ResNet/Sequential[layer2]/BasicBlock[0]/Conv2d[conv1]/1328"
#   attr {
#     key: "attr"
#     value {
#       s: "{}"
#     }
#   }
# }
# node {
#   name: "ResNet/Sequential[layer2]/BasicBlock[0]/Conv2d[conv1]/1342"
#   op: "prim::ListConstruct"
#   input: "ResNet/Sequential[layer2]/BasicBlock[0]/Conv2d[conv1]/1327"
#   input: "ResNet/Sequential[layer2]/BasicBlock[0]/Conv2d[conv1]/1327"
#   attr {
#     key: "attr"
#     value {
#       s: "{}"
#     }
#   }
# }
# node {
#   name: "ResNet/Sequential[layer2]/BasicBlock[0]/Conv2d[conv1]/1343"
#   op: "prim::ListConstruct"
#   input: "ResNet/Sequential[layer2]/BasicBlock[0]/Conv2d[conv1]/1327"
#   input: "ResNet/Sequential[layer2]/BasicBlock[0]/Conv2d[conv1]/1327"
#   attr {
#     key: "attr"
#     value {
#       s: "{}"
#     }
#   }
# }
# node {
#   name: "ResNet/Sequential[layer2]/BasicBlock[0]/Conv2d[conv1]/1344"
#   op: "prim::ListConstruct"
#   input: "ResNet/Sequential[layer2]/BasicBlock[0]/Conv2d[conv1]/1325"
#   input: "ResNet/Sequential[layer2]/BasicBlock[0]/Conv2d[conv1]/1325"
#   attr {
#     key: "attr"
#     value {
#       s: "{}"
#     }
#   }
# }
# node {
#   name: "ResNet/Sequential[layer2]/BasicBlock[0]/Conv2d[conv1]/input.33"
#   op: "aten::_convolution"
#   input: "ResNet/Sequential[layer1]/BasicBlock[1]/ReLU[relu]/input.31"
#   input: "ResNet/Sequential[layer2]/BasicBlock[0]/Conv2d[conv1]/weight/weight.101"
#   input: "ResNet/Sequential[layer2]/BasicBlock[0]/Conv2d[conv1]/1329"
#   input: "ResNet/Sequential[layer2]/BasicBlock[0]/Conv2d[conv1]/1341"
#   input: "ResNet/Sequential[layer2]/BasicBlock[0]/Conv2d[conv1]/1342"
#   input: "ResNet/Sequential[layer2]/BasicBlock[0]/Conv2d[conv1]/1343"
#   input: "ResNet/Sequential[layer2]/BasicBlock[0]/Conv2d[conv1]/1326"
#   input: "ResNet/Sequential[layer2]/BasicBlock[0]/Conv2d[conv1]/1344"
#   input: "ResNet/Sequential[layer2]/BasicBlock[0]/Conv2d[conv1]/1327"
#   input: "ResNet/Sequential[layer2]/BasicBlock[0]/Conv2d[conv1]/1326"
#   input: "ResNet/Sequential[layer2]/BasicBlock[0]/Conv2d[conv1]/1326"
#   input: "ResNet/Sequential[layer2]/BasicBlock[0]/Conv2d[conv1]/1324"
#   input: "ResNet/Sequential[layer2]/BasicBlock[0]/Conv2d[conv1]/1324"
#   attr {
#     key: "attr"
#     value {
#       s: "{}"
#     }
#   }
#   attr {
#     key: "_output_shapes"
#     value {
#       list {
#         shape {
#           dim {
#             size: 1
#           }
#           dim {
#             size: 128
#           }
#           dim {
#             size: 28
#           }
#           dim {
#             size: 28
#           }
#         }
#       }
#     }
#   }
# }
# node {
#   name: "ResNet/Sequential[layer2]/BasicBlock[0]/BatchNorm2d[bn1]/running_var/running_var.51"
#   op: "prim::GetAttr"
#   input: "ResNet/Sequential[layer2]/BasicBlock[0]/BatchNorm2d[bn1]/weight/bn1.7"
#   attr {
#     key: "attr"
#     value {
#       s: "{ name :  running_var }"
#     }
#   }
# }
# node {
#   name: "ResNet/Sequential[layer2]/BasicBlock[0]/BatchNorm2d[bn1]/running_mean/running_mean.51"
#   op: "prim::GetAttr"
#   input: "ResNet/Sequential[layer2]/BasicBlock[0]/BatchNorm2d[bn1]/weight/bn1.7"
#   attr {
#     key: "attr"
#     value {
#       s: "{ name :  running_mean }"
#     }
#   }
# }
# node {
#   name: "ResNet/Sequential[layer2]/BasicBlock[0]/BatchNorm2d[bn1]/bias/bias.51"
#   op: "prim::GetAttr"
#   input: "ResNet/Sequential[layer2]/BasicBlock[0]/BatchNorm2d[bn1]/weight/bn1.7"
#   attr {
#     key: "attr"
#     value {
#       s: "{ name :  bias }"
#     }
#   }
# }
# node {
#   name: "ResNet/Sequential[layer2]/BasicBlock[0]/BatchNorm2d[bn1]/weight/weight.103"
#   op: "prim::GetAttr"
#   input: "ResNet/Sequential[layer2]/BasicBlock[0]/BatchNorm2d[bn1]/weight/bn1.7"
#   attr {
#     key: "attr"
#     value {
#       s: "{ name :  weight }"
#     }
#   }
# }
# node {
#   name: "ResNet/Sequential[layer2]/BasicBlock[0]/BatchNorm2d[bn1]/input.35"
#   op: "aten::batch_norm"
#   input: "ResNet/Sequential[layer2]/BasicBlock[0]/Conv2d[conv1]/input.33"
#   input: "ResNet/Sequential[layer2]/BasicBlock[0]/BatchNorm2d[bn1]/weight/weight.103"
#   input: "ResNet/Sequential[layer2]/BasicBlock[0]/BatchNorm2d[bn1]/bias/bias.51"
#   input: "ResNet/Sequential[layer2]/BasicBlock[0]/BatchNorm2d[bn1]/running_mean/running_mean.51"
#   input: "ResNet/Sequential[layer2]/BasicBlock[0]/BatchNorm2d[bn1]/running_var/running_var.51"
#   input: "ResNet/Sequential[layer2]/BasicBlock[0]/Conv2d[conv1]/1326"
#   input: "ResNet/Sequential[layer2]/BasicBlock[0]/BatchNorm2d[bn1]/1331"
#   input: "ResNet/Sequential[layer2]/BasicBlock[0]/BatchNorm2d[bn1]/1330"
#   input: "ResNet/Sequential[layer2]/BasicBlock[0]/Conv2d[conv1]/1324"
#   attr {
#     key: "attr"
#     value {
#       s: "{}"
#     }
#   }
#   attr {
#     key: "_output_shapes"
#     value {
#       list {
#         shape {
#           dim {
#             size: 1
#           }
#           dim {
#             size: 128
#           }
#           dim {
#             size: 28
#           }
#           dim {
#             size: 28
#           }
#         }
#       }
#     }
#   }
# }
# node {
#   name: "ResNet/Sequential[layer2]/BasicBlock[0]/ReLU[relu]/input.37"
#   op: "aten::relu_"
#   input: "ResNet/Sequential[layer2]/BasicBlock[0]/BatchNorm2d[bn1]/input.35"
#   attr {
#     key: "attr"
#     value {
#       s: "{}"
#     }
#   }
#   attr {
#     key: "_output_shapes"
#     value {
#       list {
#         shape {
#           dim {
#             size: 1
#           }
#           dim {
#             size: 128
#           }
#           dim {
#             size: 28
#           }
#           dim {
#             size: 28
#           }
#         }
#       }
#     }
#   }
# }
# node {
#   name: "ResNet/Sequential[layer2]/BasicBlock[0]/Conv2d[conv2]/weight/weight.105"
#   op: "prim::GetAttr"
#   input: "ResNet/Sequential[layer2]/BasicBlock[0]/Conv2d[conv2]/weight/conv2.5"
#   attr {
#     key: "attr"
#     value {
#       s: "{ name :  weight }"
#     }
#   }
# }
# node {
#   name: "ResNet/Sequential[layer2]/BasicBlock[0]/Conv2d[conv2]/1353"
#   op: "prim::ListConstruct"
#   input: "ResNet/Sequential[layer2]/BasicBlock[0]/Conv2d[conv1]/1327"
#   input: "ResNet/Sequential[layer2]/BasicBlock[0]/Conv2d[conv1]/1327"
#   attr {
#     key: "attr"
#     value {
#       s: "{}"
#     }
#   }
# }
# node {
#   name: "ResNet/Sequential[layer2]/BasicBlock[0]/Conv2d[conv2]/1354"
#   op: "prim::ListConstruct"
#   input: "ResNet/Sequential[layer2]/BasicBlock[0]/Conv2d[conv1]/1327"
#   input: "ResNet/Sequential[layer2]/BasicBlock[0]/Conv2d[conv1]/1327"
#   attr {
#     key: "attr"
#     value {
#       s: "{}"
#     }
#   }
# }
# node {
#   name: "ResNet/Sequential[layer2]/BasicBlock[0]/Conv2d[conv2]/1355"
#   op: "prim::ListConstruct"
#   input: "ResNet/Sequential[layer2]/BasicBlock[0]/Conv2d[conv1]/1327"
#   input: "ResNet/Sequential[layer2]/BasicBlock[0]/Conv2d[conv1]/1327"
#   attr {
#     key: "attr"
#     value {
#       s: "{}"
#     }
#   }
# }
# node {
#   name: "ResNet/Sequential[layer2]/BasicBlock[0]/Conv2d[conv2]/1356"
#   op: "prim::ListConstruct"
#   input: "ResNet/Sequential[layer2]/BasicBlock[0]/Conv2d[conv1]/1325"
#   input: "ResNet/Sequential[layer2]/BasicBlock[0]/Conv2d[conv1]/1325"
#   attr {
#     key: "attr"
#     value {
#       s: "{}"
#     }
#   }
# }
# node {
#   name: "ResNet/Sequential[layer2]/BasicBlock[0]/Conv2d[conv2]/input.39"
#   op: "aten::_convolution"
#   input: "ResNet/Sequential[layer2]/BasicBlock[0]/ReLU[relu]/input.37"
#   input: "ResNet/Sequential[layer2]/BasicBlock[0]/Conv2d[conv2]/weight/weight.105"
#   input: "ResNet/Sequential[layer2]/BasicBlock[0]/Conv2d[conv1]/1329"
#   input: "ResNet/Sequential[layer2]/BasicBlock[0]/Conv2d[conv2]/1353"
#   input: "ResNet/Sequential[layer2]/BasicBlock[0]/Conv2d[conv2]/1354"
#   input: "ResNet/Sequential[layer2]/BasicBlock[0]/Conv2d[conv2]/1355"
#   input: "ResNet/Sequential[layer2]/BasicBlock[0]/Conv2d[conv1]/1326"
#   input: "ResNet/Sequential[layer2]/BasicBlock[0]/Conv2d[conv2]/1356"
#   input: "ResNet/Sequential[layer2]/BasicBlock[0]/Conv2d[conv1]/1327"
#   input: "ResNet/Sequential[layer2]/BasicBlock[0]/Conv2d[conv1]/1326"
#   input: "ResNet/Sequential[layer2]/BasicBlock[0]/Conv2d[conv1]/1326"
#   input: "ResNet/Sequential[layer2]/BasicBlock[0]/Conv2d[conv1]/1324"
#   input: "ResNet/Sequential[layer2]/BasicBlock[0]/Conv2d[conv1]/1324"
#   attr {
#     key: "attr"
#     value {
#       s: "{}"
#     }
#   }
#   attr {
#     key: "_output_shapes"
#     value {
#       list {
#         shape {
#           dim {
#             size: 1
#           }
#           dim {
#             size: 128
#           }
#           dim {
#             size: 28
#           }
#           dim {
#             size: 28
#           }
#         }
#       }
#     }
#   }
# }
# node {
#   name: "ResNet/Sequential[layer2]/BasicBlock[0]/BatchNorm2d[bn2]/running_var/running_var.53"
#   op: "prim::GetAttr"
#   input: "ResNet/Sequential[layer2]/BasicBlock[0]/BatchNorm2d[bn2]/weight/bn2.5"
#   attr {
#     key: "attr"
#     value {
#       s: "{ name :  running_var }"
#     }
#   }
# }
# node {
#   name: "ResNet/Sequential[layer2]/BasicBlock[0]/BatchNorm2d[bn2]/running_mean/running_mean.53"
#   op: "prim::GetAttr"
#   input: "ResNet/Sequential[layer2]/BasicBlock[0]/BatchNorm2d[bn2]/weight/bn2.5"
#   attr {
#     key: "attr"
#     value {
#       s: "{ name :  running_mean }"
#     }
#   }
# }
# node {
#   name: "ResNet/Sequential[layer2]/BasicBlock[0]/BatchNorm2d[bn2]/bias/bias.53"
#   op: "prim::GetAttr"
#   input: "ResNet/Sequential[layer2]/BasicBlock[0]/BatchNorm2d[bn2]/weight/bn2.5"
#   attr {
#     key: "attr"
#     value {
#       s: "{ name :  bias }"
#     }
#   }
# }
# node {
#   name: "ResNet/Sequential[layer2]/BasicBlock[0]/BatchNorm2d[bn2]/weight/weight.107"
#   op: "prim::GetAttr"
#   input: "ResNet/Sequential[layer2]/BasicBlock[0]/BatchNorm2d[bn2]/weight/bn2.5"
#   attr {
#     key: "attr"
#     value {
#       s: "{ name :  weight }"
#     }
#   }
# }
# node {
#   name: "ResNet/Sequential[layer2]/BasicBlock[0]/BatchNorm2d[bn2]/out.5"
#   op: "aten::batch_norm"
#   input: "ResNet/Sequential[layer2]/BasicBlock[0]/Conv2d[conv2]/input.39"
#   input: "ResNet/Sequential[layer2]/BasicBlock[0]/BatchNorm2d[bn2]/weight/weight.107"
#   input: "ResNet/Sequential[layer2]/BasicBlock[0]/BatchNorm2d[bn2]/bias/bias.53"
#   input: "ResNet/Sequential[layer2]/BasicBlock[0]/BatchNorm2d[bn2]/running_mean/running_mean.53"
#   input: "ResNet/Sequential[layer2]/BasicBlock[0]/BatchNorm2d[bn2]/running_var/running_var.53"
#   input: "ResNet/Sequential[layer2]/BasicBlock[0]/Conv2d[conv1]/1326"
#   input: "ResNet/Sequential[layer2]/BasicBlock[0]/BatchNorm2d[bn1]/1331"
#   input: "ResNet/Sequential[layer2]/BasicBlock[0]/BatchNorm2d[bn1]/1330"
#   input: "ResNet/Sequential[layer2]/BasicBlock[0]/Conv2d[conv1]/1324"
#   attr {
#     key: "attr"
#     value {
#       s: "{}"
#     }
#   }
#   attr {
#     key: "_output_shapes"
#     value {
#       list {
#         shape {
#           dim {
#             size: 1
#           }
#           dim {
#             size: 128
#           }
#           dim {
#             size: 28
#           }
#           dim {
#             size: 28
#           }
#         }
#       }
#     }
#   }
# }
# node {
#   name: "ResNet/Sequential[layer2]/BasicBlock[0]/Sequential[downsample]/Conv2d[0]/weight/weight.109"
#   op: "prim::GetAttr"
#   input: "ResNet/Sequential[layer2]/BasicBlock[0]/Sequential[downsample]/Conv2d[0]/weight/_0.3"
#   attr {
#     key: "attr"
#     value {
#       s: "{ name :  weight }"
#     }
#   }
# }
# node {
#   name: "ResNet/Sequential[layer2]/BasicBlock[0]/Sequential[downsample]/Conv2d[0]/1366"
#   op: "prim::ListConstruct"
#   input: "ResNet/Sequential[layer2]/BasicBlock[0]/Conv2d[conv1]/1328"
#   input: "ResNet/Sequential[layer2]/BasicBlock[0]/Conv2d[conv1]/1328"
#   attr {
#     key: "attr"
#     value {
#       s: "{}"
#     }
#   }
# }
# node {
#   name: "ResNet/Sequential[layer2]/BasicBlock[0]/Sequential[downsample]/Conv2d[0]/1367"
#   op: "prim::ListConstruct"
#   input: "ResNet/Sequential[layer2]/BasicBlock[0]/Conv2d[conv1]/1325"
#   input: "ResNet/Sequential[layer2]/BasicBlock[0]/Conv2d[conv1]/1325"
#   attr {
#     key: "attr"
#     value {
#       s: "{}"
#     }
#   }
# }
# node {
#   name: "ResNet/Sequential[layer2]/BasicBlock[0]/Sequential[downsample]/Conv2d[0]/1368"
#   op: "prim::ListConstruct"
#   input: "ResNet/Sequential[layer2]/BasicBlock[0]/Conv2d[conv1]/1327"
#   input: "ResNet/Sequential[layer2]/BasicBlock[0]/Conv2d[conv1]/1327"
#   attr {
#     key: "attr"
#     value {
#       s: "{}"
#     }
#   }
# }
# node {
#   name: "ResNet/Sequential[layer2]/BasicBlock[0]/Sequential[downsample]/Conv2d[0]/1369"
#   op: "prim::ListConstruct"
#   input: "ResNet/Sequential[layer2]/BasicBlock[0]/Conv2d[conv1]/1325"
#   input: "ResNet/Sequential[layer2]/BasicBlock[0]/Conv2d[conv1]/1325"
#   attr {
#     key: "attr"
#     value {
#       s: "{}"
#     }
#   }
# }
# node {
#   name: "ResNet/Sequential[layer2]/BasicBlock[0]/Sequential[downsample]/Conv2d[0]/input.41"
#   op: "aten::_convolution"
# ...
#       list {
#         shape {
#           dim {
#             size: 1
#           }
#           dim {
#             size: 512
#           }
#           dim {
#             size: 7
#           }
#           dim {
#             size: 7
#           }
#         }
#       }
#     }
#   }
# }
# node {
#   name: "ResNet/Sequential[layer4]/BasicBlock[0]/input.95"
#   op: "aten::add_"
#   input: "ResNet/Sequential[layer4]/BasicBlock[0]/BatchNorm2d[bn2]/out.13"
#   input: "ResNet/Sequential[layer4]/BasicBlock[0]/Sequential[downsample]/BatchNorm2d[1]/identity"
#   input: "ResNet/Sequential[layer4]/BasicBlock[0]/Conv2d[conv1]/1495"
#   attr {
#     key: "attr"
#     value {
#       s: "{}"
#     }
#   }
#   attr {
#     key: "_output_shapes"
#     value {
#       list {
#         shape {
#           dim {
#             size: 1
#           }
#           dim {
#             size: 512
#           }
#           dim {
#             size: 7
#           }
#           dim {
#             size: 7
#           }
#         }
#       }
#     }
#   }
# }
# node {
#   name: "ResNet/Sequential[layer4]/BasicBlock[0]/ReLU[relu]/input.97"
#   op: "aten::relu_"
#   input: "ResNet/Sequential[layer4]/BasicBlock[0]/input.95"
#   attr {
#     key: "attr"
#     value {
#       s: "{}"
#     }
#   }
#   attr {
#     key: "_output_shapes"
#     value {
#       list {
#         shape {
#           dim {
#             size: 1
#           }
#           dim {
#             size: 512
#           }
#           dim {
#             size: 7
#           }
#           dim {
#             size: 7
#           }
#         }
#       }
#     }
#   }
# }
# node {
#   name: "ResNet/Sequential[layer4]/BasicBlock[1]/Conv2d[conv1]/weight/weight.153"
#   op: "prim::GetAttr"
#   input: "ResNet/Sequential[layer4]/BasicBlock[1]/Conv2d[conv1]/weight/conv1"
#   attr {
#     key: "attr"
#     value {
#       s: "{ name :  weight }"
#     }
#   }
# }
# node {
#   name: "ResNet/Sequential[layer4]/BasicBlock[1]/Conv2d[conv1]/1552"
#   op: "prim::ListConstruct"
#   input: "ResNet/Sequential[layer4]/BasicBlock[0]/Conv2d[conv1]/1495"
#   input: "ResNet/Sequential[layer4]/BasicBlock[0]/Conv2d[conv1]/1495"
#   attr {
#     key: "attr"
#     value {
#       s: "{}"
#     }
#   }
# }
# node {
#   name: "ResNet/Sequential[layer4]/BasicBlock[1]/Conv2d[conv1]/1553"
#   op: "prim::ListConstruct"
#   input: "ResNet/Sequential[layer4]/BasicBlock[0]/Conv2d[conv1]/1495"
#   input: "ResNet/Sequential[layer4]/BasicBlock[0]/Conv2d[conv1]/1495"
#   attr {
#     key: "attr"
#     value {
#       s: "{}"
#     }
#   }
# }
# node {
#   name: "ResNet/Sequential[layer4]/BasicBlock[1]/Conv2d[conv1]/1554"
#   op: "prim::ListConstruct"
#   input: "ResNet/Sequential[layer4]/BasicBlock[0]/Conv2d[conv1]/1495"
#   input: "ResNet/Sequential[layer4]/BasicBlock[0]/Conv2d[conv1]/1495"
#   attr {
#     key: "attr"
#     value {
#       s: "{}"
#     }
#   }
# }
# node {
#   name: "ResNet/Sequential[layer4]/BasicBlock[1]/Conv2d[conv1]/1555"
#   op: "prim::ListConstruct"
#   input: "ResNet/Sequential[layer4]/BasicBlock[0]/Conv2d[conv1]/1493"
#   input: "ResNet/Sequential[layer4]/BasicBlock[0]/Conv2d[conv1]/1493"
#   attr {
#     key: "attr"
#     value {
#       s: "{}"
#     }
#   }
# }
# node {
#   name: "ResNet/Sequential[layer4]/BasicBlock[1]/Conv2d[conv1]/input.99"
#   op: "aten::_convolution"
#   input: "ResNet/Sequential[layer4]/BasicBlock[0]/ReLU[relu]/input.97"
#   input: "ResNet/Sequential[layer4]/BasicBlock[1]/Conv2d[conv1]/weight/weight.153"
#   input: "ResNet/Sequential[layer4]/BasicBlock[0]/Conv2d[conv1]/1497"
#   input: "ResNet/Sequential[layer4]/BasicBlock[1]/Conv2d[conv1]/1552"
#   input: "ResNet/Sequential[layer4]/BasicBlock[1]/Conv2d[conv1]/1553"
#   input: "ResNet/Sequential[layer4]/BasicBlock[1]/Conv2d[conv1]/1554"
#   input: "ResNet/Sequential[layer4]/BasicBlock[0]/Conv2d[conv1]/1494"
#   input: "ResNet/Sequential[layer4]/BasicBlock[1]/Conv2d[conv1]/1555"
#   input: "ResNet/Sequential[layer4]/BasicBlock[0]/Conv2d[conv1]/1495"
#   input: "ResNet/Sequential[layer4]/BasicBlock[0]/Conv2d[conv1]/1494"
#   input: "ResNet/Sequential[layer4]/BasicBlock[0]/Conv2d[conv1]/1494"
#   input: "ResNet/Sequential[layer4]/BasicBlock[0]/Conv2d[conv1]/1492"
#   input: "ResNet/Sequential[layer4]/BasicBlock[0]/Conv2d[conv1]/1492"
#   attr {
#     key: "attr"
#     value {
#       s: "{}"
#     }
#   }
#   attr {
#     key: "_output_shapes"
#     value {
#       list {
#         shape {
#           dim {
#             size: 1
#           }
#           dim {
#             size: 512
#           }
#           dim {
#             size: 7
#           }
#           dim {
#             size: 7
#           }
#         }
#       }
#     }
#   }
# }
# node {
#   name: "ResNet/Sequential[layer4]/BasicBlock[1]/BatchNorm2d[bn1]/running_var/running_var.77"
#   op: "prim::GetAttr"
#   input: "ResNet/Sequential[layer4]/BasicBlock[1]/BatchNorm2d[bn1]/weight/bn1"
#   attr {
#     key: "attr"
#     value {
#       s: "{ name :  running_var }"
#     }
#   }
# }
# node {
#   name: "ResNet/Sequential[layer4]/BasicBlock[1]/BatchNorm2d[bn1]/running_mean/running_mean.77"
#   op: "prim::GetAttr"
#   input: "ResNet/Sequential[layer4]/BasicBlock[1]/BatchNorm2d[bn1]/weight/bn1"
#   attr {
#     key: "attr"
#     value {
#       s: "{ name :  running_mean }"
#     }
#   }
# }
# node {
#   name: "ResNet/Sequential[layer4]/BasicBlock[1]/BatchNorm2d[bn1]/bias/bias.77"
#   op: "prim::GetAttr"
#   input: "ResNet/Sequential[layer4]/BasicBlock[1]/BatchNorm2d[bn1]/weight/bn1"
#   attr {
#     key: "attr"
#     value {
#       s: "{ name :  bias }"
#     }
#   }
# }
# node {
#   name: "ResNet/Sequential[layer4]/BasicBlock[1]/BatchNorm2d[bn1]/weight/weight.155"
#   op: "prim::GetAttr"
#   input: "ResNet/Sequential[layer4]/BasicBlock[1]/BatchNorm2d[bn1]/weight/bn1"
#   attr {
#     key: "attr"
#     value {
#       s: "{ name :  weight }"
#     }
#   }
# }
# node {
#   name: "ResNet/Sequential[layer4]/BasicBlock[1]/BatchNorm2d[bn1]/input.101"
#   op: "aten::batch_norm"
#   input: "ResNet/Sequential[layer4]/BasicBlock[1]/Conv2d[conv1]/input.99"
#   input: "ResNet/Sequential[layer4]/BasicBlock[1]/BatchNorm2d[bn1]/weight/weight.155"
#   input: "ResNet/Sequential[layer4]/BasicBlock[1]/BatchNorm2d[bn1]/bias/bias.77"
#   input: "ResNet/Sequential[layer4]/BasicBlock[1]/BatchNorm2d[bn1]/running_mean/running_mean.77"
#   input: "ResNet/Sequential[layer4]/BasicBlock[1]/BatchNorm2d[bn1]/running_var/running_var.77"
#   input: "ResNet/Sequential[layer4]/BasicBlock[0]/Conv2d[conv1]/1494"
#   input: "ResNet/Sequential[layer4]/BasicBlock[0]/BatchNorm2d[bn1]/1499"
#   input: "ResNet/Sequential[layer4]/BasicBlock[0]/BatchNorm2d[bn1]/1498"
#   input: "ResNet/Sequential[layer4]/BasicBlock[0]/Conv2d[conv1]/1492"
#   attr {
#     key: "attr"
#     value {
#       s: "{}"
#     }
#   }
#   attr {
#     key: "_output_shapes"
#     value {
#       list {
#         shape {
#           dim {
#             size: 1
#           }
#           dim {
#             size: 512
#           }
#           dim {
#             size: 7
#           }
#           dim {
#             size: 7
#           }
#         }
#       }
#     }
#   }
# }
# node {
#   name: "ResNet/Sequential[layer4]/BasicBlock[1]/ReLU[relu]/input.103"
#   op: "aten::relu_"
#   input: "ResNet/Sequential[layer4]/BasicBlock[1]/BatchNorm2d[bn1]/input.101"
#   attr {
#     key: "attr"
#     value {
#       s: "{}"
#     }
#   }
#   attr {
#     key: "_output_shapes"
#     value {
#       list {
#         shape {
#           dim {
#             size: 1
#           }
#           dim {
#             size: 512
#           }
#           dim {
#             size: 7
#           }
#           dim {
#             size: 7
#           }
#         }
#       }
#     }
#   }
# }
# node {
#   name: "ResNet/Sequential[layer4]/BasicBlock[1]/Conv2d[conv2]/weight/weight.157"
#   op: "prim::GetAttr"
#   input: "ResNet/Sequential[layer4]/BasicBlock[1]/Conv2d[conv2]/weight/conv2"
#   attr {
#     key: "attr"
#     value {
#       s: "{ name :  weight }"
#     }
#   }
# }
# node {
#   name: "ResNet/Sequential[layer4]/BasicBlock[1]/Conv2d[conv2]/1564"
#   op: "prim::ListConstruct"
#   input: "ResNet/Sequential[layer4]/BasicBlock[0]/Conv2d[conv1]/1495"
#   input: "ResNet/Sequential[layer4]/BasicBlock[0]/Conv2d[conv1]/1495"
#   attr {
#     key: "attr"
#     value {
#       s: "{}"
#     }
#   }
# }
# node {
#   name: "ResNet/Sequential[layer4]/BasicBlock[1]/Conv2d[conv2]/1565"
#   op: "prim::ListConstruct"
#   input: "ResNet/Sequential[layer4]/BasicBlock[0]/Conv2d[conv1]/1495"
#   input: "ResNet/Sequential[layer4]/BasicBlock[0]/Conv2d[conv1]/1495"
#   attr {
#     key: "attr"
#     value {
#       s: "{}"
#     }
#   }
# }
# node {
#   name: "ResNet/Sequential[layer4]/BasicBlock[1]/Conv2d[conv2]/1566"
#   op: "prim::ListConstruct"
#   input: "ResNet/Sequential[layer4]/BasicBlock[0]/Conv2d[conv1]/1495"
#   input: "ResNet/Sequential[layer4]/BasicBlock[0]/Conv2d[conv1]/1495"
#   attr {
#     key: "attr"
#     value {
#       s: "{}"
#     }
#   }
# }
# node {
#   name: "ResNet/Sequential[layer4]/BasicBlock[1]/Conv2d[conv2]/1567"
#   op: "prim::ListConstruct"
#   input: "ResNet/Sequential[layer4]/BasicBlock[0]/Conv2d[conv1]/1493"
#   input: "ResNet/Sequential[layer4]/BasicBlock[0]/Conv2d[conv1]/1493"
#   attr {
#     key: "attr"
#     value {
#       s: "{}"
#     }
#   }
# }
# node {
#   name: "ResNet/Sequential[layer4]/BasicBlock[1]/Conv2d[conv2]/input.105"
#   op: "aten::_convolution"
#   input: "ResNet/Sequential[layer4]/BasicBlock[1]/ReLU[relu]/input.103"
#   input: "ResNet/Sequential[layer4]/BasicBlock[1]/Conv2d[conv2]/weight/weight.157"
#   input: "ResNet/Sequential[layer4]/BasicBlock[0]/Conv2d[conv1]/1497"
#   input: "ResNet/Sequential[layer4]/BasicBlock[1]/Conv2d[conv2]/1564"
#   input: "ResNet/Sequential[layer4]/BasicBlock[1]/Conv2d[conv2]/1565"
#   input: "ResNet/Sequential[layer4]/BasicBlock[1]/Conv2d[conv2]/1566"
#   input: "ResNet/Sequential[layer4]/BasicBlock[0]/Conv2d[conv1]/1494"
#   input: "ResNet/Sequential[layer4]/BasicBlock[1]/Conv2d[conv2]/1567"
#   input: "ResNet/Sequential[layer4]/BasicBlock[0]/Conv2d[conv1]/1495"
#   input: "ResNet/Sequential[layer4]/BasicBlock[0]/Conv2d[conv1]/1494"
#   input: "ResNet/Sequential[layer4]/BasicBlock[0]/Conv2d[conv1]/1494"
#   input: "ResNet/Sequential[layer4]/BasicBlock[0]/Conv2d[conv1]/1492"
#   input: "ResNet/Sequential[layer4]/BasicBlock[0]/Conv2d[conv1]/1492"
#   attr {
#     key: "attr"
#     value {
#       s: "{}"
#     }
#   }
#   attr {
#     key: "_output_shapes"
#     value {
#       list {
#         shape {
#           dim {
#             size: 1
#           }
#           dim {
#             size: 512
#           }
#           dim {
#             size: 7
#           }
#           dim {
#             size: 7
#           }
#         }
#       }
#     }
#   }
# }
# node {
#   name: "ResNet/Sequential[layer4]/BasicBlock[1]/BatchNorm2d[bn2]/running_var/running_var"
#   op: "prim::GetAttr"
#   input: "ResNet/Sequential[layer4]/BasicBlock[1]/BatchNorm2d[bn2]/weight/bn2"
#   attr {
#     key: "attr"
#     value {
#       s: "{ name :  running_var }"
#     }
#   }
# }
# node {
#   name: "ResNet/Sequential[layer4]/BasicBlock[1]/BatchNorm2d[bn2]/running_mean/running_mean"
#   op: "prim::GetAttr"
#   input: "ResNet/Sequential[layer4]/BasicBlock[1]/BatchNorm2d[bn2]/weight/bn2"
#   attr {
#     key: "attr"
#     value {
#       s: "{ name :  running_mean }"
#     }
#   }
# }
# node {
#   name: "ResNet/Sequential[layer4]/BasicBlock[1]/BatchNorm2d[bn2]/bias/bias.79"
#   op: "prim::GetAttr"
#   input: "ResNet/Sequential[layer4]/BasicBlock[1]/BatchNorm2d[bn2]/weight/bn2"
#   attr {
#     key: "attr"
#     value {
#       s: "{ name :  bias }"
#     }
#   }
# }
# node {
#   name: "ResNet/Sequential[layer4]/BasicBlock[1]/BatchNorm2d[bn2]/weight/weight.159"
#   op: "prim::GetAttr"
#   input: "ResNet/Sequential[layer4]/BasicBlock[1]/BatchNorm2d[bn2]/weight/bn2"
#   attr {
#     key: "attr"
#     value {
#       s: "{ name :  weight }"
#     }
#   }
# }
# node {
#   name: "ResNet/Sequential[layer4]/BasicBlock[1]/BatchNorm2d[bn2]/out"
#   op: "aten::batch_norm"
#   input: "ResNet/Sequential[layer4]/BasicBlock[1]/Conv2d[conv2]/input.105"
#   input: "ResNet/Sequential[layer4]/BasicBlock[1]/BatchNorm2d[bn2]/weight/weight.159"
#   input: "ResNet/Sequential[layer4]/BasicBlock[1]/BatchNorm2d[bn2]/bias/bias.79"
#   input: "ResNet/Sequential[layer4]/BasicBlock[1]/BatchNorm2d[bn2]/running_mean/running_mean"
#   input: "ResNet/Sequential[layer4]/BasicBlock[1]/BatchNorm2d[bn2]/running_var/running_var"
#   input: "ResNet/Sequential[layer4]/BasicBlock[0]/Conv2d[conv1]/1494"
#   input: "ResNet/Sequential[layer4]/BasicBlock[0]/BatchNorm2d[bn1]/1499"
#   input: "ResNet/Sequential[layer4]/BasicBlock[0]/BatchNorm2d[bn1]/1498"
#   input: "ResNet/Sequential[layer4]/BasicBlock[0]/Conv2d[conv1]/1492"
#   attr {
#     key: "attr"
#     value {
#       s: "{}"
#     }
#   }
#   attr {
#     key: "_output_shapes"
#     value {
#       list {
#         shape {
#           dim {
#             size: 1
#           }
#           dim {
#             size: 512
#           }
#           dim {
#             size: 7
#           }
#           dim {
#             size: 7
#           }
#         }
#       }
#     }
#   }
# }
# node {
#   name: "ResNet/Sequential[layer4]/BasicBlock[1]/input.107"
#   op: "aten::add_"
#   input: "ResNet/Sequential[layer4]/BasicBlock[1]/BatchNorm2d[bn2]/out"
#   input: "ResNet/Sequential[layer4]/BasicBlock[0]/ReLU[relu]/input.97"
#   input: "ResNet/Sequential[layer4]/BasicBlock[0]/Conv2d[conv1]/1495"
#   attr {
#     key: "attr"
#     value {
#       s: "{}"
#     }
#   }
#   attr {
#     key: "_output_shapes"
#     value {
#       list {
#         shape {
#           dim {
#             size: 1
#           }
#           dim {
#             size: 512
#           }
#           dim {
#             size: 7
#           }
#           dim {
#             size: 7
#           }
#         }
#       }
#     }
#   }
# }
# node {
#   name: "ResNet/Sequential[layer4]/BasicBlock[1]/ReLU[relu]/input.109"
#   op: "aten::relu_"
#   input: "ResNet/Sequential[layer4]/BasicBlock[1]/input.107"
#   attr {
#     key: "attr"
#     value {
#       s: "{}"
#     }
#   }
#   attr {
#     key: "_output_shapes"
#     value {
#       list {
#         shape {
#           dim {
#             size: 1
#           }
#           dim {
#             size: 512
#           }
#           dim {
#             size: 7
#           }
#           dim {
#             size: 7
#           }
#         }
#       }
#     }
#   }
# }
# node {
#   name: "ResNet/AdaptiveAvgPool2d[avgpool]/1576"
#   op: "prim::Constant"
#   attr {
#     key: "attr"
#     value {
#       s: "{ value : 1}"
#     }
#   }
# }
# node {
#   name: "ResNet/AdaptiveAvgPool2d[avgpool]/1577"
#   op: "prim::ListConstruct"
#   input: "ResNet/AdaptiveAvgPool2d[avgpool]/1576"
#   input: "ResNet/AdaptiveAvgPool2d[avgpool]/1576"
#   attr {
#     key: "attr"
#     value {
#       s: "{}"
#     }
#   }
# }
# node {
#   name: "ResNet/AdaptiveAvgPool2d[avgpool]/x"
#   op: "aten::adaptive_avg_pool2d"
#   input: "ResNet/Sequential[layer4]/BasicBlock[1]/ReLU[relu]/input.109"
#   input: "ResNet/AdaptiveAvgPool2d[avgpool]/1577"
#   attr {
#     key: "attr"
#     value {
#       s: "{}"
#     }
#   }
#   attr {
#     key: "_output_shapes"
#     value {
#       list {
#         shape {
#           dim {
#             size: 1
#           }
#           dim {
#             size: 512
#           }
#           dim {
#             size: 1
#           }
#           dim {
#             size: 1
#           }
#         }
#       }
#     }
#   }
# }
# node {
#   name: "ResNet/890"
#   op: "prim::Constant"
#   attr {
#     key: "attr"
#     value {
#       s: "{ value : 1}"
#     }
#   }
# }
# node {
#   name: "ResNet/891"
#   op: "prim::Constant"
#   attr {
#     key: "attr"
#     value {
#       s: "{ value : -1}"
#     }
#   }
# }
# node {
#   name: "ResNet/input"
#   op: "aten::flatten"
#   input: "ResNet/AdaptiveAvgPool2d[avgpool]/x"
#   input: "ResNet/890"
#   input: "ResNet/891"
#   attr {
#     key: "attr"
#     value {
#       s: "{}"
#     }
#   }
#   attr {
#     key: "_output_shapes"
#     value {
#       list {
#         shape {
#           dim {
#             size: 1
#           }
#           dim {
#             size: 512
#           }
#         }
#       }
#     }
#   }
# }
# node {
#   name: "ResNet/Linear[fc]/bias/bias"
#   op: "prim::GetAttr"
#   input: "ResNet/Linear[fc]/weight/fc"
#   attr {
#     key: "attr"
#     value {
#       s: "{ name :  bias }"
#     }
#   }
# }
# node {
#   name: "ResNet/Linear[fc]/weight/weight"
#   op: "prim::GetAttr"
#   input: "ResNet/Linear[fc]/weight/fc"
#   attr {
#     key: "attr"
#     value {
#       s: "{ name :  weight }"
#     }
#   }
# }
# node {
#   name: "ResNet/Linear[fc]/1581"
#   op: "aten::linear"
#   input: "ResNet/input"
#   input: "ResNet/Linear[fc]/weight/weight"
#   input: "ResNet/Linear[fc]/bias/bias"
#   attr {
#     key: "attr"
#     value {
#       s: "{}"
#     }
#   }
#   attr {
#     key: "_output_shapes"
#     value {
#       list {
#         shape {
#           dim {
#             size: 1
#           }
#           dim {
#             size: 1000
#           }
#         }
#       }
#     }
#   }
# }
# versions {
#   producer: 22
# }

# %%
# Example Usage:
data_dict = MessageToDict(model_graph) # This step produces the Base64
cleaned_data_dict = clean_graphdef_attributes(data_dict) # This step fixes it

# %%
# data_dict = MessageToDict(model_graph)

# %%
data_dict
# Out:
# {'node': [{'name': 'input/x.1',
#    'op': 'IO Node',
#    'attr': {'attr': {'s': ''},
#     '_output_shapes': {'list': {'shape': [{'dim': [{'size': '1'},
#          {'size': '3'},
#          {'size': '224'},
#          {'size': '224'}]}]}}}},
#   {'name': 'output/output.1',
#    'op': 'IO Node',
#    'input': ['ResNet/Linear[fc]/1581'],
#    'attr': {'attr': {'s': ''},
#     '_output_shapes': {'list': {'shape': [{'dim': [{'size': '1'},
#          {'size': '1000'}]}]}}}},
#   {'name': 'ResNet/Conv2d[conv1]/1223',
#    'op': 'prim::Constant',
#    'attr': {'attr': {'s': '{ value : 1}'}}},
#   {'name': 'ResNet/Conv2d[conv1]/1224',
#    'op': 'prim::Constant',
#    'attr': {'attr': {'s': '{ value : 0}'}}},
#   {'name': 'ResNet/Conv2d[conv1]/1225',
#    'op': 'prim::Constant',
#    'attr': {'attr': {'s': '{ value : 0}'}}},
#   {'name': 'ResNet/Conv2d[conv1]/1226',
#    'op': 'prim::Constant',
#    'attr': {'attr': {'s': '{ value : 1}'}}},
#   {'name': 'ResNet/Conv2d[conv1]/1227',
#    'op': 'prim::Constant',
#    'attr': {'attr': {'s': '{ value : 3}'}}},
#   {'name': 'ResNet/Conv2d[conv1]/1228',
#    'op': 'prim::Constant',
#    'attr': {'attr': {'s': '{ value : 2}'}}},
#   {'name': 'ResNet/Conv2d[conv1]/1229',
#    'op': 'prim::Constant',
#    'attr': {'attr': {'s': '{}'}}},
#   {'name': 'ResNet/Conv2d[conv1]/weight/weight.81',
#    'op': 'prim::GetAttr',
#    'input': ['ResNet/Conv2d[conv1]/weight/conv1.1'],
#    'attr': {'attr': {'s': '{ name :  weight }'}}},
#   {'name': 'ResNet/Conv2d[conv1]/1231',
#    'op': 'prim::ListConstruct',
#    'input': ['ResNet/Conv2d[conv1]/1228', 'ResNet/Conv2d[conv1]/1228'],
#    'attr': {'attr': {'s': '{}'}}},
#   {'name': 'ResNet/Conv2d[conv1]/1232',
#    'op': 'prim::ListConstruct',
#    'input': ['ResNet/Conv2d[conv1]/1227', 'ResNet/Conv2d[conv1]/1227'],
#    'attr': {'attr': {'s': '{}'}}},
#   {'name': 'ResNet/Conv2d[conv1]/1233',
#    'op': 'prim::ListConstruct',
#    'input': ['ResNet/Conv2d[conv1]/1226', 'ResNet/Conv2d[conv1]/1226'],
#    'attr': {'attr': {'s': '{}'}}},
#   {'name': 'ResNet/Conv2d[conv1]/1234',
#    'op': 'prim::ListConstruct',
#    'input': ['ResNet/Conv2d[conv1]/1224', 'ResNet/Conv2d[conv1]/1224'],
#    'attr': {'attr': {'s': '{}'}}},
#   {'name': 'ResNet/Conv2d[conv1]/input.1',
#    'op': 'aten::_convolution',
#    'input': ['input/x.1',
#     'ResNet/Conv2d[conv1]/weight/weight.81',
#     'ResNet/Conv2d[conv1]/1229',
#     'ResNet/Conv2d[conv1]/1231',
#     'ResNet/Conv2d[conv1]/1232',
#     'ResNet/Conv2d[conv1]/1233',
#     'ResNet/Conv2d[conv1]/1225',
#     'ResNet/Conv2d[conv1]/1234',
#     'ResNet/Conv2d[conv1]/1226',
#     'ResNet/Conv2d[conv1]/1225',
#     'ResNet/Conv2d[conv1]/1225',
#     'ResNet/Conv2d[conv1]/1223',
#     'ResNet/Conv2d[conv1]/1223'],
#    'attr': {'attr': {'s': '{}'},
#     '_output_shapes': {'list': {'shape': [{'dim': [{'size': '1'},
#          {'size': '64'},
#          {'size': '112'},
#          {'size': '112'}]}]}}}},
#   {'name': 'ResNet/BatchNorm2d[bn1]/1236',
#    'op': 'prim::Constant',
#    'attr': {'attr': {'s': '{ value : 1}'}}},
#   {'name': 'ResNet/BatchNorm2d[bn1]/1237',
#    'op': 'prim::Constant',
#    'attr': {'attr': {'s': '{ value : 1e-05}'}}},
#   {'name': 'ResNet/BatchNorm2d[bn1]/1238',
#    'op': 'prim::Constant',
#    'attr': {'attr': {'s': '{ value : 0.1}'}}},
#   {'name': 'ResNet/BatchNorm2d[bn1]/1239',
#    'op': 'prim::Constant',
#    'attr': {'attr': {'s': '{ value : 0}'}}},
#   {'name': 'ResNet/BatchNorm2d[bn1]/running_var/running_var.41',
#    'op': 'prim::GetAttr',
#    'input': ['ResNet/BatchNorm2d[bn1]/weight/bn1.1'],
#    'attr': {'attr': {'s': '{ name :  running_var }'}}},
#   {'name': 'ResNet/BatchNorm2d[bn1]/running_mean/running_mean.41',
#    'op': 'prim::GetAttr',
#    'input': ['ResNet/BatchNorm2d[bn1]/weight/bn1.1'],
#    'attr': {'attr': {'s': '{ name :  running_mean }'}}},
#   {'name': 'ResNet/BatchNorm2d[bn1]/bias/bias.41',
#    'op': 'prim::GetAttr',
#    'input': ['ResNet/BatchNorm2d[bn1]/weight/bn1.1'],
#    'attr': {'attr': {'s': '{ name :  bias }'}}},
#   {'name': 'ResNet/BatchNorm2d[bn1]/weight/weight.83',
#    'op': 'prim::GetAttr',
#    'input': ['ResNet/BatchNorm2d[bn1]/weight/bn1.1'],
#    'attr': {'attr': {'s': '{ name :  weight }'}}},
#   {'name': 'ResNet/BatchNorm2d[bn1]/input.3',
#    'op': 'aten::batch_norm',
#    'input': ['ResNet/Conv2d[conv1]/input.1',
#     'ResNet/BatchNorm2d[bn1]/weight/weight.83',
#     'ResNet/BatchNorm2d[bn1]/bias/bias.41',
#     'ResNet/BatchNorm2d[bn1]/running_mean/running_mean.41',
#     'ResNet/BatchNorm2d[bn1]/running_var/running_var.41',
#     'ResNet/BatchNorm2d[bn1]/1239',
#     'ResNet/BatchNorm2d[bn1]/1238',
#     'ResNet/BatchNorm2d[bn1]/1237',
#     'ResNet/BatchNorm2d[bn1]/1236'],
#    'attr': {'attr': {'s': '{}'},
#     '_output_shapes': {'list': {'shape': [{'dim': [{'size': '1'},
#          {'size': '64'},
#          {'size': '112'},
#          {'size': '112'}]}]}}}},
#   {'name': 'ResNet/ReLU[relu]/input.5',
#    'op': 'aten::relu_',
#    'input': ['ResNet/BatchNorm2d[bn1]/input.3'],
#    'attr': {'attr': {'s': '{}'},
#     '_output_shapes': {'list': {'shape': [{'dim': [{'size': '1'},
#          {'size': '64'},
#          {'size': '112'},
#          {'size': '112'}]}]}}}},
#   {'name': 'ResNet/MaxPool2d[maxpool]/1246',
#    'op': 'prim::Constant',
#    'attr': {'attr': {'s': '{ value : 0}'}}},
#   {'name': 'ResNet/MaxPool2d[maxpool]/1247',
#    'op': 'prim::Constant',
#    'attr': {'attr': {'s': '{ value : 1}'}}},
#   {'name': 'ResNet/MaxPool2d[maxpool]/1248',
#    'op': 'prim::Constant',
#    'attr': {'attr': {'s': '{ value : 2}'}}},
#   {'name': 'ResNet/MaxPool2d[maxpool]/1249',
#    'op': 'prim::Constant',
#    'attr': {'attr': {'s': '{ value : 3}'}}},
#   {'name': 'ResNet/MaxPool2d[maxpool]/1250',
#    'op': 'prim::ListConstruct',
#    'input': ['ResNet/MaxPool2d[maxpool]/1249',
#     'ResNet/MaxPool2d[maxpool]/1249'],
#    'attr': {'attr': {'s': '{}'}}},
#   {'name': 'ResNet/MaxPool2d[maxpool]/1251',
#    'op': 'prim::ListConstruct',
#    'input': ['ResNet/MaxPool2d[maxpool]/1248',
#     'ResNet/MaxPool2d[maxpool]/1248'],
#    'attr': {'attr': {'s': '{}'}}},
#   {'name': 'ResNet/MaxPool2d[maxpool]/1252',
#    'op': 'prim::ListConstruct',
#    'input': ['ResNet/MaxPool2d[maxpool]/1247',
#     'ResNet/MaxPool2d[maxpool]/1247'],
#    'attr': {'attr': {'s': '{}'}}},
#   {'name': 'ResNet/MaxPool2d[maxpool]/1253',
#    'op': 'prim::ListConstruct',
#    'input': ['ResNet/MaxPool2d[maxpool]/1247',
#     'ResNet/MaxPool2d[maxpool]/1247'],
#    'attr': {'attr': {'s': '{}'}}},
#   {'name': 'ResNet/MaxPool2d[maxpool]/input.7',
#    'op': 'aten::max_pool2d',
#    'input': ['ResNet/ReLU[relu]/input.5',
#     'ResNet/MaxPool2d[maxpool]/1250',
#     'ResNet/MaxPool2d[maxpool]/1251',
#     'ResNet/MaxPool2d[maxpool]/1252',
#     'ResNet/MaxPool2d[maxpool]/1253',
#     'ResNet/MaxPool2d[maxpool]/1246'],
#    'attr': {'attr': {'s': '{}'},
#     '_output_shapes': {'list': {'shape': [{'dim': [{'size': '1'},
#          {'size': '64'},
#          {'size': '56'},
#          {'size': '56'}]}]}}}},
#   {'name': 'ResNet/Sequential[layer1]/BasicBlock[0]/Conv2d[conv1]/1255',
#    'op': 'prim::Constant',
#    'attr': {'attr': {'s': '{ value : 1}'}}},
#   {'name': 'ResNet/Sequential[layer1]/BasicBlock[0]/Conv2d[conv1]/1256',
#    'op': 'prim::Constant',
#    'attr': {'attr': {'s': '{ value : 0}'}}},
#   {'name': 'ResNet/Sequential[layer1]/BasicBlock[0]/Conv2d[conv1]/1257',
#    'op': 'prim::Constant',
#    'attr': {'attr': {'s': '{ value : 0}'}}},
#   {'name': 'ResNet/Sequential[layer1]/BasicBlock[0]/Conv2d[conv1]/1258',
#    'op': 'prim::Constant',
#    'attr': {'attr': {'s': '{ value : 1}'}}},
#   {'name': 'ResNet/Sequential[layer1]/BasicBlock[0]/Conv2d[conv1]/1259',
#    'op': 'prim::Constant',
#    'attr': {'attr': {'s': '{}'}}},
#   {'name': 'ResNet/Sequential[layer1]/BasicBlock[0]/BatchNorm2d[bn1]/1260',
#    'op': 'prim::Constant',
#    'attr': {'attr': {'s': '{ value : 1e-05}'}}},
#   {'name': 'ResNet/Sequential[layer1]/BasicBlock[0]/BatchNorm2d[bn1]/1261',
#    'op': 'prim::Constant',
#    'attr': {'attr': {'s': '{ value : 0.1}'}}},
#   {'name': 'ResNet/Sequential[layer1]/BasicBlock[0]/Conv2d[conv1]/weight/weight.85',
#    'op': 'prim::GetAttr',
#    'input': ['ResNet/Sequential[layer1]/BasicBlock[0]/Conv2d[conv1]/weight/conv1.3'],
#    'attr': {'attr': {'s': '{ name :  weight }'}}},
#   {'name': 'ResNet/Sequential[layer1]/BasicBlock[0]/Conv2d[conv1]/1270',
#    'op': 'prim::ListConstruct',
#    'input': ['ResNet/Sequential[layer1]/BasicBlock[0]/Conv2d[conv1]/1258',
#     'ResNet/Sequential[layer1]/BasicBlock[0]/Conv2d[conv1]/1258'],
#    'attr': {'attr': {'s': '{}'}}},
#   {'name': 'ResNet/Sequential[layer1]/BasicBlock[0]/Conv2d[conv1]/1271',
#    'op': 'prim::ListConstruct',
#    'input': ['ResNet/Sequential[layer1]/BasicBlock[0]/Conv2d[conv1]/1258',
#     'ResNet/Sequential[layer1]/BasicBlock[0]/Conv2d[conv1]/1258'],
#    'attr': {'attr': {'s': '{}'}}},
#   {'name': 'ResNet/Sequential[layer1]/BasicBlock[0]/Conv2d[conv1]/1272',
#    'op': 'prim::ListConstruct',
#    'input': ['ResNet/Sequential[layer1]/BasicBlock[0]/Conv2d[conv1]/1258',
#     'ResNet/Sequential[layer1]/BasicBlock[0]/Conv2d[conv1]/1258'],
#    'attr': {'attr': {'s': '{}'}}},
#   {'name': 'ResNet/Sequential[layer1]/BasicBlock[0]/Conv2d[conv1]/1273',
#    'op': 'prim::ListConstruct',
#    'input': ['ResNet/Sequential[layer1]/BasicBlock[0]/Conv2d[conv1]/1256',
#     'ResNet/Sequential[layer1]/BasicBlock[0]/Conv2d[conv1]/1256'],
#    'attr': {'attr': {'s': '{}'}}},
#   {'name': 'ResNet/Sequential[layer1]/BasicBlock[0]/Conv2d[conv1]/input.9',
#    'op': 'aten::_convolution',
#    'input': ['ResNet/MaxPool2d[maxpool]/input.7',
#     'ResNet/Sequential[layer1]/BasicBlock[0]/Conv2d[conv1]/weight/weight.85',
#     'ResNet/Sequential[layer1]/BasicBlock[0]/Conv2d[conv1]/1259',
#     'ResNet/Sequential[layer1]/BasicBlock[0]/Conv2d[conv1]/1270',
#     'ResNet/Sequential[layer1]/BasicBlock[0]/Conv2d[conv1]/1271',
#     'ResNet/Sequential[layer1]/BasicBlock[0]/Conv2d[conv1]/1272',
#     'ResNet/Sequential[layer1]/BasicBlock[0]/Conv2d[conv1]/1257',
#     'ResNet/Sequential[layer1]/BasicBlock[0]/Conv2d[conv1]/1273',
#     'ResNet/Sequential[layer1]/BasicBlock[0]/Conv2d[conv1]/1258',
#     'ResNet/Sequential[layer1]/BasicBlock[0]/Conv2d[conv1]/1257',
#     'ResNet/Sequential[layer1]/BasicBlock[0]/Conv2d[conv1]/1257',
#     'ResNet/Sequential[layer1]/BasicBlock[0]/Conv2d[conv1]/1255',
#     'ResNet/Sequential[layer1]/BasicBlock[0]/Conv2d[conv1]/1255'],
#    'attr': {'attr': {'s': '{}'},
#     '_output_shapes': {'list': {'shape': [{'dim': [{'size': '1'},
#          {'size': '64'},
#          {'size': '56'},
#          {'size': '56'}]}]}}}},
#   {'name': 'ResNet/Sequential[layer1]/BasicBlock[0]/BatchNorm2d[bn1]/running_var/running_var.43',
#    'op': 'prim::GetAttr',
#    'input': ['ResNet/Sequential[layer1]/BasicBlock[0]/BatchNorm2d[bn1]/weight/bn1.3'],
#    'attr': {'attr': {'s': '{ name :  running_var }'}}},
#   {'name': 'ResNet/Sequential[layer1]/BasicBlock[0]/BatchNorm2d[bn1]/running_mean/running_mean.43',
#    'op': 'prim::GetAttr',
#    'input': ['ResNet/Sequential[layer1]/BasicBlock[0]/BatchNorm2d[bn1]/weight/bn1.3'],
#    'attr': {'attr': {'s': '{ name :  running_mean }'}}},
#   {'name': 'ResNet/Sequential[layer1]/BasicBlock[0]/BatchNorm2d[bn1]/bias/bias.43',
#    'op': 'prim::GetAttr',
#    'input': ['ResNet/Sequential[layer1]/BasicBlock[0]/BatchNorm2d[bn1]/weight/bn1.3'],
#    'attr': {'attr': {'s': '{ name :  bias }'}}},
#   {'name': 'ResNet/Sequential[layer1]/BasicBlock[0]/BatchNorm2d[bn1]/weight/weight.87',
#    'op': 'prim::GetAttr',
#    'input': ['ResNet/Sequential[layer1]/BasicBlock[0]/BatchNorm2d[bn1]/weight/bn1.3'],
#    'attr': {'attr': {'s': '{ name :  weight }'}}},
#   {'name': 'ResNet/Sequential[layer1]/BasicBlock[0]/BatchNorm2d[bn1]/input.11',
#    'op': 'aten::batch_norm',
#    'input': ['ResNet/Sequential[layer1]/BasicBlock[0]/Conv2d[conv1]/input.9',
#     'ResNet/Sequential[layer1]/BasicBlock[0]/BatchNorm2d[bn1]/weight/weight.87',
#     'ResNet/Sequential[layer1]/BasicBlock[0]/BatchNorm2d[bn1]/bias/bias.43',
#     'ResNet/Sequential[layer1]/BasicBlock[0]/BatchNorm2d[bn1]/running_mean/running_mean.43',
#     'ResNet/Sequential[layer1]/BasicBlock[0]/BatchNorm2d[bn1]/running_var/running_var.43',
#     'ResNet/Sequential[layer1]/BasicBlock[0]/Conv2d[conv1]/1257',
#     'ResNet/Sequential[layer1]/BasicBlock[0]/BatchNorm2d[bn1]/1261',
#     'ResNet/Sequential[layer1]/BasicBlock[0]/BatchNorm2d[bn1]/1260',
#     'ResNet/Sequential[layer1]/BasicBlock[0]/Conv2d[conv1]/1255'],
#    'attr': {'attr': {'s': '{}'},
#     '_output_shapes': {'list': {'shape': [{'dim': [{'size': '1'},
#          {'size': '64'},
#          {'size': '56'},
#          {'size': '56'}]}]}}}},
#   {'name': 'ResNet/Sequential[layer1]/BasicBlock[0]/ReLU[relu]/input.13',
#    'op': 'aten::relu_',
#    'input': ['ResNet/Sequential[layer1]/BasicBlock[0]/BatchNorm2d[bn1]/input.11'],
#    'attr': {'attr': {'s': '{}'},
#     '_output_shapes': {'list': {'shape': [{'dim': [{'size': '1'},
#          {'size': '64'},
#          {'size': '56'},
#          {'size': '56'}]}]}}}},
#   {'name': 'ResNet/Sequential[layer1]/BasicBlock[0]/Conv2d[conv2]/weight/weight.89',
#    'op': 'prim::GetAttr',
#    'input': ['ResNet/Sequential[layer1]/BasicBlock[0]/Conv2d[conv2]/weight/conv2.1'],
#    'attr': {'attr': {'s': '{ name :  weight }'}}},
#   {'name': 'ResNet/Sequential[layer1]/BasicBlock[0]/Conv2d[conv2]/1282',
#    'op': 'prim::ListConstruct',
#    'input': ['ResNet/Sequential[layer1]/BasicBlock[0]/Conv2d[conv1]/1258',
#     'ResNet/Sequential[layer1]/BasicBlock[0]/Conv2d[conv1]/1258'],
#    'attr': {'attr': {'s': '{}'}}},
#   {'name': 'ResNet/Sequential[layer1]/BasicBlock[0]/Conv2d[conv2]/1283',
#    'op': 'prim::ListConstruct',
#    'input': ['ResNet/Sequential[layer1]/BasicBlock[0]/Conv2d[conv1]/1258',
#     'ResNet/Sequential[layer1]/BasicBlock[0]/Conv2d[conv1]/1258'],
#    'attr': {'attr': {'s': '{}'}}},
#   {'name': 'ResNet/Sequential[layer1]/BasicBlock[0]/Conv2d[conv2]/1284',
#    'op': 'prim::ListConstruct',
#    'input': ['ResNet/Sequential[layer1]/BasicBlock[0]/Conv2d[conv1]/1258',
#     'ResNet/Sequential[layer1]/BasicBlock[0]/Conv2d[conv1]/1258'],
#    'attr': {'attr': {'s': '{}'}}},
#   {'name': 'ResNet/Sequential[layer1]/BasicBlock[0]/Conv2d[conv2]/1285',
#    'op': 'prim::ListConstruct',
#    'input': ['ResNet/Sequential[layer1]/BasicBlock[0]/Conv2d[conv1]/1256',
#     'ResNet/Sequential[layer1]/BasicBlock[0]/Conv2d[conv1]/1256'],
#    'attr': {'attr': {'s': '{}'}}},
#   {'name': 'ResNet/Sequential[layer1]/BasicBlock[0]/Conv2d[conv2]/input.15',
#    'op': 'aten::_convolution',
#    'input': ['ResNet/Sequential[layer1]/BasicBlock[0]/ReLU[relu]/input.13',
#     'ResNet/Sequential[layer1]/BasicBlock[0]/Conv2d[conv2]/weight/weight.89',
#     'ResNet/Sequential[layer1]/BasicBlock[0]/Conv2d[conv1]/1259',
#     'ResNet/Sequential[layer1]/BasicBlock[0]/Conv2d[conv2]/1282',
#     'ResNet/Sequential[layer1]/BasicBlock[0]/Conv2d[conv2]/1283',
#     'ResNet/Sequential[layer1]/BasicBlock[0]/Conv2d[conv2]/1284',
#     'ResNet/Sequential[layer1]/BasicBlock[0]/Conv2d[conv1]/1257',
#     'ResNet/Sequential[layer1]/BasicBlock[0]/Conv2d[conv2]/1285',
#     'ResNet/Sequential[layer1]/BasicBlock[0]/Conv2d[conv1]/1258',
#     'ResNet/Sequential[layer1]/BasicBlock[0]/Conv2d[conv1]/1257',
#     'ResNet/Sequential[layer1]/BasicBlock[0]/Conv2d[conv1]/1257',
#     'ResNet/Sequential[layer1]/BasicBlock[0]/Conv2d[conv1]/1255',
#     'ResNet/Sequential[layer1]/BasicBlock[0]/Conv2d[conv1]/1255'],
#    'attr': {'attr': {'s': '{}'},
#     '_output_shapes': {'list': {'shape': [{'dim': [{'size': '1'},
#          {'size': '64'},
#          {'size': '56'},
#          {'size': '56'}]}]}}}},
#   {'name': 'ResNet/Sequential[layer1]/BasicBlock[0]/BatchNorm2d[bn2]/running_var/running_var.45',
#    'op': 'prim::GetAttr',
#    'input': ['ResNet/Sequential[layer1]/BasicBlock[0]/BatchNorm2d[bn2]/weight/bn2.1'],
#    'attr': {'attr': {'s': '{ name :  running_var }'}}},
#   {'name': 'ResNet/Sequential[layer1]/BasicBlock[0]/BatchNorm2d[bn2]/running_mean/running_mean.45',
#    'op': 'prim::GetAttr',
#    'input': ['ResNet/Sequential[layer1]/BasicBlock[0]/BatchNorm2d[bn2]/weight/bn2.1'],
#    'attr': {'attr': {'s': '{ name :  running_mean }'}}},
#   {'name': 'ResNet/Sequential[layer1]/BasicBlock[0]/BatchNorm2d[bn2]/bias/bias.45',
#    'op': 'prim::GetAttr',
#    'input': ['ResNet/Sequential[layer1]/BasicBlock[0]/BatchNorm2d[bn2]/weight/bn2.1'],
#    'attr': {'attr': {'s': '{ name :  bias }'}}},
#   {'name': 'ResNet/Sequential[layer1]/BasicBlock[0]/BatchNorm2d[bn2]/weight/weight.91',
#    'op': 'prim::GetAttr',
#    'input': ['ResNet/Sequential[layer1]/BasicBlock[0]/BatchNorm2d[bn2]/weight/bn2.1'],
#    'attr': {'attr': {'s': '{ name :  weight }'}}},
#   {'name': 'ResNet/Sequential[layer1]/BasicBlock[0]/BatchNorm2d[bn2]/out.1',
#    'op': 'aten::batch_norm',
#    'input': ['ResNet/Sequential[layer1]/BasicBlock[0]/Conv2d[conv2]/input.15',
#     'ResNet/Sequential[layer1]/BasicBlock[0]/BatchNorm2d[bn2]/weight/weight.91',
#     'ResNet/Sequential[layer1]/BasicBlock[0]/BatchNorm2d[bn2]/bias/bias.45',
#     'ResNet/Sequential[layer1]/BasicBlock[0]/BatchNorm2d[bn2]/running_mean/running_mean.45',
#     'ResNet/Sequential[layer1]/BasicBlock[0]/BatchNorm2d[bn2]/running_var/running_var.45',
#     'ResNet/Sequential[layer1]/BasicBlock[0]/Conv2d[conv1]/1257',
#     'ResNet/Sequential[layer1]/BasicBlock[0]/BatchNorm2d[bn1]/1261',
#     'ResNet/Sequential[layer1]/BasicBlock[0]/BatchNorm2d[bn1]/1260',
#     'ResNet/Sequential[layer1]/BasicBlock[0]/Conv2d[conv1]/1255'],
#    'attr': {'attr': {'s': '{}'},
#     '_output_shapes': {'list': {'shape': [{'dim': [{'size': '1'},
#          {'size': '64'},
#          {'size': '56'},
#          {'size': '56'}]}]}}}},
#   {'name': 'ResNet/Sequential[layer1]/BasicBlock[0]/input.17',
#    'op': 'aten::add_',
#    'input': ['ResNet/Sequential[layer1]/BasicBlock[0]/BatchNorm2d[bn2]/out.1',
#     'ResNet/MaxPool2d[maxpool]/input.7',
#     'ResNet/Sequential[layer1]/BasicBlock[0]/Conv2d[conv1]/1258'],
#    'attr': {'attr': {'s': '{}'},
#     '_output_shapes': {'list': {'shape': [{'dim': [{'size': '1'},
#          {'size': '64'},
#          {'size': '56'},
#          {'size': '56'}]}]}}}},
#   {'name': 'ResNet/Sequential[layer1]/BasicBlock[0]/ReLU[relu]/input.19',
#    'op': 'aten::relu_',
#    'input': ['ResNet/Sequential[layer1]/BasicBlock[0]/input.17'],
#    'attr': {'attr': {'s': '{}'},
#     '_output_shapes': {'list': {'shape': [{'dim': [{'size': '1'},
#          {'size': '64'},
#          {'size': '56'},
#          {'size': '56'}]}]}}}},
#   {'name': 'ResNet/Sequential[layer1]/BasicBlock[1]/Conv2d[conv1]/weight/weight.93',
#    'op': 'prim::GetAttr',
#    'input': ['ResNet/Sequential[layer1]/BasicBlock[1]/Conv2d[conv1]/weight/conv1.5'],
#    'attr': {'attr': {'s': '{ name :  weight }'}}},
#   {'name': 'ResNet/Sequential[layer1]/BasicBlock[1]/Conv2d[conv1]/1300',
#    'op': 'prim::ListConstruct',
#    'input': ['ResNet/Sequential[layer1]/BasicBlock[0]/Conv2d[conv1]/1258',
#     'ResNet/Sequential[layer1]/BasicBlock[0]/Conv2d[conv1]/1258'],
#    'attr': {'attr': {'s': '{}'}}},
#   {'name': 'ResNet/Sequential[layer1]/BasicBlock[1]/Conv2d[conv1]/1301',
#    'op': 'prim::ListConstruct',
#    'input': ['ResNet/Sequential[layer1]/BasicBlock[0]/Conv2d[conv1]/1258',
#     'ResNet/Sequential[layer1]/BasicBlock[0]/Conv2d[conv1]/1258'],
#    'attr': {'attr': {'s': '{}'}}},
#   {'name': 'ResNet/Sequential[layer1]/BasicBlock[1]/Conv2d[conv1]/1302',
#    'op': 'prim::ListConstruct',
#    'input': ['ResNet/Sequential[layer1]/BasicBlock[0]/Conv2d[conv1]/1258',
#     'ResNet/Sequential[layer1]/BasicBlock[0]/Conv2d[conv1]/1258'],
#    'attr': {'attr': {'s': '{}'}}},
#   {'name': 'ResNet/Sequential[layer1]/BasicBlock[1]/Conv2d[conv1]/1303',
#    'op': 'prim::ListConstruct',
#    'input': ['ResNet/Sequential[layer1]/BasicBlock[0]/Conv2d[conv1]/1256',
#     'ResNet/Sequential[layer1]/BasicBlock[0]/Conv2d[conv1]/1256'],
#    'attr': {'attr': {'s': '{}'}}},
#   {'name': 'ResNet/Sequential[layer1]/BasicBlock[1]/Conv2d[conv1]/input.21',
#    'op': 'aten::_convolution',
#    'input': ['ResNet/Sequential[layer1]/BasicBlock[0]/ReLU[relu]/input.19',
#     'ResNet/Sequential[layer1]/BasicBlock[1]/Conv2d[conv1]/weight/weight.93',
#     'ResNet/Sequential[layer1]/BasicBlock[0]/Conv2d[conv1]/1259',
#     'ResNet/Sequential[layer1]/BasicBlock[1]/Conv2d[conv1]/1300',
#     'ResNet/Sequential[layer1]/BasicBlock[1]/Conv2d[conv1]/1301',
#     'ResNet/Sequential[layer1]/BasicBlock[1]/Conv2d[conv1]/1302',
#     'ResNet/Sequential[layer1]/BasicBlock[0]/Conv2d[conv1]/1257',
#     'ResNet/Sequential[layer1]/BasicBlock[1]/Conv2d[conv1]/1303',
#     'ResNet/Sequential[layer1]/BasicBlock[0]/Conv2d[conv1]/1258',
#     'ResNet/Sequential[layer1]/BasicBlock[0]/Conv2d[conv1]/1257',
#     'ResNet/Sequential[layer1]/BasicBlock[0]/Conv2d[conv1]/1257',
#     'ResNet/Sequential[layer1]/BasicBlock[0]/Conv2d[conv1]/1255',
#     'ResNet/Sequential[layer1]/BasicBlock[0]/Conv2d[conv1]/1255'],
#    'attr': {'attr': {'s': '{}'},
#     '_output_shapes': {'list': {'shape': [{'dim': [{'size': '1'},
#          {'size': '64'},
#          {'size': '56'},
#          {'size': '56'}]}]}}}},
#   {'name': 'ResNet/Sequential[layer1]/BasicBlock[1]/BatchNorm2d[bn1]/running_var/running_var.47',
#    'op': 'prim::GetAttr',
#    'input': ['ResNet/Sequential[layer1]/BasicBlock[1]/BatchNorm2d[bn1]/weight/bn1.5'],
#    'attr': {'attr': {'s': '{ name :  running_var }'}}},
#   {'name': 'ResNet/Sequential[layer1]/BasicBlock[1]/BatchNorm2d[bn1]/running_mean/running_mean.47',
#    'op': 'prim::GetAttr',
#    'input': ['ResNet/Sequential[layer1]/BasicBlock[1]/BatchNorm2d[bn1]/weight/bn1.5'],
#    'attr': {'attr': {'s': '{ name :  running_mean }'}}},
#   {'name': 'ResNet/Sequential[layer1]/BasicBlock[1]/BatchNorm2d[bn1]/bias/bias.47',
#    'op': 'prim::GetAttr',
#    'input': ['ResNet/Sequential[layer1]/BasicBlock[1]/BatchNorm2d[bn1]/weight/bn1.5'],
#    'attr': {'attr': {'s': '{ name :  bias }'}}},
#   {'name': 'ResNet/Sequential[layer1]/BasicBlock[1]/BatchNorm2d[bn1]/weight/weight.95',
#    'op': 'prim::GetAttr',
#    'input': ['ResNet/Sequential[layer1]/BasicBlock[1]/BatchNorm2d[bn1]/weight/bn1.5'],
#    'attr': {'attr': {'s': '{ name :  weight }'}}},
#   {'name': 'ResNet/Sequential[layer1]/BasicBlock[1]/BatchNorm2d[bn1]/input.23',
#    'op': 'aten::batch_norm',
#    'input': ['ResNet/Sequential[layer1]/BasicBlock[1]/Conv2d[conv1]/input.21',
#     'ResNet/Sequential[layer1]/BasicBlock[1]/BatchNorm2d[bn1]/weight/weight.95',
#     'ResNet/Sequential[layer1]/BasicBlock[1]/BatchNorm2d[bn1]/bias/bias.47',
#     'ResNet/Sequential[layer1]/BasicBlock[1]/BatchNorm2d[bn1]/running_mean/running_mean.47',
#     'ResNet/Sequential[layer1]/BasicBlock[1]/BatchNorm2d[bn1]/running_var/running_var.47',
#     'ResNet/Sequential[layer1]/BasicBlock[0]/Conv2d[conv1]/1257',
#     'ResNet/Sequential[layer1]/BasicBlock[0]/BatchNorm2d[bn1]/1261',
#     'ResNet/Sequential[layer1]/BasicBlock[0]/BatchNorm2d[bn1]/1260',
#     'ResNet/Sequential[layer1]/BasicBlock[0]/Conv2d[conv1]/1255'],
#    'attr': {'attr': {'s': '{}'},
#     '_output_shapes': {'list': {'shape': [{'dim': [{'size': '1'},
#          {'size': '64'},
#          {'size': '56'},
#          {'size': '56'}]}]}}}},
#   {'name': 'ResNet/Sequential[layer1]/BasicBlock[1]/ReLU[relu]/input.25',
#    'op': 'aten::relu_',
#    'input': ['ResNet/Sequential[layer1]/BasicBlock[1]/BatchNorm2d[bn1]/input.23'],
#    'attr': {'attr': {'s': '{}'},
#     '_output_shapes': {'list': {'shape': [{'dim': [{'size': '1'},
#          {'size': '64'},
#          {'size': '56'},
#          {'size': '56'}]}]}}}},
#   {'name': 'ResNet/Sequential[layer1]/BasicBlock[1]/Conv2d[conv2]/weight/weight.97',
#    'op': 'prim::GetAttr',
#    'input': ['ResNet/Sequential[layer1]/BasicBlock[1]/Conv2d[conv2]/weight/conv2.3'],
#    'attr': {'attr': {'s': '{ name :  weight }'}}},
#   {'name': 'ResNet/Sequential[layer1]/BasicBlock[1]/Conv2d[conv2]/1312',
#    'op': 'prim::ListConstruct',
#    'input': ['ResNet/Sequential[layer1]/BasicBlock[0]/Conv2d[conv1]/1258',
#     'ResNet/Sequential[layer1]/BasicBlock[0]/Conv2d[conv1]/1258'],
#    'attr': {'attr': {'s': '{}'}}},
#   {'name': 'ResNet/Sequential[layer1]/BasicBlock[1]/Conv2d[conv2]/1313',
#    'op': 'prim::ListConstruct',
#    'input': ['ResNet/Sequential[layer1]/BasicBlock[0]/Conv2d[conv1]/1258',
#     'ResNet/Sequential[layer1]/BasicBlock[0]/Conv2d[conv1]/1258'],
#    'attr': {'attr': {'s': '{}'}}},
#   {'name': 'ResNet/Sequential[layer1]/BasicBlock[1]/Conv2d[conv2]/1314',
#    'op': 'prim::ListConstruct',
#    'input': ['ResNet/Sequential[layer1]/BasicBlock[0]/Conv2d[conv1]/1258',
#     'ResNet/Sequential[layer1]/BasicBlock[0]/Conv2d[conv1]/1258'],
#    'attr': {'attr': {'s': '{}'}}},
#   {'name': 'ResNet/Sequential[layer1]/BasicBlock[1]/Conv2d[conv2]/1315',
#    'op': 'prim::ListConstruct',
#    'input': ['ResNet/Sequential[layer1]/BasicBlock[0]/Conv2d[conv1]/1256',
#     'ResNet/Sequential[layer1]/BasicBlock[0]/Conv2d[conv1]/1256'],
#    'attr': {'attr': {'s': '{}'}}},
#   {'name': 'ResNet/Sequential[layer1]/BasicBlock[1]/Conv2d[conv2]/input.27',
#    'op': 'aten::_convolution',
#    'input': ['ResNet/Sequential[layer1]/BasicBlock[1]/ReLU[relu]/input.25',
#     'ResNet/Sequential[layer1]/BasicBlock[1]/Conv2d[conv2]/weight/weight.97',
#     'ResNet/Sequential[layer1]/BasicBlock[0]/Conv2d[conv1]/1259',
#     'ResNet/Sequential[layer1]/BasicBlock[1]/Conv2d[conv2]/1312',
#     'ResNet/Sequential[layer1]/BasicBlock[1]/Conv2d[conv2]/1313',
#     'ResNet/Sequential[layer1]/BasicBlock[1]/Conv2d[conv2]/1314',
#     'ResNet/Sequential[layer1]/BasicBlock[0]/Conv2d[conv1]/1257',
#     'ResNet/Sequential[layer1]/BasicBlock[1]/Conv2d[conv2]/1315',
#     'ResNet/Sequential[layer1]/BasicBlock[0]/Conv2d[conv1]/1258',
#     'ResNet/Sequential[layer1]/BasicBlock[0]/Conv2d[conv1]/1257',
#     'ResNet/Sequential[layer1]/BasicBlock[0]/Conv2d[conv1]/1257',
#     'ResNet/Sequential[layer1]/BasicBlock[0]/Conv2d[conv1]/1255',
#     'ResNet/Sequential[layer1]/BasicBlock[0]/Conv2d[conv1]/1255'],
#    'attr': {'attr': {'s': '{}'},
#     '_output_shapes': {'list': {'shape': [{'dim': [{'size': '1'},
#          {'size': '64'},
#          {'size': '56'},
#          {'size': '56'}]}]}}}},
#   {'name': 'ResNet/Sequential[layer1]/BasicBlock[1]/BatchNorm2d[bn2]/running_var/running_var.49',
#    'op': 'prim::GetAttr',
#    'input': ['ResNet/Sequential[layer1]/BasicBlock[1]/BatchNorm2d[bn2]/weight/bn2.3'],
#    'attr': {'attr': {'s': '{ name :  running_var }'}}},
#   {'name': 'ResNet/Sequential[layer1]/BasicBlock[1]/BatchNorm2d[bn2]/running_mean/running_mean.49',
#    'op': 'prim::GetAttr',
#    'input': ['ResNet/Sequential[layer1]/BasicBlock[1]/BatchNorm2d[bn2]/weight/bn2.3'],
#    'attr': {'attr': {'s': '{ name :  running_mean }'}}},
#   {'name': 'ResNet/Sequential[layer1]/BasicBlock[1]/BatchNorm2d[bn2]/bias/bias.49',
#    'op': 'prim::GetAttr',
#    'input': ['ResNet/Sequential[layer1]/BasicBlock[1]/BatchNorm2d[bn2]/weight/bn2.3'],
#    'attr': {'attr': {'s': '{ name :  bias }'}}},
#   {'name': 'ResNet/Sequential[layer1]/BasicBlock[1]/BatchNorm2d[bn2]/weight/weight.99',
#    'op': 'prim::GetAttr',
#    'input': ['ResNet/Sequential[layer1]/BasicBlock[1]/BatchNorm2d[bn2]/weight/bn2.3'],
#    'attr': {'attr': {'s': '{ name :  weight }'}}},
#   {'name': 'ResNet/Sequential[layer1]/BasicBlock[1]/BatchNorm2d[bn2]/out.3',
#    'op': 'aten::batch_norm',
#    'input': ['ResNet/Sequential[layer1]/BasicBlock[1]/Conv2d[conv2]/input.27',
#     'ResNet/Sequential[layer1]/BasicBlock[1]/BatchNorm2d[bn2]/weight/weight.99',
#     'ResNet/Sequential[layer1]/BasicBlock[1]/BatchNorm2d[bn2]/bias/bias.49',
#     'ResNet/Sequential[layer1]/BasicBlock[1]/BatchNorm2d[bn2]/running_mean/running_mean.49',
#     'ResNet/Sequential[layer1]/BasicBlock[1]/BatchNorm2d[bn2]/running_var/running_var.49',
#     'ResNet/Sequential[layer1]/BasicBlock[0]/Conv2d[conv1]/1257',
#     'ResNet/Sequential[layer1]/BasicBlock[0]/BatchNorm2d[bn1]/1261',
#     'ResNet/Sequential[layer1]/BasicBlock[0]/BatchNorm2d[bn1]/1260',
#     'ResNet/Sequential[layer1]/BasicBlock[0]/Conv2d[conv1]/1255'],
#    'attr': {'attr': {'s': '{}'},
#     '_output_shapes': {'list': {'shape': [{'dim': [{'size': '1'},
#          {'size': '64'},
#          {'size': '56'},
#          {'size': '56'}]}]}}}},
#   {'name': 'ResNet/Sequential[layer1]/BasicBlock[1]/input.29',
#    'op': 'aten::add_',
#    'input': ['ResNet/Sequential[layer1]/BasicBlock[1]/BatchNorm2d[bn2]/out.3',
#     'ResNet/Sequential[layer1]/BasicBlock[0]/ReLU[relu]/input.19',
#     'ResNet/Sequential[layer1]/BasicBlock[0]/Conv2d[conv1]/1258'],
#    'attr': {'attr': {'s': '{}'},
#     '_output_shapes': {'list': {'shape': [{'dim': [{'size': '1'},
#          {'size': '64'},
#          {'size': '56'},
#          {'size': '56'}]}]}}}},
#   {'name': 'ResNet/Sequential[layer1]/BasicBlock[1]/ReLU[relu]/input.31',
#    'op': 'aten::relu_',
#    'input': ['ResNet/Sequential[layer1]/BasicBlock[1]/input.29'],
#    'attr': {'attr': {'s': '{}'},
#     '_output_shapes': {'list': {'shape': [{'dim': [{'size': '1'},
#          {'size': '64'},
#          {'size': '56'},
#          {'size': '56'}]}]}}}},
#   {'name': 'ResNet/Sequential[layer2]/BasicBlock[0]/Conv2d[conv1]/1324',
#    'op': 'prim::Constant',
#    'attr': {'attr': {'s': '{ value : 1}'}}},
#   {'name': 'ResNet/Sequential[layer2]/BasicBlock[0]/Conv2d[conv1]/1325',
#    'op': 'prim::Constant',
#    'attr': {'attr': {'s': '{ value : 0}'}}},
#   {'name': 'ResNet/Sequential[layer2]/BasicBlock[0]/Conv2d[conv1]/1326',
#    'op': 'prim::Constant',
#    'attr': {'attr': {'s': '{ value : 0}'}}},
#   {'name': 'ResNet/Sequential[layer2]/BasicBlock[0]/Conv2d[conv1]/1327',
#    'op': 'prim::Constant',
#    'attr': {'attr': {'s': '{ value : 1}'}}},
#   {'name': 'ResNet/Sequential[layer2]/BasicBlock[0]/Conv2d[conv1]/1328',
#    'op': 'prim::Constant',
#    'attr': {'attr': {'s': '{ value : 2}'}}},
#   {'name': 'ResNet/Sequential[layer2]/BasicBlock[0]/Conv2d[conv1]/1329',
#    'op': 'prim::Constant',
#    'attr': {'attr': {'s': '{}'}}},
#   {'name': 'ResNet/Sequential[layer2]/BasicBlock[0]/BatchNorm2d[bn1]/1330',
#    'op': 'prim::Constant',
#    'attr': {'attr': {'s': '{ value : 1e-05}'}}},
#   {'name': 'ResNet/Sequential[layer2]/BasicBlock[0]/BatchNorm2d[bn1]/1331',
#    'op': 'prim::Constant',
#    'attr': {'attr': {'s': '{ value : 0.1}'}}},
#   {'name': 'ResNet/Sequential[layer2]/BasicBlock[0]/Conv2d[conv1]/weight/weight.101',
#    'op': 'prim::GetAttr',
#    'input': ['ResNet/Sequential[layer2]/BasicBlock[0]/Conv2d[conv1]/weight/conv1.7'],
#    'attr': {'attr': {'s': '{ name :  weight }'}}},
#   {'name': 'ResNet/Sequential[layer2]/BasicBlock[0]/Conv2d[conv1]/1341',
#    'op': 'prim::ListConstruct',
#    'input': ['ResNet/Sequential[layer2]/BasicBlock[0]/Conv2d[conv1]/1328',
#     'ResNet/Sequential[layer2]/BasicBlock[0]/Conv2d[conv1]/1328'],
#    'attr': {'attr': {'s': '{}'}}},
#   {'name': 'ResNet/Sequential[layer2]/BasicBlock[0]/Conv2d[conv1]/1342',
#    'op': 'prim::ListConstruct',
#    'input': ['ResNet/Sequential[layer2]/BasicBlock[0]/Conv2d[conv1]/1327',
#     'ResNet/Sequential[layer2]/BasicBlock[0]/Conv2d[conv1]/1327'],
#    'attr': {'attr': {'s': '{}'}}},
#   {'name': 'ResNet/Sequential[layer2]/BasicBlock[0]/Conv2d[conv1]/1343',
#    'op': 'prim::ListConstruct',
#    'input': ['ResNet/Sequential[layer2]/BasicBlock[0]/Conv2d[conv1]/1327',
#     'ResNet/Sequential[layer2]/BasicBlock[0]/Conv2d[conv1]/1327'],
#    'attr': {'attr': {'s': '{}'}}},
#   {'name': 'ResNet/Sequential[layer2]/BasicBlock[0]/Conv2d[conv1]/1344',
#    'op': 'prim::ListConstruct',
#    'input': ['ResNet/Sequential[layer2]/BasicBlock[0]/Conv2d[conv1]/1325',
#     'ResNet/Sequential[layer2]/BasicBlock[0]/Conv2d[conv1]/1325'],
#    'attr': {'attr': {'s': '{}'}}},
#   {'name': 'ResNet/Sequential[layer2]/BasicBlock[0]/Conv2d[conv1]/input.33',
#    'op': 'aten::_convolution',
#    'input': ['ResNet/Sequential[layer1]/BasicBlock[1]/ReLU[relu]/input.31',
#     'ResNet/Sequential[layer2]/BasicBlock[0]/Conv2d[conv1]/weight/weight.101',
#     'ResNet/Sequential[layer2]/BasicBlock[0]/Conv2d[conv1]/1329',
#     'ResNet/Sequential[layer2]/BasicBlock[0]/Conv2d[conv1]/1341',
#     'ResNet/Sequential[layer2]/BasicBlock[0]/Conv2d[conv1]/1342',
#     'ResNet/Sequential[layer2]/BasicBlock[0]/Conv2d[conv1]/1343',
#     'ResNet/Sequential[layer2]/BasicBlock[0]/Conv2d[conv1]/1326',
#     'ResNet/Sequential[layer2]/BasicBlock[0]/Conv2d[conv1]/1344',
#     'ResNet/Sequential[layer2]/BasicBlock[0]/Conv2d[conv1]/1327',
#     'ResNet/Sequential[layer2]/BasicBlock[0]/Conv2d[conv1]/1326',
#     'ResNet/Sequential[layer2]/BasicBlock[0]/Conv2d[conv1]/1326',
#     'ResNet/Sequential[layer2]/BasicBlock[0]/Conv2d[conv1]/1324',
#     'ResNet/Sequential[layer2]/BasicBlock[0]/Conv2d[conv1]/1324'],
#    'attr': {'attr': {'s': '{}'},
#     '_output_shapes': {'list': {'shape': [{'dim': [{'size': '1'},
#          {'size': '128'},
#          {'size': '28'},
#          {'size': '28'}]}]}}}},
#   {'name': 'ResNet/Sequential[layer2]/BasicBlock[0]/BatchNorm2d[bn1]/running_var/running_var.51',
#    'op': 'prim::GetAttr',
#    'input': ['ResNet/Sequential[layer2]/BasicBlock[0]/BatchNorm2d[bn1]/weight/bn1.7'],
#    'attr': {'attr': {'s': '{ name :  running_var }'}}},
#   {'name': 'ResNet/Sequential[layer2]/BasicBlock[0]/BatchNorm2d[bn1]/running_mean/running_mean.51',
#    'op': 'prim::GetAttr',
#    'input': ['ResNet/Sequential[layer2]/BasicBlock[0]/BatchNorm2d[bn1]/weight/bn1.7'],
#    'attr': {'attr': {'s': '{ name :  running_mean }'}}},
#   {'name': 'ResNet/Sequential[layer2]/BasicBlock[0]/BatchNorm2d[bn1]/bias/bias.51',
#    'op': 'prim::GetAttr',
#    'input': ['ResNet/Sequential[layer2]/BasicBlock[0]/BatchNorm2d[bn1]/weight/bn1.7'],
#    'attr': {'attr': {'s': '{ name :  bias }'}}},
#   {'name': 'ResNet/Sequential[layer2]/BasicBlock[0]/BatchNorm2d[bn1]/weight/weight.103',
#    'op': 'prim::GetAttr',
#    'input': ['ResNet/Sequential[layer2]/BasicBlock[0]/BatchNorm2d[bn1]/weight/bn1.7'],
#    'attr': {'attr': {'s': '{ name :  weight }'}}},
#   {'name': 'ResNet/Sequential[layer2]/BasicBlock[0]/BatchNorm2d[bn1]/input.35',
#    'op': 'aten::batch_norm',
#    'input': ['ResNet/Sequential[layer2]/BasicBlock[0]/Conv2d[conv1]/input.33',
#     'ResNet/Sequential[layer2]/BasicBlock[0]/BatchNorm2d[bn1]/weight/weight.103',
#     'ResNet/Sequential[layer2]/BasicBlock[0]/BatchNorm2d[bn1]/bias/bias.51',
#     'ResNet/Sequential[layer2]/BasicBlock[0]/BatchNorm2d[bn1]/running_mean/running_mean.51',
#     'ResNet/Sequential[layer2]/BasicBlock[0]/BatchNorm2d[bn1]/running_var/running_var.51',
#     'ResNet/Sequential[layer2]/BasicBlock[0]/Conv2d[conv1]/1326',
#     'ResNet/Sequential[layer2]/BasicBlock[0]/BatchNorm2d[bn1]/1331',
#     'ResNet/Sequential[layer2]/BasicBlock[0]/BatchNorm2d[bn1]/1330',
#     'ResNet/Sequential[layer2]/BasicBlock[0]/Conv2d[conv1]/1324'],
#    'attr': {'attr': {'s': '{}'},
#     '_output_shapes': {'list': {'shape': [{'dim': [{'size': '1'},
#          {'size': '128'},
#          {'size': '28'},
#          {'size': '28'}]}]}}}},
#   {'name': 'ResNet/Sequential[layer2]/BasicBlock[0]/ReLU[relu]/input.37',
#    'op': 'aten::relu_',
#    'input': ['ResNet/Sequential[layer2]/BasicBlock[0]/BatchNorm2d[bn1]/input.35'],
#    'attr': {'attr': {'s': '{}'},
#     '_output_shapes': {'list': {'shape': [{'dim': [{'size': '1'},
#          {'size': '128'},
#          {'size': '28'},
#          {'size': '28'}]}]}}}},
#   {'name': 'ResNet/Sequential[layer2]/BasicBlock[0]/Conv2d[conv2]/weight/weight.105',
#    'op': 'prim::GetAttr',
#    'input': ['ResNet/Sequential[layer2]/BasicBlock[0]/Conv2d[conv2]/weight/conv2.5'],
#    'attr': {'attr': {'s': '{ name :  weight }'}}},
#   {'name': 'ResNet/Sequential[layer2]/BasicBlock[0]/Conv2d[conv2]/1353',
#    'op': 'prim::ListConstruct',
#    'input': ['ResNet/Sequential[layer2]/BasicBlock[0]/Conv2d[conv1]/1327',
#     'ResNet/Sequential[layer2]/BasicBlock[0]/Conv2d[conv1]/1327'],
#    'attr': {'attr': {'s': '{}'}}},
#   {'name': 'ResNet/Sequential[layer2]/BasicBlock[0]/Conv2d[conv2]/1354',
#    'op': 'prim::ListConstruct',
#    'input': ['ResNet/Sequential[layer2]/BasicBlock[0]/Conv2d[conv1]/1327',
#     'ResNet/Sequential[layer2]/BasicBlock[0]/Conv2d[conv1]/1327'],
#    'attr': {'attr': {'s': '{}'}}},
#   {'name': 'ResNet/Sequential[layer2]/BasicBlock[0]/Conv2d[conv2]/1355',
#    'op': 'prim::ListConstruct',
#    'input': ['ResNet/Sequential[layer2]/BasicBlock[0]/Conv2d[conv1]/1327',
#     'ResNet/Sequential[layer2]/BasicBlock[0]/Conv2d[conv1]/1327'],
#    'attr': {'attr': {'s': '{}'}}},
#   {'name': 'ResNet/Sequential[layer2]/BasicBlock[0]/Conv2d[conv2]/1356',
#    'op': 'prim::ListConstruct',
#    'input': ['ResNet/Sequential[layer2]/BasicBlock[0]/Conv2d[conv1]/1325',
#     'ResNet/Sequential[layer2]/BasicBlock[0]/Conv2d[conv1]/1325'],
#    'attr': {'attr': {'s': '{}'}}},
#   {'name': 'ResNet/Sequential[layer2]/BasicBlock[0]/Conv2d[conv2]/input.39',
#    'op': 'aten::_convolution',
#    'input': ['ResNet/Sequential[layer2]/BasicBlock[0]/ReLU[relu]/input.37',
#     'ResNet/Sequential[layer2]/BasicBlock[0]/Conv2d[conv2]/weight/weight.105',
#     'ResNet/Sequential[layer2]/BasicBlock[0]/Conv2d[conv1]/1329',
#     'ResNet/Sequential[layer2]/BasicBlock[0]/Conv2d[conv2]/1353',
#     'ResNet/Sequential[layer2]/BasicBlock[0]/Conv2d[conv2]/1354',
#     'ResNet/Sequential[layer2]/BasicBlock[0]/Conv2d[conv2]/1355',
#     'ResNet/Sequential[layer2]/BasicBlock[0]/Conv2d[conv1]/1326',
#     'ResNet/Sequential[layer2]/BasicBlock[0]/Conv2d[conv2]/1356',
#     'ResNet/Sequential[layer2]/BasicBlock[0]/Conv2d[conv1]/1327',
#     'ResNet/Sequential[layer2]/BasicBlock[0]/Conv2d[conv1]/1326',
#     'ResNet/Sequential[layer2]/BasicBlock[0]/Conv2d[conv1]/1326',
#     'ResNet/Sequential[layer2]/BasicBlock[0]/Conv2d[conv1]/1324',
#     'ResNet/Sequential[layer2]/BasicBlock[0]/Conv2d[conv1]/1324'],
#    'attr': {'attr': {'s': '{}'},
#     '_output_shapes': {'list': {'shape': [{'dim': [{'size': '1'},
#          {'size': '128'},
#          {'size': '28'},
#          {'size': '28'}]}]}}}},
#   {'name': 'ResNet/Sequential[layer2]/BasicBlock[0]/BatchNorm2d[bn2]/running_var/running_var.53',
#    'op': 'prim::GetAttr',
#    'input': ['ResNet/Sequential[layer2]/BasicBlock[0]/BatchNorm2d[bn2]/weight/bn2.5'],
#    'attr': {'attr': {'s': '{ name :  running_var }'}}},
#   {'name': 'ResNet/Sequential[layer2]/BasicBlock[0]/BatchNorm2d[bn2]/running_mean/running_mean.53',
#    'op': 'prim::GetAttr',
#    'input': ['ResNet/Sequential[layer2]/BasicBlock[0]/BatchNorm2d[bn2]/weight/bn2.5'],
#    'attr': {'attr': {'s': '{ name :  running_mean }'}}},
#   {'name': 'ResNet/Sequential[layer2]/BasicBlock[0]/BatchNorm2d[bn2]/bias/bias.53',
#    'op': 'prim::GetAttr',
#    'input': ['ResNet/Sequential[layer2]/BasicBlock[0]/BatchNorm2d[bn2]/weight/bn2.5'],
#    'attr': {'attr': {'s': '{ name :  bias }'}}},
#   {'name': 'ResNet/Sequential[layer2]/BasicBlock[0]/BatchNorm2d[bn2]/weight/weight.107',
#    'op': 'prim::GetAttr',
#    'input': ['ResNet/Sequential[layer2]/BasicBlock[0]/BatchNorm2d[bn2]/weight/bn2.5'],
#    'attr': {'attr': {'s': '{ name :  weight }'}}},
#   {'name': 'ResNet/Sequential[layer2]/BasicBlock[0]/BatchNorm2d[bn2]/out.5',
#    'op': 'aten::batch_norm',
#    'input': ['ResNet/Sequential[layer2]/BasicBlock[0]/Conv2d[conv2]/input.39',
#     'ResNet/Sequential[layer2]/BasicBlock[0]/BatchNorm2d[bn2]/weight/weight.107',
#     'ResNet/Sequential[layer2]/BasicBlock[0]/BatchNorm2d[bn2]/bias/bias.53',
#     'ResNet/Sequential[layer2]/BasicBlock[0]/BatchNorm2d[bn2]/running_mean/running_mean.53',
#     'ResNet/Sequential[layer2]/BasicBlock[0]/BatchNorm2d[bn2]/running_var/running_var.53',
#     'ResNet/Sequential[layer2]/BasicBlock[0]/Conv2d[conv1]/1326',
#     'ResNet/Sequential[layer2]/BasicBlock[0]/BatchNorm2d[bn1]/1331',
#     'ResNet/Sequential[layer2]/BasicBlock[0]/BatchNorm2d[bn1]/1330',
#     'ResNet/Sequential[layer2]/BasicBlock[0]/Conv2d[conv1]/1324'],
#    'attr': {'attr': {'s': '{}'},
#     '_output_shapes': {'list': {'shape': [{'dim': [{'size': '1'},
#          {'size': '128'},
#          {'size': '28'},
#          {'size': '28'}]}]}}}},
#   {'name': 'ResNet/Sequential[layer2]/BasicBlock[0]/Sequential[downsample]/Conv2d[0]/weight/weight.109',
#    'op': 'prim::GetAttr',
#    'input': ['ResNet/Sequential[layer2]/BasicBlock[0]/Sequential[downsample]/Conv2d[0]/weight/_0.3'],
#    'attr': {'attr': {'s': '{ name :  weight }'}}},
#   {'name': 'ResNet/Sequential[layer2]/BasicBlock[0]/Sequential[downsample]/Conv2d[0]/1366',
#    'op': 'prim::ListConstruct',
#    'input': ['ResNet/Sequential[layer2]/BasicBlock[0]/Conv2d[conv1]/1328',
#     'ResNet/Sequential[layer2]/BasicBlock[0]/Conv2d[conv1]/1328'],
#    'attr': {'attr': {'s': '{}'}}},
#   {'name': 'ResNet/Sequential[layer2]/BasicBlock[0]/Sequential[downsample]/Conv2d[0]/1367',
#    'op': 'prim::ListConstruct',
#    'input': ['ResNet/Sequential[layer2]/BasicBlock[0]/Conv2d[conv1]/1325',
#     'ResNet/Sequential[layer2]/BasicBlock[0]/Conv2d[conv1]/1325'],
#    'attr': {'attr': {'s': '{}'}}},
#   {'name': 'ResNet/Sequential[layer2]/BasicBlock[0]/Sequential[downsample]/Conv2d[0]/1368',
#    'op': 'prim::ListConstruct',
#    'input': ['ResNet/Sequential[layer2]/BasicBlock[0]/Conv2d[conv1]/1327',
#     'ResNet/Sequential[layer2]/BasicBlock[0]/Conv2d[conv1]/1327'],
#    'attr': {'attr': {'s': '{}'}}},
#   {'name': 'ResNet/Sequential[layer2]/BasicBlock[0]/Sequential[downsample]/Conv2d[0]/1369',
#    'op': 'prim::ListConstruct',
#    'input': ['ResNet/Sequential[layer2]/BasicBlock[0]/Conv2d[conv1]/1325',
#     'ResNet/Sequential[layer2]/BasicBlock[0]/Conv2d[conv1]/1325'],
#    'attr': {'attr': {'s': '{}'}}},
#   {'name': 'ResNet/Sequential[layer2]/BasicBlock[0]/Sequential[downsample]/Conv2d[0]/input.41',
#    'op': 'aten::_convolution',
#    'input': ['ResNet/Sequential[layer1]/BasicBlock[1]/ReLU[relu]/input.31',
#     'ResNet/Sequential[layer2]/BasicBlock[0]/Sequential[downsample]/Conv2d[0]/weight/weight.109',
#     'ResNet/Sequential[layer2]/BasicBlock[0]/Conv2d[conv1]/1329',
#     'ResNet/Sequential[layer2]/BasicBlock[0]/Sequential[downsample]/Conv2d[0]/1366',
#     'ResNet/Sequential[layer2]/BasicBlock[0]/Sequential[downsample]/Conv2d[0]/1367',
#     'ResNet/Sequential[layer2]/BasicBlock[0]/Sequential[downsample]/Conv2d[0]/1368',
#     'ResNet/Sequential[layer2]/BasicBlock[0]/Conv2d[conv1]/1326',
#     'ResNet/Sequential[layer2]/BasicBlock[0]/Sequential[downsample]/Conv2d[0]/1369',
#     'ResNet/Sequential[layer2]/BasicBlock[0]/Conv2d[conv1]/1327',
#     'ResNet/Sequential[layer2]/BasicBlock[0]/Conv2d[conv1]/1326',
#     'ResNet/Sequential[layer2]/BasicBlock[0]/Conv2d[conv1]/1326',
#     'ResNet/Sequential[layer2]/BasicBlock[0]/Conv2d[conv1]/1324',
#     'ResNet/Sequential[layer2]/BasicBlock[0]/Conv2d[conv1]/1324'],
#    'attr': {'attr': {'s': '{}'},
#     '_output_shapes': {'list': {'shape': [{'dim': [{'size': '1'},
#          {'size': '128'},
#          {'size': '28'},
#          {'size': '28'}]}]}}}},
#   {'name': 'ResNet/Sequential[layer2]/BasicBlock[0]/Sequential[downsample]/BatchNorm2d[1]/running_var/running_var.55',
#    'op': 'prim::GetAttr',
#    'input': ['ResNet/Sequential[layer2]/BasicBlock[0]/Sequential[downsample]/BatchNorm2d[1]/weight/_1.3'],
#    'attr': {'attr': {'s': '{ name :  running_var }'}}},
#   {'name': 'ResNet/Sequential[layer2]/BasicBlock[0]/Sequential[downsample]/BatchNorm2d[1]/running_mean/running_mean.55',
#    'op': 'prim::GetAttr',
#    'input': ['ResNet/Sequential[layer2]/BasicBlock[0]/Sequential[downsample]/BatchNorm2d[1]/weight/_1.3'],
#    'attr': {'attr': {'s': '{ name :  running_mean }'}}},
#   {'name': 'ResNet/Sequential[layer2]/BasicBlock[0]/Sequential[downsample]/BatchNorm2d[1]/bias/bias.55',
#    'op': 'prim::GetAttr',
#    'input': ['ResNet/Sequential[layer2]/BasicBlock[0]/Sequential[downsample]/BatchNorm2d[1]/weight/_1.3'],
#    'attr': {'attr': {'s': '{ name :  bias }'}}},
#   {'name': 'ResNet/Sequential[layer2]/BasicBlock[0]/Sequential[downsample]/BatchNorm2d[1]/weight/weight.111',
#    'op': 'prim::GetAttr',
#    'input': ['ResNet/Sequential[layer2]/BasicBlock[0]/Sequential[downsample]/BatchNorm2d[1]/weight/_1.3'],
#    'attr': {'attr': {'s': '{ name :  weight }'}}},
#   {'name': 'ResNet/Sequential[layer2]/BasicBlock[0]/Sequential[downsample]/BatchNorm2d[1]/identity.1',
#    'op': 'aten::batch_norm',
#    'input': ['ResNet/Sequential[layer2]/BasicBlock[0]/Sequential[downsample]/Conv2d[0]/input.41',
#     'ResNet/Sequential[layer2]/BasicBlock[0]/Sequential[downsample]/BatchNorm2d[1]/weight/weight.111',
#     'ResNet/Sequential[layer2]/BasicBlock[0]/Sequential[downsample]/BatchNorm2d[1]/bias/bias.55',
#     'ResNet/Sequential[layer2]/BasicBlock[0]/Sequential[downsample]/BatchNorm2d[1]/running_mean/running_mean.55',
#     'ResNet/Sequential[layer2]/BasicBlock[0]/Sequential[downsample]/BatchNorm2d[1]/running_var/running_var.55',
#     'ResNet/Sequential[layer2]/BasicBlock[0]/Conv2d[conv1]/1326',
#     'ResNet/Sequential[layer2]/BasicBlock[0]/BatchNorm2d[bn1]/1331',
#     'ResNet/Sequential[layer2]/BasicBlock[0]/BatchNorm2d[bn1]/1330',
#     'ResNet/Sequential[layer2]/BasicBlock[0]/Conv2d[conv1]/1324'],
#    'attr': {'attr': {'s': '{}'},
#     '_output_shapes': {'list': {'shape': [{'dim': [{'size': '1'},
#          {'size': '128'},
#          {'size': '28'},
#          {'size': '28'}]}]}}}},
#   {'name': 'ResNet/Sequential[layer2]/BasicBlock[0]/input.43',
#    'op': 'aten::add_',
#    'input': ['ResNet/Sequential[layer2]/BasicBlock[0]/BatchNorm2d[bn2]/out.5',
#     'ResNet/Sequential[layer2]/BasicBlock[0]/Sequential[downsample]/BatchNorm2d[1]/identity.1',
#     'ResNet/Sequential[layer2]/BasicBlock[0]/Conv2d[conv1]/1327'],
#    'attr': {'attr': {'s': '{}'},
#     '_output_shapes': {'list': {'shape': [{'dim': [{'size': '1'},
#          {'size': '128'},
#          {'size': '28'},
#          {'size': '28'}]}]}}}},
#   {'name': 'ResNet/Sequential[layer2]/BasicBlock[0]/ReLU[relu]/input.45',
#    'op': 'aten::relu_',
#    'input': ['ResNet/Sequential[layer2]/BasicBlock[0]/input.43'],
#    'attr': {'attr': {'s': '{}'},
#     '_output_shapes': {'list': {'shape': [{'dim': [{'size': '1'},
#          {'size': '128'},
#          {'size': '28'},
#          {'size': '28'}]}]}}}},
#   {'name': 'ResNet/Sequential[layer2]/BasicBlock[1]/Conv2d[conv1]/weight/weight.113',
#    'op': 'prim::GetAttr',
#    'input': ['ResNet/Sequential[layer2]/BasicBlock[1]/Conv2d[conv1]/weight/conv1.9'],
#    'attr': {'attr': {'s': '{ name :  weight }'}}},
#   {'name': 'ResNet/Sequential[layer2]/BasicBlock[1]/Conv2d[conv1]/1384',
#    'op': 'prim::ListConstruct',
#    'input': ['ResNet/Sequential[layer2]/BasicBlock[0]/Conv2d[conv1]/1327',
#     'ResNet/Sequential[layer2]/BasicBlock[0]/Conv2d[conv1]/1327'],
#    'attr': {'attr': {'s': '{}'}}},
#   {'name': 'ResNet/Sequential[layer2]/BasicBlock[1]/Conv2d[conv1]/1385',
#    'op': 'prim::ListConstruct',
#    'input': ['ResNet/Sequential[layer2]/BasicBlock[0]/Conv2d[conv1]/1327',
#     'ResNet/Sequential[layer2]/BasicBlock[0]/Conv2d[conv1]/1327'],
#    'attr': {'attr': {'s': '{}'}}},
#   {'name': 'ResNet/Sequential[layer2]/BasicBlock[1]/Conv2d[conv1]/1386',
#    'op': 'prim::ListConstruct',
#    'input': ['ResNet/Sequential[layer2]/BasicBlock[0]/Conv2d[conv1]/1327',
#     'ResNet/Sequential[layer2]/BasicBlock[0]/Conv2d[conv1]/1327'],
#    'attr': {'attr': {'s': '{}'}}},
#   {'name': 'ResNet/Sequential[layer2]/BasicBlock[1]/Conv2d[conv1]/1387',
#    'op': 'prim::ListConstruct',
#    'input': ['ResNet/Sequential[layer2]/BasicBlock[0]/Conv2d[conv1]/1325',
#     'ResNet/Sequential[layer2]/BasicBlock[0]/Conv2d[conv1]/1325'],
#    'attr': {'attr': {'s': '{}'}}},
#   {'name': 'ResNet/Sequential[layer2]/BasicBlock[1]/Conv2d[conv1]/input.47',
#    'op': 'aten::_convolution',
#    'input': ['ResNet/Sequential[layer2]/BasicBlock[0]/ReLU[relu]/input.45',
#     'ResNet/Sequential[layer2]/BasicBlock[1]/Conv2d[conv1]/weight/weight.113',
#     'ResNet/Sequential[layer2]/BasicBlock[0]/Conv2d[conv1]/1329',
#     'ResNet/Sequential[layer2]/BasicBlock[1]/Conv2d[conv1]/1384',
#     'ResNet/Sequential[layer2]/BasicBlock[1]/Conv2d[conv1]/1385',
#     'ResNet/Sequential[layer2]/BasicBlock[1]/Conv2d[conv1]/1386',
#     'ResNet/Sequential[layer2]/BasicBlock[0]/Conv2d[conv1]/1326',
#     'ResNet/Sequential[layer2]/BasicBlock[1]/Conv2d[conv1]/1387',
#     'ResNet/Sequential[layer2]/BasicBlock[0]/Conv2d[conv1]/1327',
#     'ResNet/Sequential[layer2]/BasicBlock[0]/Conv2d[conv1]/1326',
#     'ResNet/Sequential[layer2]/BasicBlock[0]/Conv2d[conv1]/1326',
#     'ResNet/Sequential[layer2]/BasicBlock[0]/Conv2d[conv1]/1324',
#     'ResNet/Sequential[layer2]/BasicBlock[0]/Conv2d[conv1]/1324'],
#    'attr': {'attr': {'s': '{}'},
#     '_output_shapes': {'list': {'shape': [{'dim': [{'size': '1'},
#          {'size': '128'},
#          {'size': '28'},
#          {'size': '28'}]}]}}}},
#   {'name': 'ResNet/Sequential[layer2]/BasicBlock[1]/BatchNorm2d[bn1]/running_var/running_var.57',
#    'op': 'prim::GetAttr',
#    'input': ['ResNet/Sequential[layer2]/BasicBlock[1]/BatchNorm2d[bn1]/weight/bn1.9'],
#    'attr': {'attr': {'s': '{ name :  running_var }'}}},
#   {'name': 'ResNet/Sequential[layer2]/BasicBlock[1]/BatchNorm2d[bn1]/running_mean/running_mean.57',
#    'op': 'prim::GetAttr',
#    'input': ['ResNet/Sequential[layer2]/BasicBlock[1]/BatchNorm2d[bn1]/weight/bn1.9'],
# ...
#     'ResNet/Sequential[layer4]/BasicBlock[0]/Conv2d[conv1]/1494',
#     'ResNet/Sequential[layer4]/BasicBlock[0]/Sequential[downsample]/Conv2d[0]/1537',
#     'ResNet/Sequential[layer4]/BasicBlock[0]/Conv2d[conv1]/1495',
#     'ResNet/Sequential[layer4]/BasicBlock[0]/Conv2d[conv1]/1494',
#     'ResNet/Sequential[layer4]/BasicBlock[0]/Conv2d[conv1]/1494',
#     'ResNet/Sequential[layer4]/BasicBlock[0]/Conv2d[conv1]/1492',
#     'ResNet/Sequential[layer4]/BasicBlock[0]/Conv2d[conv1]/1492'],
#    'attr': {'attr': {'s': '{}'},
#     '_output_shapes': {'list': {'shape': [{'dim': [{'size': '1'},
#          {'size': '512'},
#          {'size': '7'},
#          {'size': '7'}]}]}}}},
#   {'name': 'ResNet/Sequential[layer4]/BasicBlock[0]/Sequential[downsample]/BatchNorm2d[1]/running_var/running_var.75',
#    'op': 'prim::GetAttr',
#    'input': ['ResNet/Sequential[layer4]/BasicBlock[0]/Sequential[downsample]/BatchNorm2d[1]/weight/_1.11'],
#    'attr': {'attr': {'s': '{ name :  running_var }'}}},
#   {'name': 'ResNet/Sequential[layer4]/BasicBlock[0]/Sequential[downsample]/BatchNorm2d[1]/running_mean/running_mean.75',
#    'op': 'prim::GetAttr',
#    'input': ['ResNet/Sequential[layer4]/BasicBlock[0]/Sequential[downsample]/BatchNorm2d[1]/weight/_1.11'],
#    'attr': {'attr': {'s': '{ name :  running_mean }'}}},
#   {'name': 'ResNet/Sequential[layer4]/BasicBlock[0]/Sequential[downsample]/BatchNorm2d[1]/bias/bias.75',
#    'op': 'prim::GetAttr',
#    'input': ['ResNet/Sequential[layer4]/BasicBlock[0]/Sequential[downsample]/BatchNorm2d[1]/weight/_1.11'],
#    'attr': {'attr': {'s': '{ name :  bias }'}}},
#   {'name': 'ResNet/Sequential[layer4]/BasicBlock[0]/Sequential[downsample]/BatchNorm2d[1]/weight/weight.151',
#    'op': 'prim::GetAttr',
#    'input': ['ResNet/Sequential[layer4]/BasicBlock[0]/Sequential[downsample]/BatchNorm2d[1]/weight/_1.11'],
#    'attr': {'attr': {'s': '{ name :  weight }'}}},
#   {'name': 'ResNet/Sequential[layer4]/BasicBlock[0]/Sequential[downsample]/BatchNorm2d[1]/identity',
#    'op': 'aten::batch_norm',
#    'input': ['ResNet/Sequential[layer4]/BasicBlock[0]/Sequential[downsample]/Conv2d[0]/input.93',
#     'ResNet/Sequential[layer4]/BasicBlock[0]/Sequential[downsample]/BatchNorm2d[1]/weight/weight.151',
#     'ResNet/Sequential[layer4]/BasicBlock[0]/Sequential[downsample]/BatchNorm2d[1]/bias/bias.75',
#     'ResNet/Sequential[layer4]/BasicBlock[0]/Sequential[downsample]/BatchNorm2d[1]/running_mean/running_mean.75',
#     'ResNet/Sequential[layer4]/BasicBlock[0]/Sequential[downsample]/BatchNorm2d[1]/running_var/running_var.75',
#     'ResNet/Sequential[layer4]/BasicBlock[0]/Conv2d[conv1]/1494',
#     'ResNet/Sequential[layer4]/BasicBlock[0]/BatchNorm2d[bn1]/1499',
#     'ResNet/Sequential[layer4]/BasicBlock[0]/BatchNorm2d[bn1]/1498',
#     'ResNet/Sequential[layer4]/BasicBlock[0]/Conv2d[conv1]/1492'],
#    'attr': {'attr': {'s': '{}'},
#     '_output_shapes': {'list': {'shape': [{'dim': [{'size': '1'},
#          {'size': '512'},
#          {'size': '7'},
#          {'size': '7'}]}]}}}},
#   {'name': 'ResNet/Sequential[layer4]/BasicBlock[0]/input.95',
#    'op': 'aten::add_',
#    'input': ['ResNet/Sequential[layer4]/BasicBlock[0]/BatchNorm2d[bn2]/out.13',
#     'ResNet/Sequential[layer4]/BasicBlock[0]/Sequential[downsample]/BatchNorm2d[1]/identity',
#     'ResNet/Sequential[layer4]/BasicBlock[0]/Conv2d[conv1]/1495'],
#    'attr': {'attr': {'s': '{}'},
#     '_output_shapes': {'list': {'shape': [{'dim': [{'size': '1'},
#          {'size': '512'},
#          {'size': '7'},
#          {'size': '7'}]}]}}}},
#   {'name': 'ResNet/Sequential[layer4]/BasicBlock[0]/ReLU[relu]/input.97',
#    'op': 'aten::relu_',
#    'input': ['ResNet/Sequential[layer4]/BasicBlock[0]/input.95'],
#    'attr': {'attr': {'s': '{}'},
#     '_output_shapes': {'list': {'shape': [{'dim': [{'size': '1'},
#          {'size': '512'},
#          {'size': '7'},
#          {'size': '7'}]}]}}}},
#   {'name': 'ResNet/Sequential[layer4]/BasicBlock[1]/Conv2d[conv1]/weight/weight.153',
#    'op': 'prim::GetAttr',
#    'input': ['ResNet/Sequential[layer4]/BasicBlock[1]/Conv2d[conv1]/weight/conv1'],
#    'attr': {'attr': {'s': '{ name :  weight }'}}},
#   {'name': 'ResNet/Sequential[layer4]/BasicBlock[1]/Conv2d[conv1]/1552',
#    'op': 'prim::ListConstruct',
#    'input': ['ResNet/Sequential[layer4]/BasicBlock[0]/Conv2d[conv1]/1495',
#     'ResNet/Sequential[layer4]/BasicBlock[0]/Conv2d[conv1]/1495'],
#    'attr': {'attr': {'s': '{}'}}},
#   {'name': 'ResNet/Sequential[layer4]/BasicBlock[1]/Conv2d[conv1]/1553',
#    'op': 'prim::ListConstruct',
#    'input': ['ResNet/Sequential[layer4]/BasicBlock[0]/Conv2d[conv1]/1495',
#     'ResNet/Sequential[layer4]/BasicBlock[0]/Conv2d[conv1]/1495'],
#    'attr': {'attr': {'s': '{}'}}},
#   {'name': 'ResNet/Sequential[layer4]/BasicBlock[1]/Conv2d[conv1]/1554',
#    'op': 'prim::ListConstruct',
#    'input': ['ResNet/Sequential[layer4]/BasicBlock[0]/Conv2d[conv1]/1495',
#     'ResNet/Sequential[layer4]/BasicBlock[0]/Conv2d[conv1]/1495'],
#    'attr': {'attr': {'s': '{}'}}},
#   {'name': 'ResNet/Sequential[layer4]/BasicBlock[1]/Conv2d[conv1]/1555',
#    'op': 'prim::ListConstruct',
#    'input': ['ResNet/Sequential[layer4]/BasicBlock[0]/Conv2d[conv1]/1493',
#     'ResNet/Sequential[layer4]/BasicBlock[0]/Conv2d[conv1]/1493'],
#    'attr': {'attr': {'s': '{}'}}},
#   {'name': 'ResNet/Sequential[layer4]/BasicBlock[1]/Conv2d[conv1]/input.99',
#    'op': 'aten::_convolution',
#    'input': ['ResNet/Sequential[layer4]/BasicBlock[0]/ReLU[relu]/input.97',
#     'ResNet/Sequential[layer4]/BasicBlock[1]/Conv2d[conv1]/weight/weight.153',
#     'ResNet/Sequential[layer4]/BasicBlock[0]/Conv2d[conv1]/1497',
#     'ResNet/Sequential[layer4]/BasicBlock[1]/Conv2d[conv1]/1552',
#     'ResNet/Sequential[layer4]/BasicBlock[1]/Conv2d[conv1]/1553',
#     'ResNet/Sequential[layer4]/BasicBlock[1]/Conv2d[conv1]/1554',
#     'ResNet/Sequential[layer4]/BasicBlock[0]/Conv2d[conv1]/1494',
#     'ResNet/Sequential[layer4]/BasicBlock[1]/Conv2d[conv1]/1555',
#     'ResNet/Sequential[layer4]/BasicBlock[0]/Conv2d[conv1]/1495',
#     'ResNet/Sequential[layer4]/BasicBlock[0]/Conv2d[conv1]/1494',
#     'ResNet/Sequential[layer4]/BasicBlock[0]/Conv2d[conv1]/1494',
#     'ResNet/Sequential[layer4]/BasicBlock[0]/Conv2d[conv1]/1492',
#     'ResNet/Sequential[layer4]/BasicBlock[0]/Conv2d[conv1]/1492'],
#    'attr': {'attr': {'s': '{}'},
#     '_output_shapes': {'list': {'shape': [{'dim': [{'size': '1'},
#          {'size': '512'},
#          {'size': '7'},
#          {'size': '7'}]}]}}}},
#   {'name': 'ResNet/Sequential[layer4]/BasicBlock[1]/BatchNorm2d[bn1]/running_var/running_var.77',
#    'op': 'prim::GetAttr',
#    'input': ['ResNet/Sequential[layer4]/BasicBlock[1]/BatchNorm2d[bn1]/weight/bn1'],
#    'attr': {'attr': {'s': '{ name :  running_var }'}}},
#   {'name': 'ResNet/Sequential[layer4]/BasicBlock[1]/BatchNorm2d[bn1]/running_mean/running_mean.77',
#    'op': 'prim::GetAttr',
#    'input': ['ResNet/Sequential[layer4]/BasicBlock[1]/BatchNorm2d[bn1]/weight/bn1'],
#    'attr': {'attr': {'s': '{ name :  running_mean }'}}},
#   {'name': 'ResNet/Sequential[layer4]/BasicBlock[1]/BatchNorm2d[bn1]/bias/bias.77',
#    'op': 'prim::GetAttr',
#    'input': ['ResNet/Sequential[layer4]/BasicBlock[1]/BatchNorm2d[bn1]/weight/bn1'],
#    'attr': {'attr': {'s': '{ name :  bias }'}}},
#   {'name': 'ResNet/Sequential[layer4]/BasicBlock[1]/BatchNorm2d[bn1]/weight/weight.155',
#    'op': 'prim::GetAttr',
#    'input': ['ResNet/Sequential[layer4]/BasicBlock[1]/BatchNorm2d[bn1]/weight/bn1'],
#    'attr': {'attr': {'s': '{ name :  weight }'}}},
#   {'name': 'ResNet/Sequential[layer4]/BasicBlock[1]/BatchNorm2d[bn1]/input.101',
#    'op': 'aten::batch_norm',
#    'input': ['ResNet/Sequential[layer4]/BasicBlock[1]/Conv2d[conv1]/input.99',
#     'ResNet/Sequential[layer4]/BasicBlock[1]/BatchNorm2d[bn1]/weight/weight.155',
#     'ResNet/Sequential[layer4]/BasicBlock[1]/BatchNorm2d[bn1]/bias/bias.77',
#     'ResNet/Sequential[layer4]/BasicBlock[1]/BatchNorm2d[bn1]/running_mean/running_mean.77',
#     'ResNet/Sequential[layer4]/BasicBlock[1]/BatchNorm2d[bn1]/running_var/running_var.77',
#     'ResNet/Sequential[layer4]/BasicBlock[0]/Conv2d[conv1]/1494',
#     'ResNet/Sequential[layer4]/BasicBlock[0]/BatchNorm2d[bn1]/1499',
#     'ResNet/Sequential[layer4]/BasicBlock[0]/BatchNorm2d[bn1]/1498',
#     'ResNet/Sequential[layer4]/BasicBlock[0]/Conv2d[conv1]/1492'],
#    'attr': {'attr': {'s': '{}'},
#     '_output_shapes': {'list': {'shape': [{'dim': [{'size': '1'},
#          {'size': '512'},
#          {'size': '7'},
#          {'size': '7'}]}]}}}},
#   {'name': 'ResNet/Sequential[layer4]/BasicBlock[1]/ReLU[relu]/input.103',
#    'op': 'aten::relu_',
#    'input': ['ResNet/Sequential[layer4]/BasicBlock[1]/BatchNorm2d[bn1]/input.101'],
#    'attr': {'attr': {'s': '{}'},
#     '_output_shapes': {'list': {'shape': [{'dim': [{'size': '1'},
#          {'size': '512'},
#          {'size': '7'},
#          {'size': '7'}]}]}}}},
#   {'name': 'ResNet/Sequential[layer4]/BasicBlock[1]/Conv2d[conv2]/weight/weight.157',
#    'op': 'prim::GetAttr',
#    'input': ['ResNet/Sequential[layer4]/BasicBlock[1]/Conv2d[conv2]/weight/conv2'],
#    'attr': {'attr': {'s': '{ name :  weight }'}}},
#   {'name': 'ResNet/Sequential[layer4]/BasicBlock[1]/Conv2d[conv2]/1564',
#    'op': 'prim::ListConstruct',
#    'input': ['ResNet/Sequential[layer4]/BasicBlock[0]/Conv2d[conv1]/1495',
#     'ResNet/Sequential[layer4]/BasicBlock[0]/Conv2d[conv1]/1495'],
#    'attr': {'attr': {'s': '{}'}}},
#   {'name': 'ResNet/Sequential[layer4]/BasicBlock[1]/Conv2d[conv2]/1565',
#    'op': 'prim::ListConstruct',
#    'input': ['ResNet/Sequential[layer4]/BasicBlock[0]/Conv2d[conv1]/1495',
#     'ResNet/Sequential[layer4]/BasicBlock[0]/Conv2d[conv1]/1495'],
#    'attr': {'attr': {'s': '{}'}}},
#   {'name': 'ResNet/Sequential[layer4]/BasicBlock[1]/Conv2d[conv2]/1566',
#    'op': 'prim::ListConstruct',
#    'input': ['ResNet/Sequential[layer4]/BasicBlock[0]/Conv2d[conv1]/1495',
#     'ResNet/Sequential[layer4]/BasicBlock[0]/Conv2d[conv1]/1495'],
#    'attr': {'attr': {'s': '{}'}}},
#   {'name': 'ResNet/Sequential[layer4]/BasicBlock[1]/Conv2d[conv2]/1567',
#    'op': 'prim::ListConstruct',
#    'input': ['ResNet/Sequential[layer4]/BasicBlock[0]/Conv2d[conv1]/1493',
#     'ResNet/Sequential[layer4]/BasicBlock[0]/Conv2d[conv1]/1493'],
#    'attr': {'attr': {'s': '{}'}}},
#   {'name': 'ResNet/Sequential[layer4]/BasicBlock[1]/Conv2d[conv2]/input.105',
#    'op': 'aten::_convolution',
#    'input': ['ResNet/Sequential[layer4]/BasicBlock[1]/ReLU[relu]/input.103',
#     'ResNet/Sequential[layer4]/BasicBlock[1]/Conv2d[conv2]/weight/weight.157',
#     'ResNet/Sequential[layer4]/BasicBlock[0]/Conv2d[conv1]/1497',
#     'ResNet/Sequential[layer4]/BasicBlock[1]/Conv2d[conv2]/1564',
#     'ResNet/Sequential[layer4]/BasicBlock[1]/Conv2d[conv2]/1565',
#     'ResNet/Sequential[layer4]/BasicBlock[1]/Conv2d[conv2]/1566',
#     'ResNet/Sequential[layer4]/BasicBlock[0]/Conv2d[conv1]/1494',
#     'ResNet/Sequential[layer4]/BasicBlock[1]/Conv2d[conv2]/1567',
#     'ResNet/Sequential[layer4]/BasicBlock[0]/Conv2d[conv1]/1495',
#     'ResNet/Sequential[layer4]/BasicBlock[0]/Conv2d[conv1]/1494',
#     'ResNet/Sequential[layer4]/BasicBlock[0]/Conv2d[conv1]/1494',
#     'ResNet/Sequential[layer4]/BasicBlock[0]/Conv2d[conv1]/1492',
#     'ResNet/Sequential[layer4]/BasicBlock[0]/Conv2d[conv1]/1492'],
#    'attr': {'attr': {'s': '{}'},
#     '_output_shapes': {'list': {'shape': [{'dim': [{'size': '1'},
#          {'size': '512'},
#          {'size': '7'},
#          {'size': '7'}]}]}}}},
#   {'name': 'ResNet/Sequential[layer4]/BasicBlock[1]/BatchNorm2d[bn2]/running_var/running_var',
#    'op': 'prim::GetAttr',
#    'input': ['ResNet/Sequential[layer4]/BasicBlock[1]/BatchNorm2d[bn2]/weight/bn2'],
#    'attr': {'attr': {'s': '{ name :  running_var }'}}},
#   {'name': 'ResNet/Sequential[layer4]/BasicBlock[1]/BatchNorm2d[bn2]/running_mean/running_mean',
#    'op': 'prim::GetAttr',
#    'input': ['ResNet/Sequential[layer4]/BasicBlock[1]/BatchNorm2d[bn2]/weight/bn2'],
#    'attr': {'attr': {'s': '{ name :  running_mean }'}}},
#   {'name': 'ResNet/Sequential[layer4]/BasicBlock[1]/BatchNorm2d[bn2]/bias/bias.79',
#    'op': 'prim::GetAttr',
#    'input': ['ResNet/Sequential[layer4]/BasicBlock[1]/BatchNorm2d[bn2]/weight/bn2'],
#    'attr': {'attr': {'s': '{ name :  bias }'}}},
#   {'name': 'ResNet/Sequential[layer4]/BasicBlock[1]/BatchNorm2d[bn2]/weight/weight.159',
#    'op': 'prim::GetAttr',
#    'input': ['ResNet/Sequential[layer4]/BasicBlock[1]/BatchNorm2d[bn2]/weight/bn2'],
#    'attr': {'attr': {'s': '{ name :  weight }'}}},
#   {'name': 'ResNet/Sequential[layer4]/BasicBlock[1]/BatchNorm2d[bn2]/out',
#    'op': 'aten::batch_norm',
#    'input': ['ResNet/Sequential[layer4]/BasicBlock[1]/Conv2d[conv2]/input.105',
#     'ResNet/Sequential[layer4]/BasicBlock[1]/BatchNorm2d[bn2]/weight/weight.159',
#     'ResNet/Sequential[layer4]/BasicBlock[1]/BatchNorm2d[bn2]/bias/bias.79',
#     'ResNet/Sequential[layer4]/BasicBlock[1]/BatchNorm2d[bn2]/running_mean/running_mean',
#     'ResNet/Sequential[layer4]/BasicBlock[1]/BatchNorm2d[bn2]/running_var/running_var',
#     'ResNet/Sequential[layer4]/BasicBlock[0]/Conv2d[conv1]/1494',
#     'ResNet/Sequential[layer4]/BasicBlock[0]/BatchNorm2d[bn1]/1499',
#     'ResNet/Sequential[layer4]/BasicBlock[0]/BatchNorm2d[bn1]/1498',
#     'ResNet/Sequential[layer4]/BasicBlock[0]/Conv2d[conv1]/1492'],
#    'attr': {'attr': {'s': '{}'},
#     '_output_shapes': {'list': {'shape': [{'dim': [{'size': '1'},
#          {'size': '512'},
#          {'size': '7'},
#          {'size': '7'}]}]}}}},
#   {'name': 'ResNet/Sequential[layer4]/BasicBlock[1]/input.107',
#    'op': 'aten::add_',
#    'input': ['ResNet/Sequential[layer4]/BasicBlock[1]/BatchNorm2d[bn2]/out',
#     'ResNet/Sequential[layer4]/BasicBlock[0]/ReLU[relu]/input.97',
#     'ResNet/Sequential[layer4]/BasicBlock[0]/Conv2d[conv1]/1495'],
#    'attr': {'attr': {'s': '{}'},
#     '_output_shapes': {'list': {'shape': [{'dim': [{'size': '1'},
#          {'size': '512'},
#          {'size': '7'},
#          {'size': '7'}]}]}}}},
#   {'name': 'ResNet/Sequential[layer4]/BasicBlock[1]/ReLU[relu]/input.109',
#    'op': 'aten::relu_',
#    'input': ['ResNet/Sequential[layer4]/BasicBlock[1]/input.107'],
#    'attr': {'attr': {'s': '{}'},
#     '_output_shapes': {'list': {'shape': [{'dim': [{'size': '1'},
#          {'size': '512'},
#          {'size': '7'},
#          {'size': '7'}]}]}}}},
#   {'name': 'ResNet/AdaptiveAvgPool2d[avgpool]/1576',
#    'op': 'prim::Constant',
#    'attr': {'attr': {'s': '{ value : 1}'}}},
#   {'name': 'ResNet/AdaptiveAvgPool2d[avgpool]/1577',
#    'op': 'prim::ListConstruct',
#    'input': ['ResNet/AdaptiveAvgPool2d[avgpool]/1576',
#     'ResNet/AdaptiveAvgPool2d[avgpool]/1576'],
#    'attr': {'attr': {'s': '{}'}}},
#   {'name': 'ResNet/AdaptiveAvgPool2d[avgpool]/x',
#    'op': 'aten::adaptive_avg_pool2d',
#    'input': ['ResNet/Sequential[layer4]/BasicBlock[1]/ReLU[relu]/input.109',
#     'ResNet/AdaptiveAvgPool2d[avgpool]/1577'],
#    'attr': {'attr': {'s': '{}'},
#     '_output_shapes': {'list': {'shape': [{'dim': [{'size': '1'},
#          {'size': '512'},
#          {'size': '1'},
#          {'size': '1'}]}]}}}},
#   {'name': 'ResNet/890',
#    'op': 'prim::Constant',
#    'attr': {'attr': {'s': '{ value : 1}'}}},
#   {'name': 'ResNet/891',
#    'op': 'prim::Constant',
#    'attr': {'attr': {'s': '{ value : -1}'}}},
#   {'name': 'ResNet/input',
#    'op': 'aten::flatten',
#    'input': ['ResNet/AdaptiveAvgPool2d[avgpool]/x',
#     'ResNet/890',
#     'ResNet/891'],
#    'attr': {'attr': {'s': '{}'},
#     '_output_shapes': {'list': {'shape': [{'dim': [{'size': '1'},
#          {'size': '512'}]}]}}}},
#   {'name': 'ResNet/Linear[fc]/bias/bias',
#    'op': 'prim::GetAttr',
#    'input': ['ResNet/Linear[fc]/weight/fc'],
#    'attr': {'attr': {'s': '{ name :  bias }'}}},
#   {'name': 'ResNet/Linear[fc]/weight/weight',
#    'op': 'prim::GetAttr',
#    'input': ['ResNet/Linear[fc]/weight/fc'],
#    'attr': {'attr': {'s': '{ name :  weight }'}}},
#   {'name': 'ResNet/Linear[fc]/1581',
#    'op': 'aten::linear',
#    'input': ['ResNet/input',
#     'ResNet/Linear[fc]/weight/weight',
#     'ResNet/Linear[fc]/bias/bias'],
#    'attr': {'attr': {'s': '{}'},
#     '_output_shapes': {'list': {'shape': [{'dim': [{'size': '1'},
#          {'size': '1000'}]}]}}}}],
#  'versions': {'producer': 22}}

# %%
import json
with open("output.json", "w", encoding="utf-8") as f:
    json.dump(data_dict, f, ensure_ascii=False, indent=4)

# %% [markdown]
# ---
